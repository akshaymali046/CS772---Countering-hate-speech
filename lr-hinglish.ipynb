# %%
import csv
all_hate_tweets=[]
all_nonhate_tweets=[]
with open('hate_speech.tsv', newline='', encoding="utf8") as tsvfile:
    reader = csv.reader(tsvfile, delimiter='\t')
    for row in reader:
        if row[1] == 'yes': 
            all_hate_tweets.append(row[0])
        else:
            all_nonhate_tweets.append(row[0])

# %%
import re
import string
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import TweetTokenizer
from matplotlib.patches import Ellipse
import matplotlib.transforms as transforms
import numpy as np 
import pdb
import numpy as np
import pandas as pd
import nltk
import string
from nltk.tokenize import TweetTokenizer
from os import getcwd

# %%
def process_tweet(tweet):
    '''
    Input: 
        tweet: a string containing a tweet
    Output:
        tweets_clean: a list of words containing the processed tweet

    '''
    stemmer = PorterStemmer()
    stopwords_english = stopwords.words('english')
    # remove stock market tickers like $GE
    tweet = re.sub(r'\$\w*', '', tweet)
    # remove old style retweet text "RT"
    tweet = re.sub(r'^RT[\s]+', '', tweet)
    # remove hyperlinks
    #tweet = re.sub(r'https?:\/\/.*[\r\n]*', '', tweet)
    tweet = re.sub(r'https?://[^\s\n\r]+', '', tweet)
    # remove hashtags
    # only removing the hash # sign from the word
    tweet = re.sub(r'#', '', tweet)
    # tokenize tweets
    tokenizer = TweetTokenizer(preserve_case=False, strip_handles=True,
                               reduce_len=True)
    tweet_tokens = tokenizer.tokenize(tweet)

    tweets_clean = []
    for word in tweet_tokens:
        if (word not in stopwords_english and  # remove stopwords
            word not in string.punctuation):  # remove punctuation
            # tweets_clean.append(word)
            stem_word = word # stemming word
            tweets_clean.append(stem_word)

    return tweets_clean

# %%
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import TweetTokenizer
import re
import string
from matplotlib.patches import Ellipse
import matplotlib.transforms as transforms
import numpy as np 
from collections import defaultdict
words_dict = defaultdict(int)

# %%
# split the data into two pieces, one for training and one for testing (validation set)
test_pos = all_nonhate_tweets[2400:]
train_pos = all_nonhate_tweets[:2400]
test_neg = all_hate_tweets[1328:]
train_neg = all_hate_tweets[:1328]

train_x = train_pos + train_neg
test_x = test_pos + test_neg

# avoid assumptions about the length of all_positive_tweets
train_y = np.append(np.ones(len(train_pos)), np.zeros(len(train_neg)))
test_y = np.append(np.ones(len(test_pos)), np.zeros(len(test_neg)))

# %%
# Print the shape train and test sets
print("train_y.shape = " + str(train_y.shape))
print("test_y.shape = " + str(test_y.shape))
# Out:
# train_y.shape = (3728,)
# test_y.shape = (851,)

# %%
def build_freqs(tweets, ys):
    """Build frequencies.
    Input:
        tweets: a list of tweets
        ys: an m x 1 array with the sentiment label of each tweet
            (either 0 or 1)
    Output:
        freqs: a dictionary mapping each (word, sentiment) pair to its
        frequency
    """
    # Convert np array to list since zip needs an iterable.
    # The squeeze is necessary or the list ends up with one element.
    # Also note that this is just a NOP if ys is already a list.
    yslist = np.squeeze(ys).tolist()

    # Start with an empty dictionary and populate it by looping over all tweets
    # and over all processed words in each tweet.
    freqs = {}
    for y, tweet in zip(yslist, tweets):
        for word in process_tweet(tweet):
            pair = (word, y)
            if pair in freqs:
                freqs[pair] += 1
            else:
                freqs[pair] = 1

    return freqs

# %% [markdown]
# * Create the frequency dictionary using the imported build_freqs function.
#     * We highly recommend that you open utils.py and read the build_freqs function to understand what it is doing.
#     * To view the file directory, go to the menu and click File->Open.
#
# ```Python
#     for y,tweet in zip(ys, tweets):
#         for word in process_tweet(tweet):
#             pair = (word, y)
#             if pair in freqs:
#                 freqs[pair] += 1
#             else:
#                 freqs[pair] = 1
# ```
# * Notice how the outer for loop goes through each tweet, and the inner for loop steps through each word in a tweet.
# * The 'freqs' dictionary is the frequency dictionary that's being built.
# * The key is the tuple (word, label), such as ("happy",1) or ("happy",0).  The value stored for each key is the count of how many times the word "happy" was associated with a positive label, or how many times "happy" was associated with a negative label.

# %%
# create frequency dictionary
freqs = build_freqs(train_x, train_y)

# check the output
print("type(freqs) = " + str(type(freqs)))
print("len(freqs) = " + str(len(freqs.keys())))
# Out:
# type(freqs) = <class 'dict'>
# len(freqs) = 15667

# %% [markdown]
# #### Expected output
# ```
# type(freqs) = <class 'dict'>
# len(freqs) = 11436
# ```

# %% [markdown]
# ### Process Tweet
# The given function 'process_tweet' tokenizes the tweet into individual words, removes stop words and applies stemming.

# %%
# test the function below
print('This is an example of a positive tweet: \n', train_x[1])
print('\nThis is an example of the processed version of the tweet: \n', process_tweet(train_x[1]))
# Out:
# This is an example of a positive tweet:
#  I am Muhajir .. Aur mere lye sab se Pehly Pakistan he .. agr 10 lakh Altaf Jese leaders bh is zameen ki behurmati kren un sbko sar e aam phansi Deni chahye .. Proud to be a #Muhajir and #Pakistani
#
# This is an example of the processed version of the tweet:
#  ['muhajir', '..', 'aur', 'mere', 'lye', 'sab', 'se', 'pehly', 'pakistan', '..', 'agr', '10', 'lakh', 'altaf', 'jese', 'leaders', 'bh', 'zameen', 'ki', 'behurmati', 'kren', 'un', 'sbko', 'sar', 'e', 'aam', 'phansi', 'deni', 'chahye', '..', 'proud', 'muhajir', 'pakistani']

# %% [markdown]
# <a name='1'></a>
# ## 1 - Logistic Regression
#
# <a name='1-1'></a>
# ### 1.1 - Sigmoid
# You will learn to use logistic regression for text classification.
# * The sigmoid function is defined as:
#
# $$ h(z) = \frac{1}{1+\exp^{-z}} \tag{1}$$
#
# It maps the input 'z' to a value that ranges between 0 and 1, and so it can be treated as a probability.
#
# <div style="width:image width px; font-size:100%; text-align:center;"><img src='./images/sigmoid_plot.jpg' alt="alternate text" width="width" height="height" style="width:300px;height:200px;" /> Figure 1 </div>

# %% [markdown]
# <a name='ex-1'></a>
# ### Exercise 1 -  sigmoid
# Implement the sigmoid function.
# * You will want this function to work if z is a scalar as well as if it is an array.

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li><a href="https://docs.scipy.org/doc/numpy/reference/generated/numpy.exp.html" > numpy.exp </a> </li>
#
# </ul>
# </p>

# %%
# UNQ_C1 GRADED FUNCTION: sigmoid
def sigmoid(z): 
    '''
    Input:
        z: is the input (can be a scalar or an array)
    Output:
        h: the sigmoid of z
    '''
    
    ### START CODE HERE ###
    # calculate the sigmoid of z
    h = 1/(1+np.exp(-z))
    ### END CODE HERE ###
    
    return h

# %%
# Testing your function 
if (sigmoid(0) == 0.5):
    print('SUCCESS!')
else:
    print('Oops!')

if (sigmoid(4.92) == 0.9927537604041685):
    print('CORRECT!')
else:
    print('Oops again!')
# Out:
# SUCCESS!
# CORRECT!

# %% [markdown]
# #### Logistic Regression: Regression and a Sigmoid
#
# Logistic regression takes a regular linear regression, and applies a sigmoid to the output of the linear regression.
#
# Regression:
# $$z = \theta_0 x_0 + \theta_1 x_1 + \theta_2 x_2 + ... \theta_N x_N$$
# Note that the $\theta$ values are "weights". If you took the deep learning specialization, we referred to the weights with the 'w' vector.  In this course, we're using a different variable $\theta$ to refer to the weights.
#
# Logistic regression
# $$ h(z) = \frac{1}{1+\exp^{-z}}$$
# $$z = \theta_0 x_0 + \theta_1 x_1 + \theta_2 x_2 + ... \theta_N x_N$$
# We will refer to 'z' as the 'logits'.

# %% [markdown]
# <a name='1-2'></a>
# ### 1.2 - Cost function and Gradient
#
# The cost function used for logistic regression is the average of the log loss across all training examples:
#
# $$J(\theta) = -\frac{1}{m} \sum_{i=1}^m y^{(i)}\log (h(z(\theta)^{(i)})) + (1-y^{(i)})\log (1-h(z(\theta)^{(i)}))\tag{5} $$
# * $m$ is the number of training examples
# * $y^{(i)}$ is the actual label of training example 'i'.
# * $h(z^{(i)})$ is the model's prediction for the training example 'i'.
#
# The loss function for a single training example is
# $$ Loss = -1 \times \left( y^{(i)}\log (h(z(\theta)^{(i)})) + (1-y^{(i)})\log (1-h(z(\theta)^{(i)})) \right)$$
#
# * All the $h$ values are between 0 and 1, so the logs will be negative. That is the reason for the factor of -1 applied to the sum of the two loss terms.
# * Note that when the model predicts 1 ($h(z(\theta)) = 1$) and the label 'y' is also 1, the loss for that training example is 0.
# * Similarly, when the model predicts 0 ($h(z(\theta)) = 0$) and the actual label is also 0, the loss for that training example is 0.
# * However, when the model prediction is close to 1 ($h(z(\theta)) = 0.9999$) and the label is 0, the second term of the log loss becomes a large negative number, which is then multiplied by the overall factor of -1 to convert it to a positive loss value. $-1 \times (1 - 0) \times log(1 - 0.9999) \approx 9.2$ The closer the model prediction gets to 1, the larger the loss.

# %%
# verify that when the model predicts close to 1, but the actual label is 0, the loss is a large positive value
-1 * (1 - 0) * np.log(1 - 0.9999) # loss is about 9.2
# Out:
# 9.210340371976294

# %% [markdown]
# * Likewise, if the model predicts close to 0 ($h(z) = 0.0001$) but the actual label is 1, the first term in the loss function becomes a large number: $-1 \times log(0.0001) \approx 9.2$.  The closer the prediction is to zero, the larger the loss.

# %%
# verify that when the model predicts close to 0 but the actual label is 1, the loss is a large positive value
-1 * np.log(0.0001) # loss is about 9.2
# Out:
# 9.210340371976182

# %% [markdown]
# #### Update the weights
#
# To update your weight vector $\theta$, you will apply gradient descent to iteratively improve your model's predictions.
# The gradient of the cost function $J$ with respect to one of the weights $\theta_j$ is:
#
# $$\nabla_{\theta_j}J(\theta) = \frac{1}{m} \sum_{i=1}^m(h^{(i)}-y^{(i)})x^{(i)}_j \tag{5}$$
# * 'i' is the index across all 'm' training examples.
# * 'j' is the index of the weight $\theta_j$, so $x^{(i)}_j$ is the feature associated with weight $\theta_j$
#
# * To update the weight $\theta_j$, we adjust it by subtracting a fraction of the gradient determined by $\alpha$:
# $$\theta_j = \theta_j - \alpha \times \nabla_{\theta_j}J(\theta) $$
# * The learning rate $\alpha$ is a value that we choose to control how big a single update will be.

# %% [markdown]
# <a name='ex-2'></a>
# ### Exercise 2 - gradientDescent
# Implement gradient descent function.
# * The number of iterations 'num_iters" is the number of times that you'll use the entire training set.
# * For each iteration, you'll calculate the cost function using all training examples (there are 'm' training examples), and for all features.
# * Instead of updating a single weight $\theta_i$ at a time, we can update all the weights in the column vector:
# $$\mathbf{\theta} = \begin{pmatrix}
# \theta_0
# \\
# \theta_1
# \\
# \theta_2
# \\
# \vdots
# \\
# \theta_n
# \end{pmatrix}$$
# * $\mathbf{\theta}$ has dimensions (n+1, 1), where 'n' is the number of features, and there is one more element for the bias term $\theta_0$ (note that the corresponding feature value $\mathbf{x_0}$ is 1).
# * The 'logits', 'z', are calculated by multiplying the feature matrix 'x' with the weight vector 'theta'.  $z = \mathbf{x}\mathbf{\theta}$
#     * $\mathbf{x}$ has dimensions (m, n+1)
#     * $\mathbf{\theta}$: has dimensions (n+1, 1)
#     * $\mathbf{z}$: has dimensions (m, 1)
# * The prediction 'h', is calculated by applying the sigmoid to each element in 'z': $h(z) = sigmoid(z)$, and has dimensions (m,1).
# * The cost function $J$ is calculated by taking the dot product of the vectors 'y' and 'log(h)'.  Since both 'y' and 'h' are column vectors (m,1), transpose the vector to the left, so that matrix multiplication of a row vector with column vector performs the dot product.
# $$J = \frac{-1}{m} \times \left(\mathbf{y}^T \cdot log(\mathbf{h}) + \mathbf{(1-y)}^T \cdot log(\mathbf{1-h}) \right)$$
# * The update of theta is also vectorized.  Because the dimensions of $\mathbf{x}$ are (m, n+1), and both $\mathbf{h}$ and $\mathbf{y}$ are (m, 1), we need to transpose the $\mathbf{x}$ and place it on the left in order to perform matrix multiplication, which then yields the (n+1, 1) answer we need:
# $$\mathbf{\theta} = \mathbf{\theta} - \frac{\alpha}{m} \times \left( \mathbf{x}^T \cdot \left( \mathbf{h-y} \right) \right)$$

# %%
from tqdm import tqdm

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li>use numpy.dot for matrix multiplication.</li>
#     <li>To ensure that the fraction -1/m is a decimal value, cast either the numerator or denominator (or both), like `float(1)`, or write `1.` for the float version of 1. </li>
# </ul>
# </p>

# %%
# UNQ_C2 GRADED FUNCTION: gradientDescent
def gradientDescent(x, y, theta, alpha, num_iters):
    '''
    Input:
        x: matrix of features which is (m,n+1)
        y: corresponding labels of the input matrix x, dimensions (m,1)
        theta: weight vector of dimension (n+1,1)
        alpha: learning rate
        num_iters: number of iterations you want to train your model for
    Output:
        J: the final cost
        theta: your final weight vector
    Hint: you might want to print the cost to make sure that it is going down.
    '''
    ### START CODE HERE ###
    # get 'm', the number of rows in matrix x
    m = x.shape[0]
    loss=0
    prevloss=7899
    for i in tqdm(range(0, num_iters)):
        
        # get z, the dot product of x and theta
        z = np.dot(x,theta)
        
        # get the sigmoid of z
        h = sigmoid(z)
        
        # calculate the cost function
        J = (np.dot((y.T),np.log(h))+np.dot((1-y).T,np.log(1-h)))*(-1)/m
        loss=np.max(J)
        if prevloss < loss:
            break
        # update the weights theta
        ov=np.dot(x.T,(h-y))
        theta = theta -ov*(alpha/m)
    ### END CODE HERE ###
    return float(loss), theta

# %%
# Check the function
# Construct a synthetic test case using numpy PRNG functions
np.random.seed(1)
# X input is 10 x 3 with ones for the bias terms
tmp_X = np.append(np.ones((10, 1)), np.random.rand(10, 2) * 2000, axis=1)
# Y Labels are 10 x 1
tmp_Y = (np.random.rand(10, 1) > 0.35).astype(float)

# Apply gradient descent
tmp_J, tmp_theta = gradientDescent(tmp_X, tmp_Y, np.zeros((3, 1)), 1e-8, 700)
print(f"The cost after training is {tmp_J:.8f}.")
print(f"The resulting vector of weights is {[round(t, 8) for t in np.squeeze(tmp_theta)]}")
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 700/700 [00:00<00:00, 20791.08it/s]
# The cost after training is 0.67094970.
# The resulting vector of weights is [4.1e-07, 0.00035658, 7.309e-05]

# %% [markdown]
# #### Expected output
# ```
# The cost after training is 0.67094970.
# The resulting vector of weights is [4.1e-07, 0.00035658, 7.309e-05]
# ```

# %% [markdown]
# <a name='2'></a>
# ## 2 - Extracting the Features
#
# * Given a list of tweets, extract the features and store them in a matrix. You will extract two features.
#     * The first feature is the number of positive words in a tweet.
#     * The second feature is the number of negative words in a tweet.
# * Then train your logistic regression classifier on these features.
# * Test the classifier on a validation set.
#
# <a name='ex-3'></a>
# ### Exercise 3 - extract_features
# Implement the extract_features function.
# * This function takes in a single tweet.
# * Process the tweet using the imported `process_tweet` function and save the list of tweet words.
# * Loop through each word in the list of processed words
#     * For each word, check the 'freqs' dictionary for the count when that word has a positive '1' label. (Check for the key (word, 1.0)
#     * Do the same for the count for when the word is associated with the negative label '0'. (Check for the key (word, 0.0).)

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li>Make sure you handle cases when the (word, label) key is not found in the dictionary. </li>
#     <li> Search the web for hints about using the 'get' function of a Python dictionary.  Here is an <a href="https://www.programiz.com/python-programming/methods/dictionary/get" > example </a> </li>
# </ul>
# </p>

# %%
# UNQ_C3 GRADED FUNCTION: extract_features
def extract_features(tweet, freqs, process_tweet=process_tweet):
    '''
    Input: 
        tweet: a list of words for one tweet
        freqs: a dictionary corresponding to the frequencies of each tuple (word, label)
    Output: 
        x: a feature vector of dimension (1,3)
    '''
    # process_tweet tokenizes, stems, and removes stopwords
    word_l = process_tweet(tweet)
    
    # 3 elements in the form of a 1 x 3 vector
    x = np.zeros((1, 3)) 
    
    #bias term is set to 1
    x[0,0] = 1 
    
    ### START CODE HERE ###
    
    # loop through each word in the list of words
    for word in word_l:
        
        # increment the word count for the positive label 1
        x[0,1] += freqs.get((word, 1.0), 0)
        
        # increment the word count for the negative label 0
        x[0,2] += freqs.get((word, 0.0), 0)
        
    ### END CODE HERE ###
    assert(x.shape == (1, 3))
    return x

# %%
# Check your function
# test 1
# test on training data
tmp1 = extract_features(train_x[0], freqs)
print(tmp1)
# Out:
# [[1.000e+00 4.919e+03 3.330e+03]]

# %% [markdown]
# #### Expected output
# ```
# [[1.00e+00 3.02e+03 6.10e+01]]
# ```

# %%
# test 2:
# check for when the words are not in the freqs dictionary
tmp2 = extract_features('blorb bleeeeb bloooob', freqs)
print(tmp2)
# Out:
# [[1. 0. 0.]]

# %% [markdown]
# #### Expected output
# ```
# [[1. 0. 0.]]
# ```

# %% [markdown]
# <a name='3'></a>
# ## 3 - Training Your Model
#
# To train the model:
# * Stack the features for all training examples into a matrix X.
# * Call `gradientDescent`, which you've implemented above.
#
# This section is given to you.  Please read it for understanding and run the cell.

# %%
# collect the features 'x' and stack them into a matrix 'X'
X = np.zeros((len(train_x), 3))
for i in range(len(train_x)):
    X[i, :]= extract_features(train_x[i], freqs)

# training labels corresponding to X
Y = train_y.reshape(3728,1)

# %%
Y.shape
# Out:
# (3728, 1)

# %%
J,theta = gradientDescent(X, Y, np.zeros((3, 1)), 1e-7, 50000)
print(f"The cost after training is {J:.8f}.")
print(f"The resulting vector of weights is {[round(t, 8) for t in np.squeeze(theta)]}")
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 50000/50000 [00:27<00:00, 1827.31it/s]
# The cost after training is 0.64230405.
# The resulting vector of weights is [0.00034177, 0.00182322, -0.00267502]

# %%
J,theta = gradientDescent(X, Y,theta, 1e-7, 50000)
print(f"The cost after training is {J:.8f}.")
print(f"The resulting vector of weights is {[round(t, 8) for t in np.squeeze(theta)]}")
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 50000/50000 [00:26<00:00, 1919.92it/s]
# The cost after training is 0.64228066.
# The resulting vector of weights is [0.00068372, 0.00182319, -0.00267507]

# %% [markdown]
# **Expected Output**:
#
# ```
# The cost after training is 0.22522315.
# The resulting vector of weights is [6e-08, 0.00053818, -0.0005583]
# ```

# %% [markdown]
# <a name='4'></a>
# ## 4 -  Test your Logistic Regression
#
# It is time for you to test your logistic regression function on some new input that your model has not seen before.
# <a name='ex-4'></a>
# ### Exercise 4 - predict_tweet
# Implement `predict_tweet`.
# Predict whether a tweet is positive or negative.
#
# * Given a tweet, process it, then extract the features.
# * Apply the model's learned weights on the features to get the logits.
# * Apply the sigmoid to the logits to get the prediction (a value between 0 and 1).
#
# $$y_{pred} = sigmoid(\mathbf{x} \cdot \theta)$$

# %%
# UNQ_C4 GRADED FUNCTION: predict_tweet
def predict_tweet(tweet, freqs, theta):
    '''
    Input: 
        tweet: a string
        freqs: a dictionary corresponding to the frequencies of each tuple (word, label)
        theta: (3,1) vector of weights
    Output: 
        y_pred: the probability of a tweet being positive or negative
    '''
    ### START CODE HERE ###
    
    # extract the features of the tweet and store it into x
    x = extract_features(tweet, freqs)
    # make the prediction using x and theta
    y_pred = sigmoid(np.dot(x,theta))
    ### END CODE HERE ###
    
    return y_pred

# %%
# Run this cell to test your function
for tweet in ['I am happy']:
    print( '%s -> %f' % (tweet, predict_tweet(tweet, freqs, theta)))
# Out:
# I am happy -> 0.500627

# %% [markdown]
# **Expected Output**:
# ```
# I am happy -> 0.519275
# I am bad -> 0.494347
# this movie should have been great. -> 0.515979
# great -> 0.516065
# great great -> 0.532096
# great great great -> 0.548062
# great great great great -> 0.563929
# ```

# %%
# Feel free to check the sentiment of your own tweet below
my_tweet = 'I am learning :)'
predict_tweet(my_tweet, freqs, theta)
# Out:
# array([[0.49998782]])

# %% [markdown]
# <a name='4-1'></a>
# ### 4.1 -  Check the Performance using the Test Set
# After training your model using the training set above, check how your model might perform on real, unseen data, by testing it against the test set.
#
# <a name='ex-5'></a>
# ### Exercise 5 - test_logistic_regression
# Implement `test_logistic_regression`.
# * Given the test data and the weights of your trained model, calculate the accuracy of your logistic regression model.
# * Use your 'predict_tweet' function to make predictions on each tweet in the test set.
# * If the prediction is > 0.5, set the model's classification 'y_hat' to 1, otherwise set the model's classification 'y_hat' to 0.
# * A prediction is accurate when the y_hat equals the test_y.  Sum up all the instances when they are equal and divide by m.

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li>Use np.asarray() to convert a list to a numpy array</li>
#     <li>Use numpy.squeeze() to make an (m,1) dimensional array into an (m,) array </li>
# </ul>
# </p>

# %%
# UNQ_C5 GRADED FUNCTION: test_logistic_regression
def test_logistic_regression(test_x, test_y, freqs, theta, predict_tweet=predict_tweet):
    """
    Input: 
        test_x: a list of tweets
        test_y: (m, 1) vector with the corresponding labels for the list of tweets
        freqs: a dictionary with the frequency of each pair (or tuple)
        theta: weight vector of dimension (3, 1)
    Output: 
        accuracy: (# of tweets classified correctly) / (total # of tweets)
    """
    
    ### START CODE HERE ###
    
    # the list for storing predictions
    y_hat = []
    
    for tweet in test_x:
        # get the label prediction for the tweet
        y_pred = predict_tweet(tweet, freqs, theta)
        
        if y_pred.all() > 0.5:
            # append 1.0 to the list
            y_hat.append(1.0)
        else:
            # append 0 to the list
            y_hat.append(0.0)

    # With the above implementation, y_hat is a list, but test_y is (m,1) array
    # convert both to one-dimensional arrays in order to compare them using the '==' operator
    m=test_y.shape[0]
            
    accuracy = np.sum(np.squeeze(np.asarray(y_hat)) == np.squeeze(test_y))/m

    ### END CODE HERE ###
    
    return accuracy

# %%
tmp_accuracy = test_logistic_regression(test_x, test_y, freqs, theta)
print(f"Logistic regression model's accuracy = {tmp_accuracy:.4f}")
# Out:
# Logistic regression model's accuracy = 0.6087

# %% [markdown]
# <a name='5'></a>
# ## 5 -  Error Analysis
#
# In this part you will see some tweets that your model misclassified. Why do you think the misclassifications happened? Specifically what kind of tweets does your model misclassify?

# %%
# Some error analysis done for you
print('Label Predicted Tweet')
for x,y in zip(test_x,test_y):
    y_hat = predict_tweet(x, freqs, theta)
    if np.abs(y - (y_hat[0] > 0.5)) > 0:
        print(f'{y} {round(y_hat[0][0],3)} {x}\n {process_tweet(x)}\n')
# Out:
# Label Predicted Tweet
# 1.0 0.444 At least apni na sahi,, apnay poorvajon ki janam bhoomi se itni nafrat tau na karain..Kapoor saheb
#  ['least', 'apni', 'na', 'sahi', 'apnay', 'poorvajon', 'ki', 'janam', 'bhoomi', 'se', 'itni', 'nafrat', 'tau', 'na', 'karain', '..', 'kapoor', 'saheb']
#
# 1.0 0.493 Apne mote se dimagh par zor dalen take pata chale k agar terrorsits yahan hain,tou blasts bhi yahin par kion?Think!
#  ['apne', 'mote', 'se', 'dimagh', 'par', 'zor', 'dalen', 'take', 'pata', 'chale', 'k', 'agar', 'terrorsits', 'yahan', 'hain', 'tou', 'blasts', 'bhi', 'yahin', 'par', 'kion', 'think']
#
# 1.0 0.447 Apni Army ko roti do...
#  ['apni', 'army', 'ko', 'roti', '...']
#
# 1.0 0.409 Use ghar ki safayi karni hogi.. i wish sanya kabhi mere ghar ayi hoti.pkka mera murder kar deti mera room dekh kar PROUD OF FATIMASANASHAIKH
#  ['use', 'ghar', 'ki', 'safayi', 'karni', 'hogi', '..', 'wish', 'sanya', 'kabhi', 'mere', 'ghar', 'ayi', 'hoti.pkka', 'mera', 'murder', 'kar', 'deti', 'mera', 'room', 'dekh', 'kar', 'proud', 'fatimasanashaikh']
#
# 1.0 0.423 India Waly Nafrat ko Badhawa Denay ka Koi Mauka Ni Choorty Un Gov To apni jaga un Fazool Channel waly bhi un ki... http://fb.me/5AilOCJy2
#  ['india', 'waly', 'nafrat', 'ko', 'badhawa', 'denay', 'ka', 'koi', 'mauka', 'ni', 'choorty', 'un', 'gov', 'apni', 'jaga', 'un', 'fazool', 'channel', 'waly', 'bhi', 'un', 'ki', '...']
#
# 1.0 0.431 no...! KHOON and "Cricket" KHEL ek sath ni ho sakti h; baki sari khel ho sakti h sath-sath - @AmitShah
#  ['...', 'khoon', 'cricket', 'khel', 'ek', 'sath', 'ni', 'ho', 'sakti', 'h', 'baki', 'sari', 'khel', 'ho', 'sakti', 'h', 'sath-sath']
#
# 1.0 0.287 Ye to sahe kaha par matter solve karo ki tumhare bestie kyun hate karte he
#  ['ye', 'sahe', 'kaha', 'par', 'matter', 'solve', 'karo', 'ki', 'tumhare', 'bestie', 'kyun', 'hate', 'karte']
#
# 1.0 0.493 Or gurur toh bhartiyo ke khoon me h hai..  Gurur krne waale kaam krte h  .. Tbhi gurur h..
#  ['gurur', 'toh', 'bhartiyo', 'ke', 'khoon', 'h', 'hai', '..', 'gurur', 'krne', 'waale', 'kaam', 'krte', 'h', '..', 'tbhi', 'gurur', 'h', '..']
#
# 1.0 0.48 Bass aa gaya. Aapke jaise ek do aur dost naraaz ho gaye thee. Toh no hate tweet.
#  ['bass', 'aa', 'gaya', 'aapke', 'jaise', 'ek', 'aur', 'dost', 'naraaz', 'ho', 'gaye', 'thee', 'toh', 'hate', 'tweet']
#
# 1.0 0.48 Phir to badiya hai ....Voh Kya hai ki Hindustan ke hain na to sirf pyar aur Ekta samajh Aati hai ... yeh nafrat ki soch se confuse hote hain
#  ['phir', 'badiya', 'hai', '...', 'voh', 'kya', 'hai', 'ki', 'hindustan', 'ke', 'hain', 'na', 'sirf', 'pyar', 'aur', 'ekta', 'samajh', 'aati', 'hai', '...', 'yeh', 'nafrat', 'ki', 'soch', 'se', 'confuse', 'hote', 'hain']
#
# 1.0 0.411 ya allah hitler jesa hukmaran de sdo thatta ko sharm nai roz jamah masjid ki light kharab hoti he or ye log ac room se nikulte tuk nai inko
#  ['ya', 'allah', 'hitler', 'jesa', 'hukmaran', 'de', 'sdo', 'thatta', 'ko', 'sharm', 'nai', 'roz', 'jamah', 'masjid', 'ki', 'light', 'kharab', 'hoti', 'ye', 'log', 'ac', 'room', 'se', 'nikulte', 'tuk', 'nai', 'inko']
#
# 1.0 0.339 Thatha inka alane unara  kastha mega medha hate pakana pettandi...
#  ['thatha', 'inka', 'alane', 'unara', 'kastha', 'mega', 'medha', 'hate', 'pakana', 'pettandi', '...']
#
# 1.0 0.318 Ye Sab chakkar rajnitee k hain ... Dilon mai nafrat ye log he dalte hain dono country k citizens k ...
#  ['ye', 'sab', 'chakkar', 'rajnitee', 'k', 'hain', '...', 'dilon', 'mai', 'nafrat', 'ye', 'log', 'dalte', 'hain', 'dono', 'country', 'k', 'citizens', 'k', '...']
#
# 1.0 0.397 Itna hate laate kahaan se ho?
#  ['itna', 'hate', 'laate', 'kahaan', 'se', 'ho']
#
# 1.0 0.368 Ma vasno Devi ke mandir Jane se sare paap Kat hate h aur man ko saanti multi h JAI MATA DI D.KUMAR.P pic.twitter.com/DhZfxSGq18
#  ['vasno', 'devi', 'ke', 'mandir', 'jane', 'se', 'sare', 'paap', 'kat', 'hate', 'h', 'aur', 'man', 'ko', 'saanti', 'multi', 'h', 'jai', 'mata', 'di', 'd.kumar', 'p', 'pic.twitter.com/dhzfxsgq18']
#
# 1.0 0.498 CONG MAHAN BHEEKH MANGE OF VOTES
#  ['cong', 'mahan', 'bheekh', 'mange', 'votes']
#
# 1.0 0.488 Ap k desh wasiyon k dil to nafrat se bharay hoye hain :) but hope for the best :)
#  ['ap', 'k', 'desh', 'wasiyon', 'k', 'dil', 'nafrat', 'se', 'bharay', 'hoye', 'hain', ':)', 'hope', 'best', ':)']
#
# 1.0 0.469 BJP  se nafrat,Modi se nafrat thik hai.Lekin apni BJP/Modi se nafrat ko desh se nafrat me na hone do.Congress to dube gi ,desh ko dubaoge.
#  ['bjp', 'se', 'nafrat', 'modi', 'se', 'nafrat', 'thik', 'hai.lekin', 'apni', 'bjp', 'modi', 'se', 'nafrat', 'ko', 'desh', 'se', 'nafrat', 'na', 'hone', 'do.congress', 'dube', 'gi', 'desh', 'ko', 'dubaoge']
#
# 1.0 0.497 6yrs me nikah
#  ['6yrs', 'nikah']
#
# 1.0 0.38 I wish beta baap s jeet jaye..is s jyada khushi pita ko kbhi ni milti..  hope pak play well .. I hate one sided match
#  ['wish', 'beta', 'baap', 'jeet', 'jaye', '..', 'jyada', 'khushi', 'pita', 'ko', 'kbhi', 'ni', 'milti', '..', 'hope', 'pak', 'play', 'well', '..', 'hate', 'one', 'sided', 'match']
#
# 1.0 0.255 kuch hote h joh bhai respect nah hate karte h isliye  bolna parta h apse koi against nah h wese acha k tum respect karti ho
#  ['kuch', 'hote', 'h', 'joh', 'bhai', 'respect', 'nah', 'hate', 'karte', 'h', 'isliye', 'bolna', 'parta', 'h', 'apse', 'koi', 'nah', 'h', 'wese', 'acha', 'k', 'tum', 'respect', 'karti', 'ho']
#
# 1.0 0.457 Let's stop isse pehle ki koi hamara khoon kar de
#  ["let's", 'stop', 'isse', 'pehle', 'ki', 'koi', 'hamara', 'khoon', 'kar', 'de']
#
# 1.0 0.407 Murder, is ki saza kya ho.... pic.twitter.com/icqoM54Wgz
#  ['murder', 'ki', 'saza', 'kya', 'ho', '...', 'pic.twitter.com/icqom54wgz']
#
# 1.0 0.435 Mujhe tou hameesha hate hee mila hai
#  ['mujhe', 'tou', 'hameesha', 'hate', 'hee', 'mila', 'hai']
#
# 1.0 0.444 #MyDadAlwaysSays That Kisi Se Nafrat Utni Hi Karo Ke Mohabbat Ki Gunjaish Rahe.
#  ['mydadalwayssays', 'kisi', 'se', 'nafrat', 'utni', 'hi', 'karo', 'ke', 'mohabbat', 'ki', 'gunjaish', 'rahe']
#
# 1.0 0.383 Jo bhi karlo #RishiKapoor kabhi Prime minister nhi banega Na us k bete ko koi film mileg Jitni hate pak se karni ho karlo Run veer kapoora
#  ['jo', 'bhi', 'karlo', 'rishikapoor', 'kabhi', 'prime', 'minister', 'nhi', 'banega', 'na', 'us', 'k', 'bete', 'ko', 'koi', 'film', 'mileg', 'jitni', 'hate', 'pak', 'se', 'karni', 'ho', 'karlo', 'run', 'veer', 'kapoora']
#
# 1.0 0.359 Mohabbat Mein Teri Fitrat Kya Thi Is Kadar Humse Nafrat Kya Thi Teri Chahat Pe Wafa Ki Thi Mene Tujhe Bewafa Hone Ki Zarurat Kya Thi
#  ['mohabbat', 'mein', 'teri', 'fitrat', 'kya', 'thi', 'kadar', 'humse', 'nafrat', 'kya', 'thi', 'teri', 'chahat', 'pe', 'wafa', 'ki', 'thi', 'mene', 'tujhe', 'bewafa', 'hone', 'ki', 'zarurat', 'kya', 'thi']
#
# 1.0 0.41 bhai hate nhi, jab se jindgi me PlayStation aya, tab se sab chhut gaya.
#  ['bhai', 'hate', 'nhi', 'jab', 'se', 'jindgi', 'playstation', 'aya', 'tab', 'se', 'sab', 'chhut', 'gaya']
#
# 1.0 0.494 Malum h nahi to murder karwa dogey bhai sahabuddin chela jail mn band h na... https://twitter.com/yadavtejashwi/status/875719068652785668 …
#  ['malum', 'h', 'nahi', 'murder', 'karwa', 'dogey', 'bhai', 'sahabuddin', 'chela', 'jail', 'mn', 'band', 'h', 'na', '...', '…']
#
# 1.0 0.479 @I_Hafeezian @iamhafeezgirl tw india ne terrorism phelaty hue taraqqi ki hy..wah..
#  ['tw', 'india', 'ne', 'terrorism', 'phelaty', 'hue', 'taraqqi', 'ki', 'hy', '..', 'wah', '..']
#
# 1.0 0.467 ye hamesha denial mode pe rahenge jitna marji aaina dikha do
#  ['ye', 'hamesha', 'denial', 'mode', 'pe', 'rahenge', 'jitna', 'marji', 'aaina', 'dikha']
#
# 1.0 0.481 yadi hum shuru hua na to hamare har tweet par tere aankh or kaan dono se khoon bahne lagega...
#  ['yadi', 'hum', 'shuru', 'hua', 'na', 'hamare', 'har', 'tweet', 'par', 'tere', 'aankh', 'kaan', 'dono', 'se', 'khoon', 'bahne', 'lagega', '...']
#
# 1.0 0.474 baat usse hoti jo shabdo ki bhasha samjhe , abhi to kahte the kashmir ki azadi ke liye , jab poll khul gayi ki ye to terrorism hai , MM bhi
#  ['baat', 'usse', 'hoti', 'jo', 'shabdo', 'ki', 'bhasha', 'samjhe', 'abhi', 'kahte', 'kashmir', 'ki', 'azadi', 'ke', 'liye', 'jab', 'poll', 'khul', 'gayi', 'ki', 'ye', 'terrorism', 'hai', 'mm', 'bhi']
#
# 1.0 0.497 Ind ki population b zyda hai
#  ['ind', 'ki', 'population', 'b', 'zyda', 'hai']
#
# 1.0 0.497 Ind ki poverty b zyada hai
#  ['ind', 'ki', 'poverty', 'b', 'zyada', 'hai']
#
# 1.0 0.459 Inki Ragon mai wahii khoon hai jo Aatankion ki mai hai jab opposition m hoti h to khud b Gun uthaane ki baat krti
#  ['inki', 'ragon', 'mai', 'wahii', 'khoon', 'hai', 'jo', 'aatankion', 'ki', 'mai', 'hai', 'jab', 'opposition', 'hoti', 'h', 'khud', 'b', 'gun', 'uthaane', 'ki', 'baat', 'krti']
#
# 1.0 0.446 Are toh rishi kapoor se badla lo pure India ko thodi represent karta hai wo. Keep an open mind. Hate se milta kuch nhi
#  ['toh', 'rishi', 'kapoor', 'se', 'badla', 'lo', 'pure', 'india', 'ko', 'thodi', 'represent', 'karta', 'hai', 'wo', 'keep', 'open', 'mind', 'hate', 'se', 'milta', 'kuch', 'nhi']
#
# 1.0 0.373 Alarm ki tune laga loo...aik haftay may nafrat hoo jayay gi..
#  ['alarm', 'ki', 'tune', 'laga', 'loo', '...', 'aik', 'haftay', 'may', 'nafrat', 'hoo', 'jayay', 'gi', '..']
#
# 1.0 0.477 Raveesh ji u r right
#  ['raveesh', 'ji', 'u', 'r', 'right']
#
# 1.0 0.292 Jo sochega logic ke sath ki usko hate krta hu... means yes I do
#  ['jo', 'sochega', 'logic', 'ke', 'sath', 'ki', 'usko', 'hate', 'krta', 'hu', '...', 'means', 'yes']
#
# 1.0 0.372 Yes,aur jo hate use mili wo usne khud hi bulaayi thi bayaan de kar..
#  ['yes', 'aur', 'jo', 'hate', 'use', 'mili', 'wo', 'usne', 'khud', 'hi', 'bulaayi', 'thi', 'bayaan', 'de', 'kar', '..']
#
# 1.0 0.442 Sab se jayda nafrat mujhe us bell se h  abhi se chipak rahi thi man hua uska murder kar do
#  ['sab', 'se', 'jayda', 'nafrat', 'mujhe', 'us', 'bell', 'se', 'h', 'abhi', 'se', 'chipak', 'rahi', 'thi', 'man', 'hua', 'uska', 'murder', 'kar']
#
# 1.0 0.473 Arye waha kuttey k sath shadi karne wale aisi batein karte hain Or medical ki student k sath 13  logon ne Rape kiya tumery india main woh
#  ['arye', 'waha', 'kuttey', 'k', 'sath', 'shadi', 'karne', 'wale', 'aisi', 'batein', 'karte', 'hain', 'medical', 'ki', 'student', 'k', 'sath', '13', 'logon', 'ne', 'rape', 'kiya', 'tumery', 'india', 'main', 'woh']
#
# 1.0 0.466 Tujhe kya pata ki mere dil mein
#  ['tujhe', 'kya', 'pata', 'ki', 'mere', 'dil', 'mein']
#
# 1.0 0.496 And And and.Kashmir Main Tumhari Kutti Army jO Kashmiriyo K Sth
#  ['and.kashmir', 'main', 'tumhari', 'kutti', 'army', 'jo', 'kashmiriyo', 'k', 'sth']
#
# 1.0 0.316 Azaadi k bad bhi kuch esa kro pak...hate felane se to abdus salam nhi bnte !!!
#  ['azaadi', 'k', 'bad', 'bhi', 'kuch', 'esa', 'kro', 'pak', '...', 'hate', 'felane', 'se', 'abdus', 'salam', 'nhi', 'bnte']
#
# 1.0 0.322 love with dogs and hate with cow...political animal lover..ye wahi log h jo subah kutte ki rassi pakad ke cow ka milk dhundhne jate hai
#  ['love', 'dogs', 'hate', 'cow', '...', 'political', 'animal', 'lover', '..', 'ye', 'wahi', 'log', 'h', 'jo', 'subah', 'kutte', 'ki', 'rassi', 'pakad', 'ke', 'cow', 'ka', 'milk', 'dhundhne', 'jate', 'hai']
#
# 1.0 0.29 Ranbir ko hate mat kar... Baaki sabko kar...
#  ['ranbir', 'ko', 'hate', 'mat', 'kar', '...', 'baaki', 'sabko', 'kar', '...']
#
# 1.0 0.495 Tum Na he miltae tou accha tha jahaan,
#  ['tum', 'na', 'miltae', 'tou', 'accha', 'tha', 'jahaan']
#
# 1.0 0.397 hate zyada ya pyar jyada :@
#  ['hate', 'zyada', 'ya', 'pyar', 'jyada', ':@']
#
# 1.0 0.411 Roye nhi SRKians raees ki reports bhi acchi hi hongi.zaroor.both will work dekhna.hmlog hatred faila rhe h.
#  ['roye', 'nhi', 'srkians', 'raees', 'ki', 'reports', 'bhi', 'acchi', 'hi', 'hongi.zaroor.both', 'work', 'dekhna.hmlog', 'hatred', 'faila', 'rhe', 'h']
#
# 1.0 0.467 tumhari Cong hoti tou Italy k rishtedar ammer ho hate yahan sage Bhai bhi nahi corruption kahan
#  ['tumhari', 'cong', 'hoti', 'tou', 'italy', 'k', 'rishtedar', 'ammer', 'ho', 'hate', 'yahan', 'sage', 'bhai', 'bhi', 'nahi', 'corruption', 'kahan']
#
# 1.0 0.419 ...mona ko.ghar se nikaalo wo bahut boring hai kuch karti nhi bs jb dekho camera ke aage roti rahti hai i hate u
#  ['...', 'mona', 'ko.ghar', 'se', 'nikaalo', 'wo', 'bahut', 'boring', 'hai', 'kuch', 'karti', 'nhi', 'bs', 'jb', 'dekho', 'camera', 'ke', 'aage', 'roti', 'rahti', 'hai', 'hate', 'u']
#
# 1.0 0.404 you're love. Kaun gadha hate karta tujhe
#  ['love', 'kaun', 'gadha', 'hate', 'karta', 'tujhe']
#
# 1.0 0.408 Shukar h parindo'n ko nhi pata ki unka mazhab aur sarhade'in kyaa h.
#  ['shukar', 'h', "parindo'n", 'ko', 'nhi', 'pata', 'ki', 'unka', 'mazhab', 'aur', "sarhade'in", 'kyaa', 'h']
#
# 1.0 0.379 #ShameOnSRKHaters jis srk ko pura world pyar karta use koi hate karke kya kar lenga srk world main india ki pride hai i am srk biggest fan
#  ['shameonsrkhaters', 'jis', 'srk', 'ko', 'pura', 'world', 'pyar', 'karta', 'use', 'koi', 'hate', 'karke', 'kya', 'kar', 'lenga', 'srk', 'world', 'main', 'india', 'ki', 'pride', 'hai', 'srk', 'biggest', 'fan']
#
# 1.0 0.45 Har chehare se naakab hate taalak ka ho system band.
#  ['har', 'chehare', 'se', 'naakab', 'hate', 'taalak', 'ka', 'ho', 'system', 'band']
#
# 1.0 0.456 Wifaq-ul-Madaris Pakistan K Saddar Aur Sheikhul Hadees Molana Saleemullah Khan Inteqal Kar Gaye, Patel Hospital Me Zer-e-Elaaj...
#  ['wifaq-ul-madaris', 'pakistan', 'k', 'saddar', 'aur', 'sheikhul', 'hadees', 'molana', 'saleemullah', 'khan', 'inteqal', 'kar', 'gaye', 'patel', 'hospital', 'zer-e-elaaj', '...']
#
# 1.0 0.491 haha.. naku  rohit midha Hatred ravadaniki cide karanam,,
#  ['haha', '..', 'naku', 'rohit', 'midha', 'hatred', 'ravadaniki', 'cide', 'karanam']
#
# 1.0 0.496 Molvi Shb T.v Per Fashion Show Dekh Rhy Thy
#  ['molvi', 'shb', 'v', 'per', 'fashion', 'show', 'dekh', 'rhy', 'thy']
#
# 1.0 0.386 itna hate kyu karte ho mujhe?
#  ['itna', 'hate', 'kyu', 'karte', 'ho', 'mujhe']
#
# 1.0 0.441 @RDahait Hai Dil Ye Mera Video Song _ Arijit Singh _ Hate Story 2 _ Jay Bhanushali, pic.twitter.com/zBRfm8oiue
#  ['hai', 'dil', 'ye', 'mera', 'video', 'song', 'arijit', 'singh', 'hate', 'story', '2', 'jay', 'bhanushali', 'pic.twitter.com/zbrfm8oiue']
#
# 1.0 0.47 AamirKhan ki movie Dekhne sab jaate hai Kyun ki Aamirians Sabse Dhumshani nahi karte aur naahi Aamir ke liye haters aur hate nahi badhaate
#  ['aamirkhan', 'ki', 'movie', 'dekhne', 'sab', 'jaate', 'hai', 'kyun', 'ki', 'aamirians', 'sabse', 'dhumshani', 'nahi', 'karte', 'aur', 'naahi', 'aamir', 'ke', 'liye', 'haters', 'aur', 'hate', 'nahi', 'badhaate']
#
# 1.0 0.431 Aap ko koi hate nahi karta manveer ji... https://twitter.com/ManveerFTW/status/820520525592227841 …
#  ['aap', 'ko', 'koi', 'hate', 'nahi', 'karta', 'manveer', 'ji', '...', '…']
#
# 1.0 0.489 Bahut hi weird jiju hai mere...haan :P
#  ['bahut', 'hi', 'weird', 'jiju', 'hai', 'mere', '...', 'haan', ':P']
#
# 1.0 0.428 koi chocolate kese hate kr skta hai..??
#  ['koi', 'chocolate', 'kese', 'hate', 'kr', 'skta', 'hai', '..']
#
# 1.0 0.489 So tune chocolate khana tyaag diya??
#  ['tune', 'chocolate', 'khana', 'tyaag', 'diya']
#
# 1.0 0.49 Is ko sar-e-aam phansi do. Phir lag pata jai ga.. Is ki hero giri sab nikal jai gi. or jo aise hero banna chahte hai un ki bhi. https://twitter.com/shabir_kamran/status/820604581331763200 …
#  ['ko', 'sar-e-aam', 'phansi', 'phir', 'lag', 'pata', 'jai', 'ga', '..', 'ki', 'hero', 'giri', 'sab', 'nikal', 'jai', 'gi', 'jo', 'aise', 'hero', 'banna', 'chahte', 'hai', 'un', 'ki', 'bhi', '…']
#
# 1.0 0.47 Yaar kuch mil jaata hai tweet karnay ko. Please don't hate.
#  ['yaar', 'kuch', 'mil', 'jaata', 'hai', 'tweet', 'karnay', 'ko', 'please', 'hate']
#
# 1.0 0.393 wai sadenli yu hate mi ameera
#  ['wai', 'sadenli', 'yu', 'hate', 'mi', 'ameera']
#
# 1.0 0.153 kah kah kah kah, haters gonna hate hate hate hate
#  ['kah', 'kah', 'kah', 'kah', 'haters', 'gonna', 'hate', 'hate', 'hate', 'hate']
#
# 1.0 0.393 Omg Aaj thoda jyada senti ho rahi Hun.. I hate you @filmfare
#  ['omg', 'aaj', 'thoda', 'jyada', 'senti', 'ho', 'rahi', 'hun', '..', 'hate']
#
# 1.0 0.439 tiris ka hate pic.twitter.com/jtWEQbprgW
#  ['tiris', 'ka', 'hate', 'pic.twitter.com/jtweqbprgw']
#
# 1.0 0.479 ab rohan ko hate karnai wale ko ab jelous hoo raha hai and  Ab muh band hoogaya
#  ['ab', 'rohan', 'ko', 'hate', 'karnai', 'wale', 'ko', 'ab', 'jelous', 'hoo', 'raha', 'hai', 'ab', 'muh', 'band', 'hoogaya']
#
# 1.0 0.35 Ajukan hate speech... https://twitter.com/BoengParno/status/820159942397083650 …
#  ['ajukan', 'hate', 'speech', '...', '…']
#
# 1.0 0.392 huddai — feeling jokhn mobile hate thake
#  ['huddai', '—', 'feeling', 'jokhn', 'mobile', 'hate', 'thake']
#
# 1.0 0.432 salman toh always lopa ki side leta hai hate him lopa ne om priyanka n bani ke sath kush kamm nahi kiya
#  ['salman', 'toh', 'always', 'lopa', 'ki', 'side', 'leta', 'hai', 'hate', 'lopa', 'ne', 'om', 'priyanka', 'n', 'bani', 'ke', 'sath', 'kush', 'kamm', 'nahi', 'kiya']
#
# 1.0 0.398 [2014 Archives] Amit Shah's Hate Speech in Shamli, Western Uttar Pradesh.
#  ['2014', 'archives', 'amit', "shah's", 'hate', 'speech', 'shamli', 'western', 'uttar', 'pradesh']
#
# 1.0 0.398 abe unke hate se problem hai mujhe..
#  ['abe', 'unke', 'hate', 'se', 'problem', 'hai', 'mujhe', '..']
#
# 1.0 0.377 Acha bhai ye to batao . Hindus ki kya galti hai isme.  ? Aur itni hate hindus se ?
#  ['acha', 'bhai', 'ye', 'batao', 'hindus', 'ki', 'kya', 'galti', 'hai', 'isme', 'aur', 'itni', 'hate', 'hindus', 'se']
#
# 1.0 0.38 Isiliye baat baat par gali dene par as hate ho,
#  ['isiliye', 'baat', 'baat', 'par', 'gali', 'dene', 'par', 'hate', 'ho']
#
# 1.0 0.394 Yahan log ek galti k badle sari wafaien bhol hate gain
#  ['yahan', 'log', 'ek', 'galti', 'k', 'badle', 'sari', 'wafaien', 'bhol', 'hate', 'gain']
#
# 1.0 0.381 @WFNhindi ye to mentally sick log hai agar Gandhi Ji hate to ye log desh se hatenge Sanki hai sare ye
#  ['ye', 'mentally', 'sick', 'log', 'hai', 'agar', 'gandhi', 'ji', 'hate', 'ye', 'log', 'desh', 'se', 'hatenge', 'sanki', 'hai', 'sare', 'ye']
#
# 1.0 0.401 jai hate LANE2
#  ['jai', 'hate', 'lane', '2']
#
# 1.0 0.477 Hate toh sab se milta rahta hai yaar! https://twitter.com/lovefrvrfangirl/status/818819954015289346 …
#  ['hate', 'toh', 'sab', 'se', 'milta', 'rahta', 'hai', 'yaar', '…']
#
# 1.0 0.49 @VishalDadlani Waqt change ho gaya h..Ab asli Desh bhakt Modi g h... Kya Modi g ne 2 Girls ko apne pass Letaya or rape kiya..
#  ['waqt', 'change', 'ho', 'gaya', 'h', '..', 'ab', 'asli', 'desh', 'bhakt', 'modi', 'g', 'h', '...', 'kya', 'modi', 'g', 'ne', '2', 'girls', 'ko', 'apne', 'pass', 'letaya', 'rape', 'kiya', '..']
#
# 1.0 0.401 #Persian #Literature Har aan: I hate hamrahe aval  http://melinadesigns.deviantart.com/art/Har-aan-657208809?utm_source=dlvr.it&utm_medium=twitter … #Iran #ادبیات
#  ['persian', 'literature', 'har', 'aan', 'hate', 'hamrahe', 'aval', '…', 'iran', 'ادبیات']
#
# 1.0 0.351 apni hee sabha ki tasveer dil hate ho
#  ['apni', 'hee', 'sabha', 'ki', 'tasveer', 'dil', 'hate', 'ho']
#
# 1.0 0.466 Ji jangal ka kanoon to ap ne samaj liya hy, molvi hate Us k khliaf uchalty phirty ho 1/2
#  ['ji', 'jangal', 'ka', 'kanoon', 'ap', 'ne', 'samaj', 'liya', 'hy', 'molvi', 'hate', 'us', 'k', 'khliaf', 'uchalty', 'phirty', 'ho', '1/2']
#
# 1.0 0.344 Bhai tumhari side hi hain hum log....We hate gauhar and bani
#  ['bhai', 'tumhari', 'side', 'hi', 'hain', 'hum', 'log', '...', 'hate', 'gauhar', 'bani']
#
# 1.0 0.434 kya hate dekha nahi kya rohan was saying both were wrong usne lopa ko apne tarike se samjhaya fir bani ko bola
#  ['kya', 'hate', 'dekha', 'nahi', 'kya', 'rohan', 'saying', 'wrong', 'usne', 'lopa', 'ko', 'apne', 'tarike', 'se', 'samjhaya', 'fir', 'bani', 'ko', 'bola']
#
# 1.0 0.392 me kitnay bhi khi waalo se mila hu they hate AH and Farooq sattar etc
#  ['kitnay', 'bhi', 'khi', 'waalo', 'se', 'mila', 'hu', 'hate', 'ah', 'farooq', 'sattar', 'etc']
#
# 1.0 0.384 B A N G A L I R - P I T H E - P O R O B MAA, DIDA Ar Hate Toiri Pithe Ke Kota Khale???
#  ['b', 'n', 'g', 'l', 'r', 'p', 'h', 'e', 'p', 'r', 'b', 'maa', 'dida', 'ar', 'hate', 'toiri', 'pithe', 'ke', 'kota', 'khale']
#
# 1.0 0.375 jaab do log ek dusre se pyaar karte fer mutual separation kaise ho sakte. Only hate can do that n vohi huya
#  ['jaab', 'log', 'ek', 'dusre', 'se', 'pyaar', 'karte', 'fer', 'mutual', 'separation', 'kaise', 'ho', 'sakte', 'hate', 'n', 'vohi', 'huya']
#
# 1.0 0.298 yaarume naa hate panna maten na.suriya ku apram my fav thalapathy thaan.naa hate panra oore aalu kohli
#  ['yaarume', 'naa', 'hate', 'panna', 'maten', 'na.suriya', 'ku', 'apram', 'fav', 'thalapathy', 'thaan.naa', 'hate', 'panra', 'oore', 'aalu', 'kohli']
#
# 1.0 0.444 nothing kaise koi SRK ko hate kar sakta hai??
#  ['nothing', 'kaise', 'koi', 'srk', 'ko', 'hate', 'kar', 'sakta', 'hai']
#
# 1.0 0.433 I've no problem with haters but hate se zyada apne idol ko pyaar bhi kar liya Karo Toh accha rahega na
#  ["i've", 'problem', 'haters', 'hate', 'se', 'zyada', 'apne', 'idol', 'ko', 'pyaar', 'bhi', 'kar', 'liya', 'karo', 'toh', 'accha', 'rahega', 'na']
#
# 1.0 0.358 Ab khush.. mujhe lga you hate sachin  Isliye sab hta diya..
#  ['ab', 'khush', '..', 'mujhe', 'lga', 'hate', 'sachin', 'isliye', 'sab', 'hta', 'diya', '..']
#
# 1.0 0.32 tum kaisi aurat ho...SRK ko hate karti ho?? Shame on u..
#  ['tum', 'kaisi', 'aurat', 'ho', '...', 'srk', 'ko', 'hate', 'karti', 'ho', 'shame', 'u', '..']
#
# 1.0 0.308 jagga, tera hate karna banta hai. Tujhe toh sara india hate karta hai....shame on u
#  ['jagga', 'tera', 'hate', 'karna', 'banta', 'hai', 'tujhe', 'toh', 'sara', 'india', 'hate', 'karta', 'hai', '...', 'shame', 'u']
#
# 1.0 0.454 Kaun #filmfare ko yun hate karega jaise hum karte hai
#  ['kaun', 'filmfare', 'ko', 'yun', 'hate', 'karega', 'jaise', 'hum', 'karte', 'hai']
#
# 1.0 0.408 ini hate speech nih pak @DivHumasPolrihttps://twitter.com/corleonuno/status/819910608984256513 …
#  ['ini', 'hate', 'speech', 'nih', 'pak', '…']
#
# 1.0 0.46 @anjanaomkashyap bapu pehle bhi hate they cong ki sarkar me aur ab sirf hathe nahi modi ne bapu ke paze per kabja kar lia
#  ['bapu', 'pehle', 'bhi', 'hate', 'cong', 'ki', 'sarkar', 'aur', 'ab', 'sirf', 'hathe', 'nahi', 'modi', 'ne', 'bapu', 'ke', 'paze', 'per', 'kabja', 'kar', 'lia']
#
# 1.0 0.337 Itna hate leke kahan jayga...
#  ['itna', 'hate', 'leke', 'kahan', 'jayga', '...']
#
# 1.0 0.435 words for lopa shakal bhi gandi dil bhi ganda sab kuch ganda hate her
#  ['words', 'lopa', 'shakal', 'bhi', 'gandi', 'dil', 'bhi', 'ganda', 'sab', 'kuch', 'ganda', 'hate']
#
# 1.0 0.369 Kaash tm meri hoti ! Bht khush rkhta ! Har nakhra uthata ! But u hate me — Ab ap kon?  http://l.ask.fm/igoto/45DKECN75V62DDAUPY6IQO6C6KDTZAA3R3567WXIJCS2J7FI2AT5AJKQFZEMCSR3KO3PQEAJIZWTKFAU34N7A55YPPSKNTBAUYOADFKYCASCGMX5GWID6KPLQSVKBSDZSKQY2H2QZTGX7K4GJSNBWTLK67BSL4ET2LHV77K3QK236UUDLFOUVQHX5FR2P3XGTIUKEOQF7U====== …
#  ['kaash', 'tm', 'meri', 'hoti', 'bht', 'khush', 'rkhta', 'har', 'nakhra', 'uthata', 'u', 'hate', '—', 'ab', 'ap', 'kon', '…']
#
# 1.0 0.396 @annieluvannie4 why you hate your life ... zindagi eik haseen tofa hai zindagi ki qadar karo kyun k ye eik baar he milti hai dubara nahi
#  ['hate', 'life', '...', 'zindagi', 'eik', 'haseen', 'tofa', 'hai', 'zindagi', 'ki', 'qadar', 'karo', 'kyun', 'k', 'ye', 'eik', 'baar', 'milti', 'hai', 'dubara', 'nahi']
#
# 1.0 0.408 ko hafeez sawed ki news mil hate hai
#  ['ko', 'hafeez', 'sawed', 'ki', 'news', 'mil', 'hate', 'hai']
#
# 1.0 0.396 Wajah Tum Ho - Hate Story 3
#  ['wajah', 'tum', 'ho', 'hate', 'story', '3']
#
# 1.0 0.396 Qalam o Kalaam hi k zarye bandooq utai jati hay. It's called hate speech. https://twitter.com/_Kintsukuroi_/status/819635429993496577 …
#  ['qalam', 'kalaam', 'hi', 'k', 'zarye', 'bandooq', 'utai', 'jati', 'hay', 'called', 'hate', 'speech', '…']
#
# 1.0 0.393 hahahah edhe mu edhe kamt, amo durt kush tmi prek ma bojn kuku akull edhe mthojn shpesh qashtu and i hate that haha
#  ['hahahah', 'edhe', 'mu', 'edhe', 'kamt', 'amo', 'durt', 'kush', 'tmi', 'prek', 'bojn', 'kuku', 'akull', 'edhe', 'mthojn', 'shpesh', 'qashtu', 'hate', 'haha']
#
# 1.0 0.425 @AmaalMallik aapko koi kaise hate kar sakta hai
#  ['aapko', 'koi', 'kaise', 'hate', 'kar', 'sakta', 'hai']
#
# 1.0 0.376 Adhan bro edhuvume muzhusa theriyama chumma hate panradhu..
#  ['adhan', 'bro', 'edhuvume', 'muzhusa', 'theriyama', 'chumma', 'hate', 'panradhu', '..']
#
# 1.0 0.358 Bani was bang on 'Jitna apne mujhe hate kitna uuse do guna teen guna India ne mujhe pyaar dia' We are here for you.. I Stand By Bani
#  ['bani', 'bang', 'jitna', 'apne', 'mujhe', 'hate', 'kitna', 'uuse', 'guna', 'teen', 'guna', 'india', 'ne', 'mujhe', 'pyaar', 'dia', '..', 'stand', 'bani']
#
# 1.0 0.44 bhai tu hain kon use hate karne wala
#  ['bhai', 'tu', 'hain', 'kon', 'use', 'hate', 'karne', 'wala']
#
# 1.0 0.464 fawad ko koi kesay hate kr skta hai?
#  ['fawad', 'ko', 'koi', 'kesay', 'hate', 'kr', 'skta', 'hai']
#
# 1.0 0.408 tujhe nahi padhna.. andhaa bane rehna hai toh na padh.. even if u hate u must read the opposite side.
#  ['tujhe', 'nahi', 'padhna', '..', 'andhaa', 'bane', 'rehna', 'hai', 'toh', 'na', 'padh', '..', 'even', 'u', 'hate', 'u', 'must', 'read', 'opposite', 'side']
#
# 1.0 0.343 @eranuragpandey pataa he bahut akkians mujhse hate karte h
#  ['pataa', 'bahut', 'akkians', 'mujhse', 'hate', 'karte', 'h']
#
# 1.0 0.335 kisi ki maa ke bare mein agar bar bar kuch bola hate toh ap shant rahoge...
#  ['kisi', 'ki', 'maa', 'ke', 'bare', 'mein', 'agar', 'bar', 'bar', 'kuch', 'bola', 'hate', 'toh', 'ap', 'shant', 'rahoge', '...']
#
# 1.0 0.446 https://twitter.com/ArvindKejriwal/status/819491235484139521Jab … ye paglapanti ki baat karta hai samajlo iska koi na koi neta kanoon ke hate aane wala hai
#  ['…', 'ye', 'paglapanti', 'ki', 'baat', 'karta', 'hai', 'samajlo', 'iska', 'koi', 'na', 'koi', 'neta', 'kanoon', 'ke', 'hate', 'aane', 'wala', 'hai']
#
# 1.0 0.297 *Gasp* Hate speech Garon, Hate speech!
#  ['gasp', 'hate', 'speech', 'garon', 'hate', 'speech']
#
# 1.0 0.432 Itna bhi ro ko hate mat karo yaar
#  ['itna', 'bhi', 'ro', 'ko', 'hate', 'mat', 'karo', 'yaar']
#
# 1.0 0.42 sab hame itna hate kyu karte hain,hum toh pyar k bhuke hain
#  ['sab', 'hame', 'itna', 'hate', 'kyu', 'karte', 'hain', 'hum', 'toh', 'pyar', 'k', 'bhuke', 'hain']
#
# 1.0 0.333 @JantaKaReporter Bhai Saab aapki logone vote diya hei sarkar chalane... Modi hate monger club chalane ki liye nahi.
#  ['bhai', 'saab', 'aapki', 'logone', 'vote', 'diya', 'hei', 'sarkar', 'chalane', '...', 'modi', 'hate', 'monger', 'club', 'chalane', 'ki', 'liye', 'nahi']
#
# 1.0 0.35 mai ye vahiyat foto share bas isliye kar rahi hu...ki ladko ko samaj me aye ki videsho mai ladkiyo ko kitni azadi h...waha rape bi nai hote. pic.twitter.com/kU4E4VdvTk
#  ['mai', 'ye', 'vahiyat', 'foto', 'share', 'bas', 'isliye', 'kar', 'rahi', 'hu', '...', 'ki', 'ladko', 'ko', 'samaj', 'aye', 'ki', 'videsho', 'mai', 'ladkiyo', 'ko', 'kitni', 'azadi', 'h', '...', 'waha', 'rape', 'bi', 'nai', 'hote', 'pic.twitter.com/ku4e4vdvtk']
#
# 1.0 0.487 @_poojalove Aap aise kyu bolti ho koi aapse hate nahi krta bs Arjun Maya se Thoda jyada pyar karte hai
#  ['aap', 'aise', 'kyu', 'bolti', 'ho', 'koi', 'aapse', 'hate', 'nahi', 'krta', 'bs', 'arjun', 'maya', 'se', 'thoda', 'jyada', 'pyar', 'karte', 'hai']
#
# 1.0 0.41 Wah hate speech ini namanya. https://twitter.com/Babeh_Helmi/status/819229271507861504 …
#  ['wah', 'hate', 'speech', 'ini', 'namanya', '…']
#
# 1.0 0.375 tum kyun hate karte ho usko?
#  ['tum', 'kyun', 'hate', 'karte', 'ho', 'usko']
#
# 1.0 0.279 defend unko karte h jinhone kuch kiya ho  ik ik lopa fans hate bani as if inke ghar se ptanhi kitna chura kar gyi h
#  ['defend', 'unko', 'karte', 'h', 'jinhone', 'kuch', 'kiya', 'ho', 'ik', 'ik', 'lopa', 'fans', 'hate', 'bani', 'inke', 'ghar', 'se', 'ptanhi', 'kitna', 'chura', 'kar', 'gyi', 'h']
#
# 1.0 0.43 ye to kuch bhi nhi. Inki arrested mp tapas pal to opposition ki women ki rape karne ki dhamki bhi dete he
#  ['ye', 'kuch', 'bhi', 'nhi', 'inki', 'arrested', 'mp', 'tapas', 'pal', 'opposition', 'ki', 'women', 'ki', 'rape', 'karne', 'ki', 'dhamki', 'bhi', 'dete']
#
# 1.0 0.429 Aaj twitter par kuch zyada hi hate tweets hai.
#  ['aaj', 'twitter', 'par', 'kuch', 'zyada', 'hi', 'hate', 'tweets', 'hai']
#
# 1.0 0.422 Aisi hi koi baat hinduism ke baray men kare tb wo hate k bajaye aqal ki speech kyun ban jati hai? Islam doesn't need this.
#  ['aisi', 'hi', 'koi', 'baat', 'hinduism', 'ke', 'baray', 'men', 'kare', 'tb', 'wo', 'hate', 'k', 'bajaye', 'aqal', 'ki', 'speech', 'kyun', 'ban', 'jati', 'hai', 'islam', 'need']
#
# 1.0 0.32 Naahi Aata naahi karnaar RT ,Malaa vaatal ti fakt Deepika la hate karte....
#  ['naahi', 'aata', 'naahi', 'karnaar', 'rt', 'malaa', 'vaatal', 'ti', 'fakt', 'deepika', 'la', 'hate', 'karte', '...']
#
# 1.0 0.389 acha fake dp laga ke modigiri kar rai he  i hate modi bhakt ... duniya ke sabse bevkuf log hote he andhbhakt
#  ['acha', 'fake', 'dp', 'laga', 'ke', 'modigiri', 'kar', 'rai', 'hate', 'modi', 'bhakt', '...', 'duniya', 'ke', 'sabse', 'bevkuf', 'log', 'hote', 'andhbhakt']
#
# 1.0 0.265 pagal person..solder ko bolte hai ki jate q ho militory...marne ke liye....i hate this my....better huaa jo bhi huaa
#  ['pagal', 'person', '..', 'solder', 'ko', 'bolte', 'hai', 'ki', 'jate', 'q', 'ho', 'militory', '...', 'marne', 'ke', 'liye', '...', 'hate', '...', 'better', 'huaa', 'jo', 'bhi', 'huaa']
#
# 1.0 0.415 Agar waqai yeh log hate speech karty thy to phat tu in ko publicly hanged nazar chie hy #RecoverAllActivists
#  ['agar', 'waqai', 'yeh', 'log', 'hate', 'speech', 'karty', 'thy', 'phat', 'tu', 'ko', 'publicly', 'hanged', 'nazar', 'chie', 'hy', 'recoverallactivists']
#
# 1.0 0.394 kuna hate speech yurushwa ati ni walughya sana sana waupatanishwa
#  ['kuna', 'hate', 'speech', 'yurushwa', 'ati', 'ni', 'walughya', 'sana', 'sana', 'waupatanishwa']
#
# 1.0 0.451 really !! Kuch bacha hai mazaak udaane ko ya hate k liye ? *Smh* @PolyesterPalla
#  ['really', 'kuch', 'bacha', 'hai', 'mazaak', 'udaane', 'ko', 'ya', 'hate', 'k', 'liye', 'smh']
#
# 1.0 0.298 kina raakhyaa? Hate brigade le raastra baadi bhanera hate failaaulaa
#  ['kina', 'raakhyaa', 'hate', 'brigade', 'le', 'raastra', 'baadi', 'bhanera', 'hate', 'failaaulaa']
#
# 1.0 0.397 Mawlana Farid Uddin Al Mobarak - Jubokrai Islamer Jhanda Hate Egiye Ashbe (Bengali): http://youtu.be/f3e1eoA9WRM?a  via @YouTube
#  ['mawlana', 'farid', 'uddin', 'al', 'mobarak', 'jubokrai', 'islamer', 'jhanda', 'hate', 'egiye', 'ashbe', 'bengali', '):', 'via']
#
# 1.0 0.322 Hate ki baat ho rahi h na?
#  ['hate', 'ki', 'baat', 'ho', 'rahi', 'h', 'na']
#
# 1.0 0.425 @Gurmeetramrahim @insan_honey #MSGwithYouth @derasachasauda mein bahut lok nasha shod kr hate haii
#  ['msgwithyouth', 'mein', 'bahut', 'lok', 'nasha', 'shod', 'kr', 'hate', 'haii']
#
# 1.0 0.376 usee hate karnese kya hoga..
#  ['usee', 'hate', 'karnese', 'kya', 'hoga', '..']
#
# 1.0 0.378 koi baat ni , glad for manveer but hate manu!inko votes ki zyada zarurt hai wese b! lOL
#  ['koi', 'baat', 'ni', 'glad', 'manveer', 'hate', 'manu', 'inko', 'votes', 'ki', 'zyada', 'zarurt', 'hai', 'wese', 'b', 'lol']
#
# 1.0 0.403 Haters gonna hate assi dil bich #Raftaar
#  ['haters', 'gonna', 'hate', 'assi', 'dil', 'bich', 'raftaar']
#
# 1.0 0.451 @aa_aashim Sab kitna hate karte hai meri niti ko it makes me sad pic.twitter.com/30iLEMpjLF
#  ['sab', 'kitna', 'hate', 'karte', 'hai', 'meri', 'niti', 'ko', 'makes', 'sad', 'pic.twitter.com/30ilempjlf']
#
# 1.0 0.415 twitter mai dhoni dhoni chillata nahi iska meaning yeh nahi ki I hate him .. Nikal aab
#  ['twitter', 'mai', 'dhoni', 'dhoni', 'chillata', 'nahi', 'iska', 'meaning', 'yeh', 'nahi', 'ki', 'hate', '..', 'nikal', 'aab']
#
# 1.0 0.365 my dear yehi shayri han bus farq Jo baat kahnhi sakte unko shair main dhal dete Kuch samajh hate h aur kuch
#  ['dear', 'yehi', 'shayri', 'han', 'bus', 'farq', 'jo', 'baat', 'kahnhi', 'sakte', 'unko', 'shair', 'main', 'dhal', 'dete', 'kuch', 'samajh', 'hate', 'h', 'aur', 'kuch']
#
# 1.0 0.421 @iindrojit @narendramodi  bhai its freedom of speech not hate speech
#  ['bhai', 'freedom', 'speech', 'hate', 'speech']
#
# 1.0 0.435 kal to kuch aur bol re the... Ek baat bolo hate or love bahut confusion hota hai
#  ['kal', 'kuch', 'aur', 'bol', '...', 'ek', 'baat', 'bolo', 'hate', 'love', 'bahut', 'confusion', 'hota', 'hai']
#
# 1.0 0.43 Hate Story nahi dekhi kya?
#  ['hate', 'story', 'nahi', 'dekhi', 'kya']
#
# 1.0 0.482 Aaj Phir Tumpe Pyaar Aaya Hai Full Video HD 1080p Hate Story 2 by Arijit Singh http://fb.me/7UaB8Thng
#  ['aaj', 'phir', 'tumpe', 'pyaar', 'aaya', 'hai', 'full', 'video', 'hd', '1080p', 'hate', 'story', '2', 'arijit', 'singh']
#
# 1.0 0.375 ha yeh sikhata.Be Hai ki kisi ko use mazhab se hate mat Karo par Koi tumko kattarpanthi se terrorize kare saho bhi mat
#  ['ha', 'yeh', 'sikhata.be', 'hai', 'ki', 'kisi', 'ko', 'use', 'mazhab', 'se', 'hate', 'mat', 'karo', 'par', 'koi', 'tumko', 'kattarpanthi', 'se', 'terrorize', 'kare', 'saho', 'bhi', 'mat']
#
# 1.0 0.366 kuch bhi yaar..   Ab helly kisiko lyk bhi naa kare...  Itna bhi hate kyun karna..
#  ['kuch', 'bhi', 'yaar', '..', 'ab', 'helly', 'kisiko', 'lyk', 'bhi', 'naa', 'kare', '...', 'itna', 'bhi', 'hate', 'kyun', 'karna', '..']
#
# 1.0 0.47 Panday ziada hate speech to geo per hoti hai jahan tum paison ki khatr beathy howay ho amir liaquat ajkul tumri beand beja rha hai na https://twitter.com/shazbkhanzdaGEO/status/825064147624873984 …
#  ['panday', 'ziada', 'hate', 'speech', 'geo', 'per', 'hoti', 'hai', 'jahan', 'tum', 'paison', 'ki', 'khatr', 'beathy', 'howay', 'ho', 'amir', 'liaquat', 'ajkul', 'tumri', 'beand', 'beja', 'rha', 'hai', 'na', '…']
#
# 1.0 0.416 Aur jab apny kapray utrany lagay to hate speech.
#  ['aur', 'jab', 'apny', 'kapray', 'utrany', 'lagay', 'hate', 'speech']
#
# 1.0 0.485 khud ko best bolna aur dusre ka love hate calculate karna alag baat hota hain naa? KRK se pooch k dekho
#  ['khud', 'ko', 'best', 'bolna', 'aur', 'dusre', 'ka', 'love', 'hate', 'calculate', 'karna', 'alag', 'baat', 'hota', 'hain', 'naa', 'krk', 'se', 'pooch', 'k', 'dekho']
#
# 1.0 0.384 isi waja se aaj itna hate mila mujhe
#  ['isi', 'waja', 'se', 'aaj', 'itna', 'hate', 'mila', 'mujhe']
#
# 1.0 0.427 Aur hate tum hum sey kartey ho!
#  ['aur', 'hate', 'tum', 'hum', 'sey', 'kartey', 'ho']
#
# 1.0 0.415 Aur hate hi kar key sartey ho!
#  ['aur', 'hate', 'hi', 'kar', 'key', 'sartey', 'ho']
#
# 1.0 0.482 bol ti  band ho gai  Hate speech kia hoti hai me batao number to do apna
#  ['bol', 'ti', 'band', 'ho', 'gai', 'hate', 'speech', 'kia', 'hoti', 'hai', 'batao', 'number', 'apna']
#
# 1.0 0.446 mujhe pata hai you hate me!!
#  ['mujhe', 'pata', 'hai', 'hate']
#
# 1.0 0.359 kise n hate nhi kiye..
#  ['kise', 'n', 'hate', 'nhi', 'kiye', '..']
#
# 1.0 0.427 Apko Q itni Hate speech ker rahe hain #AamirLiaquat ke khilaf ?
#  ['apko', 'q', 'itni', 'hate', 'speech', 'ker', 'rahe', 'hain', 'aamirliaquat', 'ke', 'khilaf']
#
# 1.0 0.373 Mohsin abb tum mujhe hate karogy
#  ['mohsin', 'abb', 'tum', 'mujhe', 'hate', 'karogy']
#
# 1.0 0.397 yr imaan ab hum ko yeah hate u hey boley gey jeejo jo mill gaye is ko badal gaye.
#  ['yr', 'imaan', 'ab', 'hum', 'ko', 'yeah', 'hate', 'u', 'hey', 'boley', 'gey', 'jeejo', 'jo', 'mill', 'gaye', 'ko', 'badal', 'gaye']
#
# 1.0 0.463 mjh jo bh kaho ,, pr mery favrt ko na he like kro aur na he hate , warna
#  ['mjh', 'jo', 'bh', 'kaho', 'pr', 'mery', 'favrt', 'ko', 'na', 'like', 'kro', 'aur', 'na', 'hate', 'warna']
#
# 1.0 0.454 tu bhakt nahi hater hai.Nd log hate v usi Ko karte hai jisko kabhi v love Kiya ho. As I told u I m not a bhakt of any1.
#  ['tu', 'bhakt', 'nahi', 'hater', 'hai.nd', 'log', 'hate', 'v', 'usi', 'ko', 'karte', 'hai', 'jisko', 'kabhi', 'v', 'love', 'kiya', 'ho', 'told', 'u', 'bhakt', '1']
#
# 1.0 0.402 Hate karne ki bhi ek hadd hoti hai..
#  ['hate', 'karne', 'ki', 'bhi', 'ek', 'hadd', 'hoti', 'hai', '..']
#
# 1.0 0.465 dono milke phir ek dusre ko hate karne se zyada alag rehna hi theek hai
#  ['dono', 'milke', 'phir', 'ek', 'dusre', 'ko', 'hate', 'karne', 'se', 'zyada', 'alag', 'rehna', 'hi', 'theek', 'hai']
#
# 1.0 0.2 villain ki acting aisi honi chaiye ki ap usko hate karne lago. Usne itna achchha kya isiliye to uske liye mujhe hate feeling aya
#  ['villain', 'ki', 'acting', 'aisi', 'honi', 'chaiye', 'ki', 'ap', 'usko', 'hate', 'karne', 'lago', 'usne', 'itna', 'achchha', 'kya', 'isiliye', 'uske', 'liye', 'mujhe', 'hate', 'feeling', 'aya']
#
# 1.0 0.42 makkhan lagane wale log aksar chunna laga hate hai
#  ['makkhan', 'lagane', 'wale', 'log', 'aksar', 'chunna', 'laga', 'hate', 'hai']
#
# 1.0 0.334 Kiss ki hate speech chala di ?
#  ['kiss', 'ki', 'hate', 'speech', 'chala', 'di']
#
# 1.0 0.306 (2/2)  Kyun ke ye manogi to tum Islam ko hate kaise karogi phir? Sara propaganda jhoota sabit hoga. Jiyo bharam me karo hate.
#  ['2/2', 'kyun', 'ke', 'ye', 'manogi', 'tum', 'islam', 'ko', 'hate', 'kaise', 'karogi', 'phir', 'sara', 'propaganda', 'jhoota', 'sabit', 'hoga', 'jiyo', 'bharam', 'karo', 'hate']
#
# 1.0 0.403 @navinspeaks @NitibhaKaul  Navin now we hate u most.Kaise insan ho tumhe sharam aani chahiye.Rohan ke samne khade rehne ki aukat nahi hai
#  ['navin', 'hate', 'u', 'most.kaise', 'insan', 'ho', 'tumhe', 'sharam', 'aani', 'chahiye.rohan', 'ke', 'samne', 'khade', 'rehne', 'ki', 'aukat', 'nahi', 'hai']
#
# 1.0 0.354 @navinspeaks @rohan4747 @LokeshKumari1 @NitibhaKaul  Dekho Rohan ki popularity Usse ke liye mai tumhe hate kar rahi hu keyoki I love Rohan.
#  ['dekho', 'rohan', 'ki', 'popularity', 'usse', 'ke', 'liye', 'mai', 'tumhe', 'hate', 'kar', 'rahi', 'hu', 'keyoki', 'love', 'rohan']
#
# 0.0 0.556 Madarchod Saale gang rape ki paidayish
#  ['madarchod', 'saale', 'gang', 'rape', 'ki', 'paidayish']
#
# 0.0 0.704 Kashmir mai Jo ho raha hai Kiya wo terrorism nahi
#  ['kashmir', 'mai', 'jo', 'ho', 'raha', 'hai', 'kiya', 'wo', 'terrorism', 'nahi']
#
# 0.0 0.709 Toilet  nahi Isliye Tu Bahot rape hotay wahan  Rishi kapoor Ranbir Kis ka Beata Hain Haha shakti kapoor yeh Gulshan yeh Amitab
#  ['toilet', 'nahi', 'isliye', 'tu', 'bahot', 'rape', 'hotay', 'wahan', 'rishi', 'kapoor', 'ranbir', 'kis', 'ka', 'beata', 'hain', 'haha', 'shakti', 'kapoor', 'yeh', 'gulshan', 'yeh', 'amitab']
#
# 0.0 0.585 Tera baap hoga, tum log waise bhi rape ki padaish ho https://twitter.com/timesn0w/status/876081428584255489 …
#  ['tera', 'baap', 'hoga', 'tum', 'log', 'waise', 'bhi', 'rape', 'ki', 'padaish', 'ho', '…']
#
# 0.0 0.627 To Ek ek kar ke terror attacks me marne se unke pariwar ko dard nahi hoga? Kya kahna chahte ho?
#  ['ek', 'ek', 'kar', 'ke', 'terror', 'attacks', 'marne', 'se', 'unke', 'pariwar', 'ko', 'dard', 'nahi', 'hoga', 'kya', 'kahna', 'chahte', 'ho']
#
# 0.0 0.701 bhaiya ravish ,  tere bhai ne eh ladki ka rape kiya wo ladki ko bhi insaaf nhi mila abhi tsk kabho prime time pe us ladki tarf se bhi bolo.
#  ['bhaiya', 'ravish', 'tere', 'bhai', 'ne', 'eh', 'ladki', 'ka', 'rape', 'kiya', 'wo', 'ladki', 'ko', 'bhi', 'insaaf', 'nhi', 'mila', 'abhi', 'tsk', 'kabho', 'prime', 'time', 'pe', 'us', 'ladki', 'tarf', 'se', 'bhi', 'bolo']
#
# 0.0 0.667 Dilog acha hy rishi sir sbko pata hu terrorism kon kr Raha hy soo plzzz dosron pay ilzm na lagao pehly apne ghr ko saaf kro
#  ['dilog', 'acha', 'hy', 'rishi', 'sir', 'sbko', 'pata', 'hu', 'terrorism', 'kon', 'kr', 'raha', 'hy', 'soo', 'plzzz', 'dosron', 'pay', 'ilzm', 'na', 'lagao', 'pehly', 'apne', 'ghr', 'ko', 'saaf', 'kro']
#
# 0.0 0.574 Army ko roti nai milti awam k pas toilet nai or girls ka sath rape.muqabla karty hain Pakistan se wah g wah
#  ['army', 'ko', 'roti', 'nai', 'milti', 'awam', 'k', 'pas', 'toilet', 'nai', 'girls', 'ka', 'sath', 'rape.muqabla', 'karty', 'hain', 'pakistan', 'se', 'wah', 'g', 'wah']
#
# 0.0 0.609 Kapoor saheb, we are not terrorists, we are terrorism victims,, baqi itni nafrat,.. yaqeen nahi aata K Kapoor itni nafrat kartay hain !!!
#  ['kapoor', 'saheb', 'terrorists', 'terrorism', 'victims', 'baqi', 'itni', 'nafrat', '..', 'yaqeen', 'nahi', 'aata', 'k', 'kapoor', 'itni', 'nafrat', 'kartay', 'hain']
#
# 0.0 0.606 Ghus ja TV ke andar, kahi wo murder scene miss na ho jaye
#  ['ghus', 'ja', 'tv', 'ke', 'andar', 'kahi', 'wo', 'murder', 'scene', 'miss', 'na', 'ho', 'jaye']
#
# 0.0 0.599 Hum khaatey hain COW ka gosht uska khoon nhy peetey!
#  ['hum', 'khaatey', 'hain', 'cow', 'ka', 'gosht', 'uska', 'khoon', 'nhy', 'peetey']
#
# 0.0 0.502 Sr agar barud kam pad jaye topic me to mhamara khoon bardenge makkal Mila to in gaddar on ki puri nasal Mira dene.jai bhavani https://twitter.com/sudhirchaudhary/status/876094803368329218 …
#  ['sr', 'agar', 'barud', 'kam', 'pad', 'jaye', 'topic', 'mhamara', 'khoon', 'bardenge', 'makkal', 'mila', 'gaddar', 'ki', 'puri', 'nasal', 'mira', 'dene.jai', 'bhavani', '…']
#
# 0.0 0.565 Padhe likhe log social media pe nafrat faila the hai isse acha toh hum gawar hi thik the phele. @abpnewstv
#  ['padhe', 'likhe', 'log', 'social', 'media', 'pe', 'nafrat', 'faila', 'hai', 'isse', 'acha', 'toh', 'hum', 'gawar', 'hi', 'thik', 'phele']
#
# 0.0 0.702 @narendramodi nahi rape kam huye, na jobs badhe. UP BIHAR JHARKHAND aapse nahi sambhale na sudhare. baatein kar walo aapke logon se khali.
#  ['nahi', 'rape', 'kam', 'huye', 'na', 'jobs', 'badhe', 'bihar', 'jharkhand', 'aapse', 'nahi', 'sambhale', 'na', 'sudhare', 'baatein', 'kar', 'walo', 'aapke', 'logon', 'se', 'khali']
#
# 0.0 0.697 Mujhe tou Pata bhi nhi tha ke INDIANS andhe hain puri duniya KO Pata hai ke Sab se zaida terrorism kis country country me hai....
#  ['mujhe', 'tou', 'pata', 'bhi', 'nhi', 'tha', 'ke', 'indians', 'andhe', 'hain', 'puri', 'duniya', 'ko', 'pata', 'hai', 'ke', 'sab', 'se', 'zaida', 'terrorism', 'kis', 'country', 'country', 'hai', '...']
#
# 0.0 0.618 his hair is like more of Mahi!!! akhir khoon ka asaar ho hi gaya!!! #Ishqbaaazhttps://twitter.com/Muskanrathi10/status/876110194803179520 …
#  ['hair', 'like', 'mahi', 'akhir', 'khoon', 'ka', 'asaar', 'ho', 'hi', 'gaya', 'ishqbaaaz', '…']
#
# 0.0 0.661 Pakistan me ladkiyo ki kya halat he iska andaza isi baat se lagaya ja sakta he Pak me rape accused ko nhi rape victims ko saza di jati he
#  ['pakistan', 'ladkiyo', 'ki', 'kya', 'halat', 'iska', 'andaza', 'isi', 'baat', 'se', 'lagaya', 'ja', 'sakta', 'pak', 'rape', 'accused', 'ko', 'nhi', 'rape', 'victims', 'ko', 'saza', 'di', 'jati']
#
# 0.0 0.662 chal tujhy to bar rape krny ka chance mil jata ha naw
#  ['chal', 'tujhy', 'bar', 'rape', 'krny', 'ka', 'chance', 'mil', 'jata', 'ha', 'naw']
#
# 0.0 0.65 Aap log khud apni behnu ka rape kar rahe ho hamain kya sikhawoge
#  ['aap', 'log', 'khud', 'apni', 'behnu', 'ka', 'rape', 'kar', 'rahe', 'ho', 'hamain', 'kya', 'sikhawoge']
#
# 0.0 0.704 Aur India rape mukth hone ke liye nirbhaya kand ko yaad karta hai.
#  ['aur', 'india', 'rape', 'mukth', 'hone', 'ke', 'liye', 'nirbhaya', 'kand', 'ko', 'yaad', 'karta', 'hai']
#
# 0.0 0.598 Rishi sab har muslim terrorism na he hota agar ap ak ache or samajdar insaan hote to ap ko ye batane ke zarorat na te........
#  ['rishi', 'sab', 'har', 'muslim', 'terrorism', 'na', 'hota', 'agar', 'ap', 'ak', 'ache', 'samajdar', 'insaan', 'hote', 'ap', 'ko', 'ye', 'batane', 'ke', 'zarorat', 'na', 'te', '...']
#
# 0.0 0.579 indira Gandhi ko marne wala sikh.Rajiv Gandhi ko marne wali tamil ki thi,to Terrorism ko paida karne waly palny wala khud india haI.mind it https://twitter.com/chintskap/status/875447907922567170 …
#  ['indira', 'gandhi', 'ko', 'marne', 'wala', 'sikh.rajiv', 'gandhi', 'ko', 'marne', 'wali', 'tamil', 'ki', 'thi', 'terrorism', 'ko', 'paida', 'karne', 'waly', 'palny', 'wala', 'khud', 'india', 'hai.mind', '…']
#
# 0.0 0.579 Ab Gujarati janta Ka khoon pee rahe hain
#  ['ab', 'gujarati', 'janta', 'ka', 'khoon', 'pee', 'rahe', 'hain']
#
# 0.0 0.626 Aur 1971 ka stats dekhna tum saalon, pta chalega kaun kittey gddhey mein hai.
#  ['aur', '1971', 'ka', 'stats', 'dekhna', 'tum', 'saalon', 'pta', 'chalega', 'kaun', 'kittey', 'gddhey', 'mein', 'hai']
#
# 0.0 0.537 SIRF VOTE KE LIYE - SHARM KARO https://twitter.com/imnikbirla/status/876019410326228992 …
#  ['sirf', 'vote', 'ke', 'liye', 'sharm', 'karo', '…']
#
# 0.0 0.809 Awwww fir Bura Laga?? Bas kal tak aankh na fod liyo. Live rape dekh le Pakistan ka, legal bhi hai ye, rape obsessed chutiye
#  ['awww', 'fir', 'bura', 'laga', 'bas', 'kal', 'tak', 'aankh', 'na', 'fod', 'liyo', 'live', 'rape', 'dekh', 'le', 'pakistan', 'ka', 'legal', 'bhi', 'hai', 'ye', 'rape', 'obsessed', 'chutiye']
#
# 0.0 0.651 Muslim koi dharam nahi hai, ye to dunia ko idiot banane ke sauch hai
#  ['muslim', 'koi', 'dharam', 'nahi', 'hai', 'ye', 'dunia', 'ko', 'idiot', 'banane', 'ke', 'sauch', 'hai']
#
# 0.0 0.662 Haan ab to rape wali nsal jawan ho chuki hai
#  ['haan', 'ab', 'rape', 'wali', 'nsal', 'jawan', 'ho', 'chuki', 'hai']
#
# 0.0 0.643 Log pehle jan Lete hai. Aur fir jaan {murder} Lete hai https://twitter.com/NeHa_Ji_/status/876060500445904896 …
#  ['log', 'pehle', 'jan', 'lete', 'hai', 'aur', 'fir', 'jaan', 'murder', 'lete', 'hai', '…']
#
# 0.0 0.544 Bhai, khoon se tweet karayega kya??
#  ['bhai', 'khoon', 'se', 'tweet', 'karayega', 'kya']
#
# 0.0 0.737 Dosron ke mulk terrorist bejhtes hein knowledge itni ka larkiyon ko gaaliyaan detaa hai Bheno ka rape hona deta hein shit railway pa karte h
#  ['dosron', 'ke', 'mulk', 'terrorist', 'bejhtes', 'hein', 'knowledge', 'itni', 'ka', 'larkiyon', 'ko', 'gaaliyaan', 'detaa', 'hai', 'bheno', 'ka', 'rape', 'hona', 'deta', 'hein', 'shit', 'railway', 'pa', 'karte', 'h']
#
# 0.0 0.549 Kya sab kisan Bhai kcsath AAP yahi karegi??
#  ['kya', 'sab', 'kisan', 'bhai', 'kcsath', 'aap', 'yahi', 'karegi']
#
# 0.0 0.643 bhul gye ya yaad dilaye india ne sirf13 days k andar pakistan ko haraya tha sabak sikho aur terrorism band karo samjhe
#  ['bhul', 'gye', 'ya', 'yaad', 'dilaye', 'india', 'ne', 'sirf', '13', 'days', 'k', 'andar', 'pakistan', 'ko', 'haraya', 'tha', 'sabak', 'sikho', 'aur', 'terrorism', 'band', 'karo', 'samjhe']
#
# 0.0 0.681 @chintskap Terrorism tum logo nay phailya  hua kashmir mai hum nay nahe daily kashmiri shaheed karna kaha ke insaniyat hai ?
#  ['terrorism', 'tum', 'logo', 'nay', 'phailya', 'hua', 'kashmir', 'mai', 'hum', 'nay', 'nahe', 'daily', 'kashmiri', 'shaheed', 'karna', 'kaha', 'ke', 'insaniyat', 'hai']
#
# 0.0 0.547 Han ye monkey kalbhoshan bhi pakistani h na? Or isy Pakistan ne hindustan m terrorism phelane bheja tha? Jao pehle aina dekho
#  ['han', 'ye', 'monkey', 'kalbhoshan', 'bhi', 'pakistani', 'h', 'na', 'isy', 'pakistan', 'ne', 'hindustan', 'terrorism', 'phelane', 'bheja', 'tha', 'jao', 'pehle', 'aina', 'dekho']
#
# 0.0 0.726 Mujh bhi rapist ke moo lagnaa ka shq ni rape capital ka citizen
#  ['mujh', 'bhi', 'rapist', 'ke', 'moo', 'lagnaa', 'ka', 'shq', 'ni', 'rape', 'capital', 'ka', 'citizen']
#
# 0.0 0.692 Hamare javanMar rahe hai aur ham terrorists ko hi mar kar apni qamar Thap thapa rahe sir pak saniko ko maro terrorism turant bandh ho jayga.
#  ['hamare', 'javanmar', 'rahe', 'hai', 'aur', 'ham', 'terrorists', 'ko', 'hi', 'mar', 'kar', 'apni', 'qamar', 'thap', 'thapa', 'rahe', 'sir', 'pak', 'saniko', 'ko', 'maro', 'terrorism', 'turant', 'bandh', 'ho', 'jayga']
#
# 0.0 0.584 #ModelTownMassacre Zalimo Jwab do,Khoon ka Hisab do!!!
#  ['modeltownmassacre', 'zalimo', 'jwab', 'khoon', 'ka', 'hisab']
#
# 0.0 0.653 Apne Virodhiyion ko Online Rape and Gang Rape ki Dhamki dena ..Kis ki Sanskriti hai.???
#  ['apne', 'virodhiyion', 'ko', 'online', 'rape', 'gang', 'rape', 'ki', 'dhamki', 'dena', '..', 'kis', 'ki', 'sanskriti', 'hai']
#
# 0.0 0.538 kahenge ye bhi fake hai
#  ['kahenge', 'ye', 'bhi', 'fake', 'hai']
#
# 0.0 0.611 Bhai Army to donoun taraf ki hi lagi hoe hai. Hum log aapas main nafrat ko pata nahi kyun parwaan charha rhe hain  https://twitter.com/iamWali10/status/876031527087349760 …
#  ['bhai', 'army', 'donoun', 'taraf', 'ki', 'hi', 'lagi', 'hoe', 'hai', 'hum', 'log', 'aapas', 'main', 'nafrat', 'ko', 'pata', 'nahi', 'kyun', 'parwaan', 'charha', 'rhe', 'hain', '…']
#
# 0.0 0.53 Kashmir me itny log shaheed karty ho woh terrorism act ni Jahil Rishi kapoor Khoty kabhi school be chala jata ...
#  ['kashmir', 'itny', 'log', 'shaheed', 'karty', 'ho', 'woh', 'terrorism', 'act', 'ni', 'jahil', 'rishi', 'kapoor', 'khoty', 'kabhi', 'school', 'chala', 'jata', '...']
#
# 0.0 0.63 Yar ap rape to pehle band karo os ky bad baat karna
#  ['yar', 'ap', 'rape', 'pehle', 'band', 'karo', 'os', 'ky', 'bad', 'baat', 'karna']
#
# 0.0 0.56 thori c sharam b nae ha .. !! kon kar raa ha terrorism !! ultaa chor kotowaal ko dantay .. !!
#  ['thori', 'c', 'sharam', 'b', 'nae', 'ha', '..', 'kon', 'kar', 'raa', 'ha', 'terrorism', 'ultaa', 'chor', 'kotowaal', 'ko', 'dantay', '..']
#
# 0.0 0.665 Itne sidhe hote to baat hi kucch or hoti. Pata nahi kyun terrorism ko panah deke baithe hai.
#  ['itne', 'sidhe', 'hote', 'baat', 'hi', 'kucch', 'hoti', 'pata', 'nahi', 'kyun', 'terrorism', 'ko', 'panah', 'deke', 'baithe', 'hai']
#
# 0.0 0.841 Terrorism ka Matlab bhee pata Hai. Aap ka pita modi nay APS m bacho ko Mara Gujrat or Kashmir ya Kia Hai shoib Malik ka salo
#  ['terrorism', 'ka', 'matlab', 'bhee', 'pata', 'hai', 'aap', 'ka', 'pita', 'modi', 'nay', 'aps', 'bacho', 'ko', 'mara', 'gujrat', 'kashmir', 'ya', 'kia', 'hai', 'shoib', 'malik', 'ka', 'salo']
#
# ...
#
# 0.0 0.741 CAPTAIN ko koi Kuch bolega tho uska rape hoga wo bhi insane rape
#  ['captain', 'ko', 'koi', 'kuch', 'bolega', 'tho', 'uska', 'rape', 'hoga', 'wo', 'bhi', 'insane', 'rape']
#
# 0.0 0.689 pehke wale SRK hote toh abtak inki maiya ka rape ho chuka hota  aajkal bahoot simple hogayein hain.
#  ['pehke', 'wale', 'srk', 'hote', 'toh', 'abtak', 'inki', 'maiya', 'ka', 'rape', 'ho', 'chuka', 'hota', 'aajkal', 'bahoot', 'simple', 'hogayein', 'hain']
#
# 0.0 0.713 agar Hindustan me Rape ki saza jo Islam me he(saza e Maurice) to Muluk me Rape nahi ho sakta he
#  ['agar', 'hindustan', 'rape', 'ki', 'saza', 'jo', 'islam', 'saza', 'e', 'maurice', 'muluk', 'rape', 'nahi', 'ho', 'sakta']
#
# 0.0 0.771 @mohantyindia see @defencepk 50% Public PAGAL ho gai Bhukha mar dete hai bomb daltr hai gharope ladkiyo ka rape karte hai ?
#  ['see', '50', 'public', 'pagal', 'ho', 'gai', 'bhukha', 'mar', 'dete', 'hai', 'bomb', 'daltr', 'hai', 'gharope', 'ladkiyo', 'ka', 'rape', 'karte', 'hai']
#
# 0.0 0.657 knsa terrorism?? agr yeh baat ha phir toh sabse zyada hum log hain is cheez ka shikaar
#  ['knsa', 'terrorism', 'agr', 'yeh', 'baat', 'ha', 'phir', 'toh', 'sabse', 'zyada', 'hum', 'log', 'hain', 'cheez', 'ka', 'shikaar']
#
# 0.0 0.695 Namo ji 'betiyon ko rape se bachao-rapist ko sajaye maut' kya hoga Aap ke Raaj me???
#  ['namo', 'ji', 'betiyon', 'ko', 'rape', 'se', 'bachao-rapist', 'ko', 'sajaye', 'maut', 'kya', 'hoga', 'aap', 'ke', 'raaj']
#
# 0.0 0.56 Gandhi se yaad aaya vo Gandhi jo ldkiyo k sath sota tha, ya vo Jo Hindu aurato Ko bolta tha muslimo se chupchap rape krva lo - kadve bol https://twitter.com/digvijaya_28/status/820168305419792384 …
#  ['gandhi', 'se', 'yaad', 'aaya', 'vo', 'gandhi', 'jo', 'ldkiyo', 'k', 'sath', 'sota', 'tha', 'ya', 'vo', 'jo', 'hindu', 'aurato', 'ko', 'bolta', 'tha', 'muslimo', 'se', 'chupchap', 'rape', 'krva', 'lo', 'kadve', 'bol', '…']
#
# 0.0 0.646 Ya to apni beheno ka rape karoge ya shaadi kar ke chodoge.. par chahiye apni behen he.
#  ['ya', 'apni', 'beheno', 'ka', 'rape', 'karoge', 'ya', 'shaadi', 'kar', 'ke', 'chodoge', '..', 'par', 'chahiye', 'apni', 'behen']
#
# 0.0 0.653 Islea Rape hote hai
#  ['islea', 'rape', 'hote', 'hai']
#
# 0.0 0.595 Acha..hindu dharma ko bad me dekhna jao.halala roko.masumo.ka rape hota he is bahane se
#  ['acha', '..', 'hindu', 'dharma', 'ko', 'bad', 'dekhna', 'jao.halala', 'roko.masumo.ka', 'rape', 'hota', 'bahane', 'se']
#
# 0.0 0.702 @uptvbreaking bhai ye batao tum ji murthal rape case ki baat kar rahe ho wo rape case mein tum high court se aage hogaye..
#  ['bhai', 'ye', 'batao', 'tum', 'ji', 'murthal', 'rape', 'case', 'ki', 'baat', 'kar', 'rahe', 'ho', 'wo', 'rape', 'case', 'mein', 'tum', 'high', 'court', 'se', 'aage', 'hogaye', '..']
#
# 0.0 0.566 itna stand un sab bahno ke liye lo jo acid pidit h. rape pidit h. unka dard samjho @bani_j @biggboss @lopa9999
#  ['itna', 'stand', 'un', 'sab', 'bahno', 'ke', 'liye', 'lo', 'jo', 'acid', 'pidit', 'h', 'rape', 'pidit', 'h', 'unka', 'dard', 'samjho']
#
# 0.0 0.566 itna stand un sab bahno ke liye lo jo acid pidit h. rape pidit h. unka dard samjho @bani_j @biggboss @teambanij
#  ['itna', 'stand', 'un', 'sab', 'bahno', 'ke', 'liye', 'lo', 'jo', 'acid', 'pidit', 'h', 'rape', 'pidit', 'h', 'unka', 'dard', 'samjho']
#
# 0.0 0.566 itna stand un sab bahno ke liye lo jo acid pidit h. rape pidit h. unka dard samjho @bani_j @biggboss @lopa9999 @no_nonsense13
#  ['itna', 'stand', 'un', 'sab', 'bahno', 'ke', 'liye', 'lo', 'jo', 'acid', 'pidit', 'h', 'rape', 'pidit', 'h', 'unka', 'dard', 'samjho']
#
# 0.0 0.645 Bhanwari Devi ka nam yad hai Rajsthan ki thi.. Unhone RaGa Pe Rape kr Arop dala Aur dead BODy mili unki..
#  ['bhanwari', 'devi', 'ka', 'nam', 'yad', 'hai', 'rajsthan', 'ki', 'thi', '..', 'unhone', 'raga', 'pe', 'rape', 'kr', 'arop', 'dala', 'aur', 'dead', 'body', 'mili', 'unki', '..']
#
# 0.0 0.723 ab v to rape band nahi ho raha hai
#  ['ab', 'v', 'rape', 'band', 'nahi', 'ho', 'raha', 'hai']
#
# 0.0 0.581 i hate lopa tameez hie nahi uski mom ko cancer hai khud ko shamjte kaya bani ko always kuch na kuch bholte hai batmeez girl
#  ['hate', 'lopa', 'tameez', 'hie', 'nahi', 'uski', 'mom', 'ko', 'cancer', 'hai', 'khud', 'ko', 'shamjte', 'kaya', 'bani', 'ko', 'always', 'kuch', 'na', 'kuch', 'bholte', 'hai', 'batmeez', 'girl']
#
# 0.0 0.603 sirji 1 mulla rape and killed to dalit girl in bihar kuch to bhonko
#  ['sirji', '1', 'mulla', 'rape', 'killed', 'dalit', 'girl', 'bihar', 'kuch', 'bhonko']
#
# 0.0 0.65 Kaha gai WO media Jo rape jasi ghatnaa ko saalo chalate hai ek Fauji ki fariyaad  koi kyu nhi sunta hai or keval officer se desh nhi chalega
#  ['kaha', 'gai', 'wo', 'media', 'jo', 'rape', 'jasi', 'ghatnaa', 'ko', 'saalo', 'chalate', 'hai', 'ek', 'fauji', 'ki', 'fariyaad', 'koi', 'kyu', 'nhi', 'sunta', 'hai', 'keval', 'officer', 'se', 'desh', 'nhi', 'chalega']
#
# 0.0 0.584 i love you for this tweet I hate that ridiculous bani ek task to kar nahi pai aaj tak bas ande or tatto k siwa kuch nahi hai
#  ['love', 'tweet', 'hate', 'ridiculous', 'bani', 'ek', 'task', 'kar', 'nahi', 'pai', 'aaj', 'tak', 'bas', 'ande', 'tatto', 'k', 'siwa', 'kuch', 'nahi', 'hai']
#
# 0.0 0.616 @AngryDrBread Humayun, apne PM se bol ki pehle terrorism khatam kare. Puriya duniya me gandagi faila ke rakhi hai Pakistan ne.
#  ['humayun', 'apne', 'pm', 'se', 'bol', 'ki', 'pehle', 'terrorism', 'khatam', 'kare', 'puriya', 'duniya', 'gandagi', 'faila', 'ke', 'rakhi', 'hai', 'pakistan', 'ne']
#
# 0.0 0.634 sir, @SupraMario jaise log rape ko bhi galat nhi mante honge.
#  ['sir', 'jaise', 'log', 'rape', 'ko', 'bhi', 'galat', 'nhi', 'mante', 'honge']
#
# 0.0 0.618 Kashmiri hindu innocent nahi the kya?unhone kya gunah kiya tha? Unke sath q rape mass murder hua?kisne kiya?terrorists kon hain?
#  ['kashmiri', 'hindu', 'innocent', 'nahi', 'kya', 'unhone', 'kya', 'gunah', 'kiya', 'tha', 'unke', 'sath', 'q', 'rape', 'mass', 'murder', 'hua', 'kisne', 'kiya', 'terrorists', 'kon', 'hain']
#
# 0.0 0.608 Fucking hate PPP. Kaam aik anay ka nahi kia aur har cheez ka name benazir bhutto shaheed rakh dia. Kuttay ka bache
#  ['fucking', 'hate', 'ppp', 'kaam', 'aik', 'anay', 'ka', 'nahi', 'kia', 'aur', 'har', 'cheez', 'ka', 'name', 'benazir', 'bhutto', 'shaheed', 'rakh', 'dia', 'kuttay', 'ka', 'bache']
#
# 0.0 0.595 behanchod pehle terrorism to band karlo. 2-3 baar bheek di uske baad bhi harkato se baaz naahi aate.
#  ['behanchod', 'pehle', 'terrorism', 'band', 'karlo', '2-3', 'baar', 'bheek', 'di', 'uske', 'baad', 'bhi', 'harkato', 'se', 'baaz', 'naahi', 'aate']
#
# 0.0 0.829 @SushmaSwaraj Hai Aap Bataiye Kaise Dar Na Lage Media Aur Ministers Ko Dehli Aur Election Dikhta Hai Us Rape Victim Ka Dard Nahi Dikhta.
#  ['hai', 'aap', 'bataiye', 'kaise', 'dar', 'na', 'lage', 'media', 'aur', 'ministers', 'ko', 'dehli', 'aur', 'election', 'dikhta', 'hai', 'us', 'rape', 'victim', 'ka', 'dard', 'nahi', 'dikhta']
#
# 0.0 0.647 Hindustan ka law and order world me kachra hai. Rape ki case sunwayi hote hote rapist mar jate h. Isi ka RaGa bachaw karenge..
#  ['hindustan', 'ka', 'law', 'order', 'world', 'kachra', 'hai', 'rape', 'ki', 'case', 'sunwayi', 'hote', 'hote', 'rapist', 'mar', 'jate', 'h', 'isi', 'ka', 'raga', 'bachaw', 'karenge', '..']
#
# 0.0 0.582 Nahin Pitaah Shri, Bilkul bhi nahi, I hate Alcohol..  Aap ko to pataa hai Woh to sirf Aap ko hi shair Tweet kiyaa thaa
#  ['nahin', 'pitaah', 'shri', 'bilkul', 'bhi', 'nahi', 'hate', 'alcohol', '..', 'aap', 'ko', 'pataa', 'hai', 'woh', 'sirf', 'aap', 'ko', 'hi', 'shair', 'tweet', 'kiyaa', 'thaa']
#
# 0.0 0.714 bhai hindu to hathon hath lenge unki beti ka rape karne wale ko. unse ummed bhi kya hai!
#  ['bhai', 'hindu', 'hathon', 'hath', 'lenge', 'unki', 'beti', 'ka', 'rape', 'karne', 'wale', 'ko', 'unse', 'ummed', 'bhi', 'kya', 'hai']
#
# 0.0 0.613 aur tere musalmano ki terha hum apni bahu betiyo ka to rape nahi karte saale..
#  ['aur', 'tere', 'musalmano', 'ki', 'terha', 'hum', 'apni', 'bahu', 'betiyo', 'ka', 'rape', 'nahi', 'karte', 'saale', '..']
#
# 0.0 0.6 esliye toh favrt hai even manveer bhi as a game acha hai per manu I just hate him,manveer ko bas use kar raha hai
#  ['esliye', 'toh', 'favrt', 'hai', 'even', 'manveer', 'bhi', 'game', 'acha', 'hai', 'per', 'manu', 'hate', 'manveer', 'ko', 'bas', 'use', 'kar', 'raha', 'hai']
#
# 0.0 0.691 @ArvindKejriwal wo indian army se hai bhai sahab ussi army se hai jinpe tumhare JNU wale kutto ne rape jaise arop lagaye the
#  ['wo', 'indian', 'army', 'se', 'hai', 'bhai', 'sahab', 'ussi', 'army', 'se', 'hai', 'jinpe', 'tumhare', 'jnu', 'wale', 'kutto', 'ne', 'rape', 'jaise', 'arop', 'lagaye']
#
# 0.0 0.826 Yaha rape karne walonko saza miltha hai, waha rape kiska hua hai usko miltha hai.
#  ['yaha', 'rape', 'karne', 'walonko', 'saza', 'miltha', 'hai', 'waha', 'rape', 'kiska', 'hua', 'hai', 'usko', 'miltha', 'hai']
#
# 0.0 0.584 medical me rape ki pushti na hone pr bhi paid media ne kiya santo ko badnam.  #IsHumanRightAlive
#  ['medical', 'rape', 'ki', 'pushti', 'na', 'hone', 'pr', 'bhi', 'paid', 'media', 'ne', 'kiya', 'santo', 'ko', 'badnam', 'ishumanrightalive']
#
# 0.0 0.667 chutiya sale ka bhi rape kar dena chahiye jab samajh me ayega
#  ['chutiya', 'sale', 'ka', 'bhi', 'rape', 'kar', 'dena', 'chahiye', 'jab', 'samajh', 'ayega']
#
# 0.0 0.823 EK Neta us ladki jaisa hai jo khud ke kapde FAAD ke rape rape chilati hai.
#  ['ek', 'neta', 'us', 'ladki', 'jaisa', 'hai', 'jo', 'khud', 'ke', 'kapde', 'faad', 'ke', 'rape', 'rape', 'chilati', 'hai']
#
# 0.0 0.571 @alkeshmshah @ArvindKejriwalApni Ma se puchte ho ki  ration card ke liye rape karoon ki nahi. Haram kahan tu deshdrohi kahan Modi
#  ['pni', 'se', 'puchte', 'ho', 'ki', 'ration', 'card', 'ke', 'liye', 'rape', 'karoon', 'ki', 'nahi', 'haram', 'kahan', 'tu', 'deshdrohi', 'kahan', 'modi']
#
# 0.0 0.633 aaj wo hi @ArvindKejriwal bol rha h jisne JNU ke RasLeela Sanchalak Kanhaiya ke "Army Rape krti h" byan ka support kita tha..
#  ['aaj', 'wo', 'hi', 'bol', 'rha', 'h', 'jisne', 'jnu', 'ke', 'rasleela', 'sanchalak', 'kanhaiya', 'ke', 'army', 'rape', 'krti', 'h', 'byan', 'ka', 'support', 'kita', 'tha', '..']
#
# 0.0 0.513 Isi bewkoof  kejriwal ne JNU me un logo ka support kiya tha jo bol rhe the ki Army Rape krti h.
#  ['isi', 'bewkoof', 'kejriwal', 'ne', 'jnu', 'un', 'logo', 'ka', 'support', 'kiya', 'tha', 'jo', 'bol', 'rhe', 'ki', 'army', 'rape', 'krti', 'h']
#
# 0.0 0.722 tumne kyaa kiya delhi ke liye ab punjaab chale gaye saale rape hote hai delhi main tu punjaab main mauz karta hai
#  ['tumne', 'kyaa', 'kiya', 'delhi', 'ke', 'liye', 'ab', 'punjaab', 'chale', 'gaye', 'saale', 'rape', 'hote', 'hai', 'delhi', 'main', 'tu', 'punjaab', 'main', 'mauz', 'karta', 'hai']
#
# 0.0 0.682 Ek kaam kro ye 3 ldke jha bhi dikhe jaan se maar dena inko  Rap ka Rape kr dia http://fb.me/DgfpzMdO
#  ['ek', 'kaam', 'kro', 'ye', '3', 'ldke', 'jha', 'bhi', 'dikhe', 'jaan', 'se', 'maar', 'dena', 'inko', 'rap', 'ka', 'rape', 'kr', 'dia']
#
# 0.0 0.694 hahaha hohoho. kaun si imadaar rajneeti krta hai yeh pagal aadmi. Ration card k naam pr rape krte hai pAAPiye
#  ['hahaha', 'hohoho', 'kaun', 'si', 'imadaar', 'rajneeti', 'krta', 'hai', 'yeh', 'pagal', 'aadmi', 'ration', 'card', 'k', 'naam', 'pr', 'rape', 'krte', 'hai', 'paapiye']
#
# 0.0 0.644 shiv kon hai ye toh tere rapist Muhammad se puchh jiski rape ka tu nateeja hai.....bhadwe rapist ka result.....aisha kaisi chudi
#  ['shiv', 'kon', 'hai', 'ye', 'toh', 'tere', 'rapist', 'muhammad', 'se', 'puchh', 'jiski', 'rape', 'ka', 'tu', 'nateeja', 'hai', '...', 'bhadwe', 'rapist', 'ka', 'result', '...', 'aisha', 'kaisi', 'chudi']
#
# 0.0 0.6 Mughalo k rape ka nateeja hai tu osama bin laden ki aulaad......dekh kahin agla bomb teri maa k gaand mein naa fatt jaye
#  ['mughalo', 'k', 'rape', 'ka', 'nateeja', 'hai', 'tu', 'osama', 'bin', 'laden', 'ki', 'aulaad', '...', 'dekh', 'kahin', 'agla', 'bomb', 'teri', 'maa', 'k', 'gaand', 'mein', 'naa', 'fatt', 'jaye']
#
# 0.0 0.607 Pehle mooh kholo rape Kiya hain khud ke logone, we know why u stay at home hijab ke android kya hain
#  ['pehle', 'mooh', 'kholo', 'rape', 'kiya', 'hain', 'khud', 'ke', 'logone', 'know', 'u', 'stay', 'home', 'hijab', 'ke', 'android', 'kya', 'hain']
#
# 0.0 0.651 Sachche deen kon? VO LOOTERE, KASAI, Ghod-sawar Mangoliye/Arab jo lootne aaye aur Hindu auratonko rape kr ke tumhe paida kiya??? https://twitter.com/NururBarkati/status/818467514178904064 …
#  ['sachche', 'deen', 'kon', 'vo', 'lootere', 'kasai', 'ghod-sawar', 'mangoliye', 'arab', 'jo', 'lootne', 'aaye', 'aur', 'hindu', 'auratonko', 'rape', 'kr', 'ke', 'tumhe', 'paida', 'kiya', '…']
#
# 0.0 0.722 @anuragkashyap72  jaha tak mujhe pta hai terrorism has no religion but still jab tak aap jaise log chutiyapa kabhi band nahi hoga
#  ['jaha', 'tak', 'mujhe', 'pta', 'hai', 'terrorism', 'religion', 'still', 'jab', 'tak', 'aap', 'jaise', 'log', 'chutiyapa', 'kabhi', 'band', 'nahi', 'hoga']
#
# 0.0 0.536 MC kuch gundo ki vajah se tum aaj Hindu.. bol rahe ho Islamic terrorism bolne me gand phatti hai
#  ['mc', 'kuch', 'gundo', 'ki', 'vajah', 'se', 'tum', 'aaj', 'hindu', '..', 'bol', 'rahe', 'ho', 'islamic', 'terrorism', 'bolne', 'gand', 'phatti', 'hai']
#
# 0.0 0.545 aur jo hate speech @najamsethi kuuta karta hai us ka kya? hai himmat to defend kro usko?
#  ['aur', 'jo', 'hate', 'speech', 'kuuta', 'karta', 'hai', 'us', 'ka', 'kya', 'hai', 'himmat', 'defend', 'kro', 'usko']
#
# 0.0 0.627 haha slb ko thappad pada tab kaisa des mei ho lagraha hei jab har din rape hota hei tab gaand marwa rahi thi kya
#  ['haha', 'slb', 'ko', 'thappad', 'pada', 'tab', 'kaisa', 'des', 'mei', 'ho', 'lagraha', 'hei', 'jab', 'har', 'din', 'rape', 'hota', 'hei', 'tab', 'gaand', 'marwa', 'rahi', 'thi', 'kya']
#
# 0.0 0.577 I have to say i hate @TheManuPunjabi . khud manu use kr raha hai aur ilzam bani py laga raha hai. sara season manu ny yhi kya hai @BiggBoss
#  ['say', 'hate', 'khud', 'manu', 'use', 'kr', 'raha', 'hai', 'aur', 'ilzam', 'bani', 'py', 'laga', 'raha', 'hai', 'sara', 'season', 'manu', 'ny', 'yhi', 'kya', 'hai']
#
# 0.0 0.686 @TarekFatah Magar Porkistani insaan nahi hai ghade hai sarey rape ki padaish
#  ['magar', 'porkistani', 'insaan', 'nahi', 'hai', 'ghade', 'hai', 'sarey', 'rape', 'ki', 'padaish']
#
# 0.0 0.59 Wese chahe rape hote rahe poore desh me! No one bats an eye then!
#  ['wese', 'chahe', 'rape', 'hote', 'rahe', 'poore', 'desh', 'one', 'bats', 'eye']
#
# 0.0 0.642 Raees ka rape hoke hi rahega
#  ['raees', 'ka', 'rape', 'hoke', 'hi', 'rahega']
#
# 0.0 0.506 Bhensa Ko van karna chye tha , us or awaz uthanay wlay Ko ban kr diya ( hate speech) tou Bhensa kr rha hai  #PEMRA
#  ['bhensa', 'ko', 'van', 'karna', 'chye', 'tha', 'us', 'awaz', 'uthanay', 'wlay', 'ko', 'ban', 'kr', 'diya', 'hate', 'speech', 'tou', 'bhensa', 'kr', 'rha', 'hai', 'pemra']
#
# 0.0 0.527 chal na gunda manvr manu ka chamcha i hate m2 piche piche chugliya karta hai manu ke sath ghar ganda bna rak
#  ['chal', 'na', 'gunda', 'manvr', 'manu', 'ka', 'chamcha', 'hate', 'm2', 'piche', 'piche', 'chugliya', 'karta', 'hai', 'manu', 'ke', 'sath', 'ghar', 'ganda', 'bna', 'rak']
#
# 0.0 0.507 I hate this person Jo desh ke rastra gaan ko ijjat nahi deta usko Indian team me bhi koi jagaha nahi deni chahaiye
#  ['hate', 'person', 'jo', 'desh', 'ke', 'rastra', 'gaan', 'ko', 'ijjat', 'nahi', 'deta', 'usko', 'indian', 'team', 'bhi', 'koi', 'jagaha', 'nahi', 'deni', 'chahaiye']
#
# 0.0 0.6 #UP ELECTIONS 2017 Betiyoon Ka Rape kar unhe pedh se latka diya tha shayad Ye sabhi ko hoga yaad..UP bachaoo Desh Bachaoo
#  ['elections', '2017', 'betiyoon', 'ka', 'rape', 'kar', 'unhe', 'pedh', 'se', 'latka', 'diya', 'tha', 'shayad', 'ye', 'sabhi', 'ko', 'hoga', 'yaad', '..', 'bachaoo', 'desh', 'bachaoo']
#
# 0.0 0.757 delhi me bhi yhi kha tha fir rape murder kyu  badh gya itna lgta hai bhul gye ap vha bhi aap hai
#  ['delhi', 'bhi', 'yhi', 'kha', 'tha', 'fir', 'rape', 'murder', 'kyu', 'badh', 'gya', 'itna', 'lgta', 'hai', 'bhul', 'gye', 'ap', 'vha', 'bhi', 'aap', 'hai']
#
# 0.0 0.647 Ye hai sapa ke neta jo ki varanasi cholapur block ke pramukh hai. Inki gunda gardi.ladish ko rape ki dhamki pic.twitter.com/51y8zk16Ln
#  ['ye', 'hai', 'sapa', 'ke', 'neta', 'jo', 'ki', 'varanasi', 'cholapur', 'block', 'ke', 'pramukh', 'hai', 'inki', 'gunda', 'gardi.ladish', 'ko', 'rape', 'ki', 'dhamki', 'pic.twitter.com/51y8zk16ln']

# %% [markdown]
# Later in this specialization, we will see how we can use deeplearning to improve the prediction performance.

# %% [markdown]
# <a name='6'></a>
# ## 6 - Predict with your own Tweet

# %%
# Feel free to change the tweet below
my_tweet = 'ab janata ke praakrtik otomaitik #raiphal ka baarood #nasabandee karake band karoge,,to phir khilauna #bandook to chalaenge hee....  ib kutte karm karoge to pher #kutte kee maut hee maroge    #tera bee tem aagya #kaijriwalassassinationchlaim'
print(process_tweet(my_tweet))
y_hat = predict_tweet(my_tweet, freqs, theta)
print(y_hat)
if y_hat > 0.5:
    print('non-hate')
else: 
    print('hate')
# Out:
# ['ab', 'janata', 'ke', 'praakrtik', 'otomaitik', 'raiphal', 'ka', 'baarood', 'nasabandee', 'karake', 'band', 'karoge', 'phir', 'khilauna', 'bandook', 'chalaenge', 'hee', '...', 'ib', 'kutte', 'karm', 'karoge', 'pher', 'kutte', 'kee', 'maut', 'hee', 'maroge', 'tera', 'bee', 'tem', 'aagya', 'kaijriwalassassinationchlaim']
# [[0.52350543]]
# non-hate

# %%
my_tweet = 'kitana achchha samudaay hai ye hamesha gareeb logo ke lie bhandaara arenj karata hai'
print(process_tweet(my_tweet))
y_hat = predict_tweet(my_tweet, freqs, theta)
print(y_hat)
if y_hat > 0.5:
    print('non-hate')
else: 
    print('haye')
# Out:
# ['kitana', 'achchha', 'samudaay', 'hai', 'ye', 'hamesha', 'gareeb', 'logo', 'ke', 'lie', 'bhandaara', 'arenj', 'karata', 'hai']
# [[0.59712545]]
# non-hate
