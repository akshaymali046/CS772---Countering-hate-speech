# %% [markdown]
# <a name='0'></a>
# ## Importing libraries and defining cleaning and other useful functions

# %%
import re
import string

# %%
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import TweetTokenizer

# %%
from matplotlib.patches import Ellipse
import matplotlib.transforms as transforms
import numpy as np

# %%
def process_tweet(tweet):
    '''
    Input: 
        tweet: a string containing a tweet
    Output:
        tweets_clean: a list of words containing the processed tweet

    '''
    stemmer = PorterStemmer()
    stopwords_english = stopwords.words('english')
    # remove stock market tickers like $GE
    tweet = re.sub(r'\$\w*', '', tweet)
    # remove old style retweet text "RT"
    tweet = re.sub(r'^RT[\s]+', '', tweet)
    # remove hyperlinks
    #tweet = re.sub(r'https?:\/\/.*[\r\n]*', '', tweet)
    tweet = re.sub(r'https?://[^\s\n\r]+', '', tweet)
    # remove hashtags
    # only removing the hash # sign from the word
    tweet = re.sub(r'#', '', tweet)
    # tokenize tweets
    tokenizer = TweetTokenizer(preserve_case=False, strip_handles=True,
                               reduce_len=True)
    tweet_tokens = tokenizer.tokenize(tweet)

    tweets_clean = []
    for word in tweet_tokens:
        if (word not in stopwords_english and  # remove stopwords
            word not in string.punctuation):  # remove punctuation
            # tweets_clean.append(word)
            stem_word = word  # stemming word
            tweets_clean.append(stem_word)

    return tweets_clean

# %%
process_tweet("newcamp.iitb.ac.in")
# Out:
# ['newcamp.iitb.ac.in']

# %%
def lookup(freqs, word, label):
    '''
    Input:
        freqs: a dictionary with the frequency of each pair (or tuple)
        word: the word to look up
        label: the label corresponding to the word
    Output:
        n: the number of times the word with its corresponding label appears.
    '''
    n = 0  # freqs.get((word, label), 0)

    pair = (word, label)
    if (pair in freqs):
        n = freqs[pair]

    return n

# %%
def confidence_ellipse(x, y, ax, n_std=3.0, facecolor='none', **kwargs):
    """
    Create a plot of the covariance confidence ellipse of `x` and `y`
    Parameters
    ----------
    x, y : array_like, shape (n, )
        Input data.
    ax : matplotlib.axes.Axes
        The axes object to draw the ellipse into.
    n_std : float
        The number of standard deviations to determine the ellipse's radiuses.
    Returns
    -------
    matplotlib.patches.Ellipse
    Other parameters
    ----------------
    kwargs : `~matplotlib.patches.Patch` properties
    """
    if x.size != y.size:
        raise ValueError("x and y must be the same size")

    cov = np.cov(x, y)
    pearson = cov[0, 1] / np.sqrt(cov[0, 0] * cov[1, 1])
    # Using a special case to obtain the eigenvalues of this
    # two-dimensionl dataset.
    ell_radius_x = np.sqrt(1 + pearson)
    ell_radius_y = np.sqrt(1 - pearson)
    ellipse = Ellipse((0, 0),
                      width=ell_radius_x * 2,
                      height=ell_radius_y * 2,
                      facecolor=facecolor,
                      **kwargs)

    # Calculating the stdandard deviation of x from
    # the squareroot of the variance and multiplying
    # with the given number of standard deviations.
    scale_x = np.sqrt(cov[0, 0]) * n_std
    mean_x = np.mean(x)

    # calculating the stdandard deviation of y ...
    scale_y = np.sqrt(cov[1, 1]) * n_std
    mean_y = np.mean(y)

    transf = transforms.Affine2D() \
        .rotate_deg(45) \
        .scale(scale_x, scale_y) \
        .translate(mean_x, mean_y)

    ellipse.set_transform(transf + ax.transData)
    return ax.add_patch(ellipse)

# %%
import pdb
import numpy as np
import pandas as pd
import nltk
import string
from nltk.tokenize import TweetTokenizer
from os import getcwd

# %%
import csv
all_hate_tweets=[]
all_nonhate_tweets=[]
with open('hate_speech.tsv', newline='', encoding="utf8") as tsvfile:
    reader = csv.reader(tsvfile, delimiter='\t')
    for row in reader:
        if row[1] == 'yes': 
            all_hate_tweets.append(row[0])
        else:
            all_nonhate_tweets.append(row[0])

# %%
len(all_hate_tweets)
# Out:
# 1661

# %%
len(all_nonhate_tweets)
# Out:
# 2918

# %%
all_hate_tweets[15]
# Out:
# 'Aayega jab take alia ki shaadi age pass aayegi kyuki alia said 30ki hoote hi won shaadi kargi varun bhi kitna kutta hai Natasha ka shaadi ka spna this alia ke saath shaadi ki baat paaki kar ki hate varun alia sid please career pe focus karo aue alia ke banner se film mat karo'

# %%
all_nonhate_tweets[15]
# Out:
# 'aj arshi ne jo laat eske pichwade mei mari thi wo photo twit kro bhai juldi se.'

# %%
# split the data into two pieces, one for training and one for testing (validation set)
test_pos = all_nonhate_tweets[2400:]
train_pos = all_nonhate_tweets[:2400]
test_neg = all_hate_tweets[1328:]
train_neg = all_hate_tweets[:1328]

train_x = train_pos + train_neg
test_x = test_pos + test_neg

# avoid assumptions about the length of all_positive_tweets
train_y = np.append(np.ones(len(train_pos)), np.zeros(len(train_neg)))
test_y = np.append(np.ones(len(test_pos)), np.zeros(len(test_neg)))

# %% [markdown]
# <a name='1'></a>
# ## 1 - Process the Data
#
# For any machine learning project, once you've gathered the data, the first step is to process it to make useful inputs to your model.
# - **Remove noise**: You will first want to remove noise from your data -- that is, remove words that don't tell you much about the content. These include all common words like 'I, you, are, is, etc...' that would not give us enough information on the sentiment.
# - We'll also remove stock market tickers, retweet symbols, hyperlinks, and hashtags because they can not tell you a lot of information on the sentiment.
# - You also want to remove all the punctuation from a tweet. The reason for doing this is because we want to treat words with or without the punctuation as the same word, instead of treating "happy", "happy?", "happy!", "happy," and "happy." as different words.
# - Finally you want to use stemming to only keep track of one variation of each word. In other words, we'll treat "motivation", "motivated", and "motivate" similarly by grouping them within the same stem of "motiv-".
#
# We have given you the function `process_tweet` that does this for you.

# %%
custom_tweet = "Aayega jab take alia ki shaadi age pass aayegi kyuki alia said 30ki hoote hi won shaadi kargi varun bhi kitna kutta hai Natasha ka shaadi ka spna this alia ke saath shaadi ki baat paaki kar ki hate varun alia sid please career pe focus karo aue alia ke banner se film mat karo"
# print cleaned tweet
print(process_tweet(custom_tweet))
# Out:
# ['aayega', 'jab', 'take', 'alia', 'ki', 'shaadi', 'age', 'pass', 'aayegi', 'kyuki', 'alia', 'said', '30ki', 'hoote', 'hi', 'shaadi', 'kargi', 'varun', 'bhi', 'kitna', 'kutta', 'hai', 'natasha', 'ka', 'shaadi', 'ka', 'spna', 'alia', 'ke', 'saath', 'shaadi', 'ki', 'baat', 'paaki', 'kar', 'ki', 'hate', 'varun', 'alia', 'sid', 'please', 'career', 'pe', 'focus', 'karo', 'aue', 'alia', 'ke', 'banner', 'se', 'film', 'mat', 'karo']

# %% [markdown]
# <a name='1-1'></a>
# ### 1.1 - Implementing your Helper Functions
#
# To help you train your naive bayes model, you will need to compute a dictionary where the keys are a tuple (word, label) and the values are the corresponding frequency.  Note that the labels we'll use here are 1 for positive and 0 for negative.
#
# You will also implement a lookup helper function that takes in the `freqs` dictionary, a word, and a label (1 or 0) and returns the number of times that word and label tuple appears in the collection of tweets.
#
# For example: given a list of tweets `["i am rather excited", "you are rather happy"]` and the label 1, the function will return a dictionary that contains the following key-value pairs:
#
# {
#     ("rather", 1): 2,
#     ("happi", 1) : 1,
#     ("excit", 1) : 1
# }
#
# - Notice how for each word in the given string, the same label 1 is assigned to each word.
# - Notice how the words "i" and "am" are not saved, since it was removed by process_tweet because it is a stopword.
# - Notice how the word "rather" appears twice in the list of tweets, and so its count value is 2.

# %%
# UNQ_C1 GRADED FUNCTION: count_tweets

def count_tweets(result, tweets, ys):
    '''
    Input:
        result: a dictionary that will be used to map each pair to its frequency
        tweets: a list of tweets
        ys: a list corresponding to the sentiment of each tweet (either 0 or 1)
    Output:
        result: a dictionary mapping each pair to its frequency
    '''
    ### START CODE HERE ###
    for y, tweet in zip(ys, tweets):
        for word in process_tweet(tweet):
            # define the key, which is the word and label tuple
            pair = (word,y)
            
            # if the key exists in the dictionary, increment the count
            if pair in result:
                result[pair] += 1

            # else, if the key is new, add it to the dictionary and set the count to 1
            else:
                result[pair] = 1
    ### END CODE HERE ###

    return result

# %%
# Testing your function

result = {}
tweets = ['i am happy', 'i am tricked', 'i am sad', 'i am tired', 'i am tired']
ys = [1, 0, 0, 0, 0]
count_tweets(result, tweets, ys)
# Out:
# {('happy', 1): 1, ('tricked', 0): 1, ('sad', 0): 1, ('tired', 0): 2}

# %% [markdown]
# <a name='2'></a>
# ## 2 - Train your Model using Naive Bayes
#
# Naive bayes is an algorithm that could be used for sentiment analysis. It takes a short time to train and also has a short prediction time.
#
# #### So how do you train a Naive Bayes classifier?
# - The first part of training a naive bayes classifier is to identify the number of classes that you have.
# - You will create a probability for each class.
# $P(D_{pos})$ is the probability that the document is positive.
# $P(D_{neg})$ is the probability that the document is negative.
# Use the formulas as follows and store the values in a dictionary:
#
# $$P(D_{pos}) = \frac{D_{pos}}{D}\tag{1}$$
#
# $$P(D_{neg}) = \frac{D_{neg}}{D}\tag{2}$$
#
# Where $D$ is the total number of documents, or tweets in this case, $D_{pos}$ is the total number of positive tweets and $D_{neg}$ is the total number of negative tweets.

# %% [markdown]
# #### Prior and Logprior
#
# The prior probability represents the underlying probability in the target population that a tweet is positive versus negative.  In other words, if we had no specific information and blindly picked a tweet out of the population set, what is the probability that it will be positive versus that it will be negative? That is the "prior".
#
# The prior is the ratio of the probabilities $\frac{P(D_{pos})}{P(D_{neg})}$.
# We can take the log of the prior to rescale it, and we'll call this the logprior
#
# $$\text{logprior} = log \left( \frac{P(D_{pos})}{P(D_{neg})} \right) = log \left( \frac{D_{pos}}{D_{neg}} \right)$$.
#
# Note that $log(\frac{A}{B})$ is the same as $log(A) - log(B)$.  So the logprior can also be calculated as the difference between two logs:
#
# $$\text{logprior} = \log (P(D_{pos})) - \log (P(D_{neg})) = \log (D_{pos}) - \log (D_{neg})\tag{3}$$

# %% [markdown]
# #### Positive and Negative Probability of a Word
# To compute the positive probability and the negative probability for a specific word in the vocabulary, we'll use the following inputs:
#
# - $freq_{pos}$ and $freq_{neg}$ are the frequencies of that specific word in the positive or negative class. In other words, the positive frequency of a word is the number of times the word is counted with the label of 1.
# - $N_{pos}$ and $N_{neg}$ are the total number of positive and negative words for all documents (for all tweets), respectively.
# - $V$ is the number of unique words in the entire set of documents, for all classes, whether positive or negative.
#
# We'll use these to compute the positive and negative probability for a specific word using this formula:
#
# $$ P(W_{pos}) = \frac{freq_{pos} + 1}{N_{pos} + V}\tag{4} $$
# $$ P(W_{neg}) = \frac{freq_{neg} + 1}{N_{neg} + V}\tag{5} $$
#
# Notice that we add the "+1" in the numerator for additive smoothing.  This [wiki article](https://en.wikipedia.org/wiki/Additive_smoothing) explains more about additive smoothing.

# %% [markdown]
# #### Log likelihood
# To compute the loglikelihood of that very same word, we can implement the following equations:
#
# $$\text{loglikelihood} = \log \left(\frac{P(W_{pos})}{P(W_{neg})} \right)\tag{6}$$

# %% [markdown]
# ##### Create `freqs` dictionary
# - Given your `count_tweets` function, you can compute a dictionary called `freqs` that contains all the frequencies.
# - In this `freqs` dictionary, the key is the tuple (word, label)
# - The value is the number of times it has appeared.
#
# We will use this dictionary in several parts of this assignment.

# %%
# Build the freqs dictionary for later uses
freqs = count_tweets({}, train_x, train_y)

# %% [markdown]
# <a name='ex-2'></a>
# ### Exercise 2 - train_naive_bayes
# Given a freqs dictionary, `train_x` (a list of tweets) and a `train_y` (a list of labels for each tweet), implement a naive bayes classifier.
#
# ##### Calculate $V$
# - You can then compute the number of unique words that appear in the `freqs` dictionary to get your $V$ (you can use the `set` function).
#
# ##### Calculate $freq_{pos}$ and $freq_{neg}$
# - Using your `freqs` dictionary, you can compute the positive and negative frequency of each word $freq_{pos}$ and $freq_{neg}$.
#
# ##### Calculate $N_{pos}$, and $N_{neg}$
# - Using `freqs` dictionary, you can also compute the total number of positive words and total number of negative words $N_{pos}$ and $N_{neg}$.
#
# ##### Calculate $D$, $D_{pos}$, $D_{neg}$
# - Using the `train_y` input list of labels, calculate the number of documents (tweets) $D$, as well as the number of positive documents (tweets) $D_{pos}$ and number of negative documents (tweets) $D_{neg}$.
# - Calculate the probability that a document (tweet) is positive $P(D_{pos})$, and the probability that a document (tweet) is negative $P(D_{neg})$
#
# ##### Calculate the logprior
# - the logprior is $log(D_{pos}) - log(D_{neg})$
#
# ##### Calculate log likelihood
# - Finally, you can iterate over each word in the vocabulary, use your `lookup` function to get the positive frequencies, $freq_{pos}$, and the negative frequencies, $freq_{neg}$, for that specific word.
# - Compute the positive probability of each word $P(W_{pos})$, negative probability of each word $P(W_{neg})$ using equations 4 & 5.
#
# $$ P(W_{pos}) = \frac{freq_{pos} + 1}{N_{pos} + V}\tag{4} $$
# $$ P(W_{neg}) = \frac{freq_{neg} + 1}{N_{neg} + V}\tag{5} $$
#
# **Note:** We'll use a dictionary to store the log likelihoods for each word.  The key is the word, the value is the log likelihood of that word).
#
# - You can then compute the loglikelihood: $log \left( \frac{P(W_{pos})}{P(W_{neg})} \right)$.

# %%
def train_naive_bayes(freqs, train_x, train_y):
    '''
    Input:
        freqs: dictionary from (word, label) to how often the word appears
        train_x: a list of tweets
        train_y: a list of labels correponding to the tweets (0,1)
    Output:
        logprior: the log prior. (equation 3 above)
        loglikelihood: the log likelihood of you Naive bayes equation. (equation 6 above)
    '''
    loglikelihood = {}
    logprior = 0

    ### START CODE HERE ###

    # calculate V, the number of unique words in the vocabulary
    vocab = []
    for pair in freqs.keys():
        if pair[0] not in vocab:
            vocab.append(pair[0])
        
    V = len(set(vocab))    

    # calculate N_pos, N_neg, V_pos, V_neg
    N_pos = N_neg = 0
    for pair in freqs.keys():
        # if the label is positive (greater than zero)
        if pair[1] > 0:

            # Increment the number of positive words by the count for this (word, label) pair
            N_pos += lookup(freqs, pair[0], 1)

        # else, the label is negative
        else:

            # increment the number of negative words by the count for this (word,label) pair
            N_neg += lookup(freqs, pair[0], 0)
    
    # Calculate D, the number of documents
    D = len(train_y)

    # Calculate D_pos, the number of positive documents
    # Calculate D_neg, the number of negative documents

    D_pos = 0
    D_neg = 0
    for i in range(len(train_y)):
        if train_y[i] == 1:
            D_pos += 1
        else:
            D_neg += 1

    # Calculate logprior
    logprior = np.log(D_pos/D_neg)
    
    # For each word in the vocabulary...
    for word in vocab:
        # get the positive and negative frequency of the word
        freq_pos = lookup(freqs, word, 1)
        freq_neg = lookup(freqs, word, 0)
        

        # calculate the probability that each word is positive, and negative
        p_w_pos = (freq_pos+1)/(N_pos+V)
        p_w_neg = (freq_neg+1)/(N_neg+V)

        # calculate the log likelihood of the word
        loglikelihood[word] = np.log(p_w_pos/p_w_neg)

    ### END CODE HERE ###

    return logprior, loglikelihood

# %%
# UNQ_C3 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
logprior, loglikelihood = train_naive_bayes(freqs, train_x, train_y)
print(logprior)
print(len(loglikelihood))
# Out:
# 0.5917946862996578
# 12544

# %% [markdown]
# <a name='3'></a>
# ## 3 - Test your Naive Bayes
#
# Now that we have the `logprior` and `loglikelihood`, we can test the naive bayes function by making predicting on some tweets!
#
# <a name='ex-3'></a>
# ### Exercise 3 - naive_bayes_predict
# Implement `naive_bayes_predict`.
#
# **Instructions**:
# Implement the `naive_bayes_predict` function to make predictions on tweets.
# * The function takes in the `tweet`, `logprior`, `loglikelihood`.
# * It returns the probability that the tweet belongs to the positive or negative class.
# * For each tweet, sum up loglikelihoods of each word in the tweet.
# * Also add the logprior to this sum to get the predicted sentiment of that tweet.
#
# $$ p = logprior + \sum_i^N (loglikelihood_i)$$
#
# #### Note
# Note we calculate the prior from the training data, and that the training data is evenly split between positive and negative labels (4000 positive and 4000 negative tweets).  This means that the ratio of positive to negative 1, and the logprior is 0.
#
# The value of 0.0 means that when we add the logprior to the log likelihood, we're just adding zero to the log likelihood.  However, please remember to include the logprior, because whenever the data is not perfectly balanced, the logprior will be a non-zero value.

# %%
# UNQ_C4 GRADED FUNCTION: naive_bayes_predict

def naive_bayes_predict(tweet, logprior, loglikelihood):
    '''
    Input:
        tweet: a string
        logprior: a number
        loglikelihood: a dictionary of words mapping to numbers
    Output:
        p: the sum of all the logliklihoods of each word in the tweet (if found in the dictionary) + logprior (a number)

    '''
    ### START CODE HERE ###
    # process the tweet to get a list of words
    word_l = process_tweet(tweet)

    # initialize probability to zero
    p = 0

    # add the logprior
    p += logprior

    for word in word_l:

        # check if the word exists in the loglikelihood dictionary
        if word in loglikelihood:
            # add the log likelihood of that word to the probability
            p += loglikelihood[word]

    ### END CODE HERE ###

    return p

# %%
# UNQ_C5 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
my_tweet = 'She smiled.'
p = naive_bayes_predict(my_tweet, logprior, loglikelihood)
print('The expected output is', p)
# Out:
# The expected output is 0.5917946862996578

# %% [markdown]
# **Expected Output**:
# - The expected output is around 1.55
# - The sentiment is positive.

# %%
# UNQ_C5 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
my_tweet = 'bjp party ghatiya soch rakhti hai'
p = naive_bayes_predict(my_tweet, logprior, loglikelihood)
print('The expected output is', p)
# Out:
# The expected output is -1.5218028993768866

# %%
# Experiment with your own tweet.
my_tweet = 'bjp accha kam kr rhi hai'
p = naive_bayes_predict(my_tweet, logprior, loglikelihood)
print('The expected output is', p)
# Out:
# The expected output is 0.13144902260093805

# %% [markdown]
# <a name='ex-4'></a>
# ### Exercise 4 - test_naive_bayes
# Implement test_naive_bayes.
#
# **Instructions**:
# * Implement `test_naive_bayes` to check the accuracy of your predictions.
# * The function takes in your `test_x`, `test_y`, log_prior, and loglikelihood
# * It returns the accuracy of your model.
# * First, use `naive_bayes_predict` function to make predictions for each tweet in text_x.

# %%
# UNQ_C6 GRADED FUNCTION: test_naive_bayes

def test_naive_bayes(test_x, test_y, logprior, loglikelihood, naive_bayes_predict=naive_bayes_predict):
    """
    Input:
        test_x: A list of tweets
        test_y: the corresponding labels for the list of tweets
        logprior: the logprior
        loglikelihood: a dictionary with the loglikelihoods for each word
    Output:
        accuracy: (# of tweets classified correctly)/(total # of tweets)
    """
    accuracy = 0  # return this properly
    dictss={}
    ### START CODE HERE ###
    y_hats = []
    for tweet in test_x:
        # if the prediction is > 0
        if naive_bayes_predict(tweet, logprior, loglikelihood) > 0:
            # the predicted class is 1
            y_hat_i = 1
        else:
            # otherwise the predicted class is 0
            y_hat_i = 0

        # append the predicted class to the list y_hats
        y_hats.append(y_hat_i)

    # error is the average of the absolute values of the differences between y_hats and test_y
    error = np.sum(np.squeeze(np.asarray(y_hats)) != np.squeeze(test_y))/len(test_y)

    # Accuracy is 1 minus the error
    accuracy = 1 - error

    ### END CODE HERE ###

    return accuracy

# %%
print("Naive Bayes accuracy = %0.4f" %
      (test_naive_bayes(test_x, test_y, logprior, loglikelihood)))
# Out:
# Naive Bayes accuracy = 0.6251

# %%
# UNQ_C7 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
# Run this cell to test your function
for tweet in ['I am happy', 'I am bad', 'this movie should have been great.', 'great', 'great great', 'great great great', 'great great great great']:
    # print( '%s -> %f' % (tweet, naive_bayes_predict(tweet, logprior, loglikelihood)))
    p = naive_bayes_predict(tweet, logprior, loglikelihood)
#     print(f'{tweet} -> {p:.2f} ({p_category})')
    print(f'{tweet} -> {p:.2f}')
# Out:
# I am happy -> 0.98
# I am bad -> 0.63
# this movie should have been great. -> 0.60
# great -> 0.98
# great great -> 1.37
# great great great -> 1.76
# great great great great -> 2.15

# %%
for tweet in test_pos[60:70]: 
    p = naive_bayes_predict(tweet, logprior, loglikelihood)
    print(f'{tweet} -> {p:.2f}')
# Out:
# India mai baap se phele beta ajata hai Rape se jabi 14th August or 15th August ka difference pata nai, Rape jo bhut huta hai -> 3.30
# Sir ap raw ko samjha de wo pak mein kalbhoshan jese pithu bhejna band krde terrorism khud khatam hojae gi.umar pachpan ki harkate bachon si https://twitter.com/chintskap/status/875447907922567170 … -> 4.78
# ya allah hitler jesa hukmaran de sdo thatta ko sharm nai roz jamah masjid ki light kharab hoti he or ye log ac room se nikulte tuk nai inko -> -1.92
# @rssurjewala jinke khoon mein hai desh or deshwasiyo se gadaari wo hai congress saari. -> -0.68
# Aapki soch ko aap k followers ne bhi reject kar diya. Sirf 1400 kuch logo'n ne pasand ki aur taqreeban 1500 RTs, nafrat chore'n Insan bane'n https://twitter.com/chintskap/status/875447907922567170 … -> 3.46
# jinke khoon mein hai desh or deshwasiyo se gadaari wo hai congress saari. -> -0.68
# aik baat tay hai, india ka media jitni hatred dikhata hai Pakistani media nahin dikhata. Game hai, game ki tarah lo -> 0.24
# Behen ki loudi tumhare me to legal rape krte h... bhai behen ka chutiya -> -2.35
# Thatha inka alane unara  kastha mega medha hate pakana pettandi... -> 0.97
# Ye Sab chakkar rajnitee k hain ... Dilon mai nafrat ye log he dalte hain dono country k citizens k ... -> -0.07

# %% [markdown]
# **Expected Output**:
# - I am happy -> 2.14
# - I am bad -> -1.31
# - this movie should have been great. -> 2.12
# - great -> 2.13
# - great great -> 4.26
# - great great great -> 6.39
# - great great great great -> 8.52

# %%
for tweet in test_neg[1:5]: 
    p = naive_bayes_predict(tweet, logprior, loglikelihood)
    print(f'{tweet} -> {p:.2f}')
# Out:
# Madarchod Saale gang rape ki paidayish -> 0.86
# bs kr de taao hate speech ki -> 0.74
# Kashmir mai Jo ho raha hai Kiya wo terrorism nahi -> 3.54
# Toilet  nahi Isliye Tu Bahot rape hotay wahan  Rishi kapoor Ranbir Kis ka Beata Hain Haha shakti kapoor yeh Gulshan yeh Amitab -> 3.32

# %%
# Feel free to check the sentiment of your own tweet below
my_tweet = 'you are bad :('
naive_bayes_predict(my_tweet, logprior, loglikelihood)
# Out:
# -0.18328037283401155

# %% [markdown]
# <a name='4'></a>
# ## 4 - Filter words by Ratio of Positive to Negative Counts
#
# - Some words have more positive counts than others, and can be considered "more positive".  Likewise, some words can be considered more negative than others.
# - One way for us to define the level of positiveness or negativeness, without calculating the log likelihood, is to compare the positive to negative frequency of the word.
#     - Note that we can also use the log likelihood calculations to compare relative positivity or negativity of words.
# - We can calculate the ratio of positive to negative frequencies of a word.
# - Once we're able to calculate these ratios, we can also filter a subset of words that have a minimum ratio of positivity / negativity or higher.
# - Similarly, we can also filter a subset of words that have a maximum ratio of positivity / negativity or lower (words that are at least as negative, or even more negative than a given threshold).
#
# <a name='ex-5'></a>
# ### Exercise 5 - get_ratio
# Implement get_ratio.
#
# - Given the freqs dictionary of words and a particular word, use `lookup(freqs,word,1)` to get the positive count of the word.
# - Similarly, use the `lookup` function to get the negative count of that word.
# - Calculate the ratio of positive divided by negative counts
#
# $$ ratio = \frac{\text{pos_words} + 1}{\text{neg_words} + 1} $$
#
# Where pos_words and neg_words correspond to the frequency of the words in their respective classes.
# <table>
#     <tr>
#         <td>
#             <b>Words</b>
#         </td>
#         <td>
#         Positive word count
#         </td>
#          <td>
#         Negative Word Count
#         </td>
#   </tr>
#     <tr>
#         <td>
#         glad
#         </td>
#          <td>
#         41
#         </td>
#     <td>
#         2
#         </td>
#   </tr>
#     <tr>
#         <td>
#         arriv
#         </td>
#          <td>
#         57
#         </td>
#     <td>
#         4
#         </td>
#   </tr>
#     <tr>
#         <td>
#         :(
#         </td>
#          <td>
#         1
#         </td>
#     <td>
#         3663
#         </td>
#   </tr>
#     <tr>
#         <td>
#         :-(
#         </td>
#          <td>
#         0
#         </td>
#     <td>
#         378
#         </td>
#   </tr>
# </table>

# %%
# UNQ_C8 GRADED FUNCTION: get_ratio

def get_ratio(freqs, word):
    '''
    Input:
        freqs: dictionary containing the words

    Output: a dictionary with keys 'positive', 'negative', and 'ratio'.
        Example: {'positive': 10, 'negative': 20, 'ratio': 0.5}
    '''
    pos_neg_ratio = {'positive': 0, 'negative': 0, 'ratio': 0.0}
    ### START CODE HERE ###
    # use lookup() to find positive counts for the word (denoted by the integer 1)
    pos_neg_ratio['positive'] = lookup(freqs,word,1)
    
    # use lookup() to find negative counts for the word (denoted by integer 0)
    pos_neg_ratio['negative'] = lookup(freqs,word,0)
    
    # calculate the ratio of positive to negative counts for the word
    pos_neg_ratio['ratio'] = (lookup(freqs,word,1)+1) / (lookup(freqs,word,0)+1)
    ### END CODE HERE ###
    return pos_neg_ratio

# %%
get_ratio(freqs, 'happi')
# Out:
# {'positive': 0, 'negative': 0, 'ratio': 1.0}

# %% [markdown]
# <a name='ex-6'></a>
# ### Exercise 6 - get_words_by_threshold
# Implement get_words_by_threshold(freqs,label,threshold)
#
# * If we set the label to 1, then we'll look for all words whose threshold of positive/negative is at least as high as that threshold, or higher.
# * If we set the label to 0, then we'll look for all words whose threshold of positive/negative is at most as low as the given threshold, or lower.
# * Use the `get_ratio` function to get a dictionary containing the positive count, negative count, and the ratio of positive to negative counts.
# * Append the `get_ratio` dictionary inside another dictinoary, where the key is the word, and the value is the dictionary `pos_neg_ratio` that is returned by the `get_ratio` function.
# An example key-value pair would have this structure:
# ```
# {'happi':
#     {'positive': 10, 'negative': 20, 'ratio': 0.524}
# }
# ```

# %%
# UNQ_C9 GRADED FUNCTION: get_words_by_threshold

def get_words_by_threshold(freqs, label, threshold, get_ratio=get_ratio):
    '''
    Input:
        freqs: dictionary of words
        label: 1 for positive, 0 for negative
        threshold: ratio that will be used as the cutoff for including a word in the returned dictionary
    Output:
        word_list: dictionary containing the word and information on its positive count, negative count, and ratio of positive to negative counts.
        example of a key value pair:
        {'happi':
            {'positive': 10, 'negative': 20, 'ratio': 0.5}
        }
    '''
    word_list = {}

    ### START CODE HERE ###
    for key in freqs.keys():
        word= key[0]

        # get the positive/negative ratio for a word
        pos_neg_ratio = get_ratio(freqs, word)

        # if the label is 1 and the ratio is greater than or equal to the threshold...
        if label == 1 and pos_neg_ratio['ratio'] >= threshold:
        
            # Add the pos_neg_ratio to the dictionary
            word_list[word] = pos_neg_ratio

        # If the label is 0 and the pos_neg_ratio is less than or equal to the threshold...
        elif label == 0 and pos_neg_ratio['ratio'] <= threshold:
        
            # Add the pos_neg_ratio to the dictionary
            word_list[word] = pos_neg_ratio

        # otherwise, do not include this word in the list (do nothing)

    ### END CODE HERE ###
    return word_list

# %%
# Test your function: find negative words at or below a threshold
get_words_by_threshold(freqs, label=0, threshold=5)
# Out:
# {'knowing': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'ki': {'positive': 737, 'negative': 590, 'ratio': 1.248730964467005},
#  'vikas': {'positive': 27, 'negative': 27, 'ratio': 1.0},
#  'kitna': {'positive': 21, 'negative': 15, 'ratio': 1.375},
#  'samjhata': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'hai': {'positive': 1556, 'negative': 984, 'ratio': 1.5807106598984773},
#  'priyanka': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'aur': {'positive': 512, 'negative': 319, 'ratio': 1.603125},
#  'itch': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'guard': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'luv': {'positive': 8, 'negative': 7, 'ratio': 1.125},
#  'ko': {'positive': 742, 'negative': 480, 'ratio': 1.5446985446985446},
#  'usne': {'positive': 12, 'negative': 17, 'ratio': 0.7222222222222222},
#  'bola': {'positive': 34, 'negative': 17, 'ratio': 1.9444444444444444},
#  'tha': {'positive': 175, 'negative': 124, 'ratio': 1.408},
#  'ben': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'wali': {'positive': 21, 'negative': 14, 'ratio': 1.4666666666666666},
#  'baat': {'positive': 97, 'negative': 73, 'ratio': 1.3243243243243243},
#  'ab': {'positive': 124, 'negative': 89, 'ratio': 1.3888888888888888},
#  'sallu': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'ne': {'positive': 218, 'negative': 151, 'ratio': 1.4407894736842106},
#  'bhi': {'positive': 469, 'negative': 296, 'ratio': 1.5824915824915824},
#  'agree': {'positive': 3, 'negative': 1, 'ratio': 2.0},
#  'kiya': {'positive': 155, 'negative': 126, 'ratio': 1.2283464566929134},
#  'muhajir': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  '..': {'positive': 355, 'negative': 268, 'ratio': 1.3234200743494424},
#  'mere': {'positive': 30, 'negative': 12, 'ratio': 2.3846153846153846},
#  'lye': {'positive': 3, 'negative': 2, 'ratio': 1.3333333333333333},
#  'sab': {'positive': 115, 'negative': 66, 'ratio': 1.7313432835820894},
#  'se': {'positive': 573, 'negative': 409, 'ratio': 1.4},
#  'pehly': {'positive': 4, 'negative': 2, 'ratio': 1.6666666666666667},
#  'pakistan': {'positive': 99, 'negative': 47, 'ratio': 2.0833333333333335},
#  'agr': {'positive': 18, 'negative': 5, 'ratio': 3.1666666666666665},
#  '10': {'positive': 12, 'negative': 9, 'ratio': 1.3},
#  'lakh': {'positive': 9, 'negative': 2, 'ratio': 3.3333333333333335},
#  'altaf': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  'jese': {'positive': 5, 'negative': 9, 'ratio': 0.6},
#  'leaders': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'bh': {'positive': 4, 'negative': 2, 'ratio': 1.6666666666666667},
#  'zameen': {'positive': 1, 'negative': 4, 'ratio': 0.4},
#  'behurmati': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'kren': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'un': {'positive': 21, 'negative': 21, 'ratio': 1.0},
#  'sbko': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'sar': {'positive': 3, 'negative': 5, 'ratio': 0.6666666666666666},
#  'e': {'positive': 12, 'negative': 7, 'ratio': 1.625},
#  'aam': {'positive': 8, 'negative': 8, 'ratio': 1.0},
#  'phansi': {'positive': 26, 'negative': 12, 'ratio': 2.076923076923077},
#  'deni': {'positive': 8, 'negative': 3, 'ratio': 2.25},
#  'chahye': {'positive': 3, 'negative': 2, 'ratio': 1.3333333333333333},
#  'proud': {'positive': 3, 'negative': 0, 'ratio': 4.0},
#  'pakistani': {'positive': 18, 'negative': 12, 'ratio': 1.4615384615384615},
#  'doctor': {'positive': 3, 'negative': 1, 'ratio': 2.0},
#  'sahi': {'positive': 43, 'negative': 26, 'ratio': 1.6296296296296295},
#  'ke': {'positive': 670, 'negative': 410, 'ratio': 1.632603406326034},
#  'phd': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'hate': {'positive': 469, 'negative': 483, 'ratio': 0.9710743801652892},
#  'politics': {'positive': 4, 'negative': 4, 'ratio': 1.0},
#  'wale': {'positive': 48, 'negative': 53, 'ratio': 0.9074074074074074},
#  'bhai': {'positive': 174, 'negative': 80, 'ratio': 2.1604938271604937},
#  'padhe': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'likhe': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  'ho': {'positive': 556, 'negative': 357, 'ratio': 1.5558659217877095},
#  'fir': {'positive': 46, 'negative': 31, 'ratio': 1.46875},
#  'kyu': {'positive': 55, 'negative': 33, 'ratio': 1.6470588235294117},
#  'ye': {'positive': 260, 'negative': 217, 'ratio': 1.1972477064220184},
#  'baate': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  'karte': {'positive': 109, 'negative': 103, 'ratio': 1.0576923076923077},
#  'tum': {'positive': 153, 'negative': 124, 'ratio': 1.232},
#  'bas': {'positive': 30, 'negative': 17, 'ratio': 1.7222222222222223},
#  'bowling': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'khelo': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'maje': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'lo': {'positive': 29, 'negative': 20, 'ratio': 1.4285714285714286},
#  'pic.twitter.com/fk1qubqstw': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'poore': {'positive': 5, 'negative': 1, 'ratio': 3.0},
#  'desh': {'positive': 106, 'negative': 90, 'ratio': 1.1758241758241759},
#  'patel': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'obc': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  'aate': {'positive': 10, 'negative': 6, 'ratio': 1.5714285714285714},
#  'hain': {'positive': 265, 'negative': 173, 'ratio': 1.528735632183908},
#  'sirf': {'positive': 93, 'negative': 47, 'ratio': 1.9583333333333333},
#  'gujrat': {'positive': 6, 'negative': 2, 'ratio': 2.3333333333333335},
#  'chor': {'positive': 20, 'negative': 15, 'ratio': 1.3125},
#  'kar': {'positive': 292, 'negative': 203, 'ratio': 1.4362745098039216},
#  'may': {'positive': 16, 'negative': 7, 'ratio': 2.125},
#  'manuwadiyon': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'bramanwadi': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'kabhi': {'positive': 64, 'negative': 51, 'ratio': 1.25},
#  'aapko': {'positive': 19, 'negative': 7, 'ratio': 2.5},
#  'aarackchan': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'nahi': {'positive': 466, 'negative': 251, 'ratio': 1.8531746031746033},
#  'denge': {'positive': 10, 'negative': 9, 'ratio': 1.1},
#  'jis': {'positive': 30, 'negative': 32, 'ratio': 0.9393939393939394},
#  'mila': {'positive': 8, 'negative': 6, 'ratio': 1.2857142857142858},
#  'usse': {'positive': 16, 'negative': 10, 'ratio': 1.5454545454545454},
#  'nafrat': {'positive': 118, 'negative': 78, 'ratio': 1.5063291139240507},
#  'khoon': {'positive': 133, 'negative': 41, 'ratio': 3.1904761904761907},
#  'chamdi': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'ka': {'positive': 763, 'negative': 448, 'ratio': 1.7015590200445434},
#  'frak': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'karne': {'positive': 111, 'negative': 65, 'ratio': 1.696969696969697},
#  'waale': {'positive': 8, 'negative': 4, 'ratio': 1.8},
#  'bharmhanwadi': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'kisi': {'positive': 100, 'negative': 81, 'ratio': 1.2317073170731707},
#  'sage': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'ek': {'positive': 200, 'negative': 107, 'ratio': 1.8611111111111112},
#  'dil': {'positive': 35, 'negative': 13, 'ratio': 2.5714285714285716},
#  'jaan': {'positive': 20, 'negative': 5, 'ratio': 3.5},
#  'akal': {'positive': 6, 'negative': 3, 'ratio': 1.75},
#  'imitihaan': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'kal': {'positive': 28, 'negative': 18, 'ratio': 1.5263157894736843},
#  'kp': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'rape': {'positive': 1241, 'negative': 685, 'ratio': 1.8104956268221575},
#  'sawing': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'two': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'legs': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'honge': {'positive': 8, 'negative': 6, 'ratio': 1.2857142857142858},
#  'justified': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'due': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  'cinematic': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'liberty': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'aaj': {'positive': 92, 'negative': 47, 'ratio': 1.9375},
#  'toh': {'positive': 146, 'negative': 73, 'ratio': 1.9864864864864864},
#  'rajput': {'positive': 10, 'negative': 5, 'ratio': 1.8333333333333333},
#  'gayi': {'positive': 31, 'negative': 14, 'ratio': 2.1333333333333333},
#  'shaan': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'urdu': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'gulaam': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'sorry': {'positive': 4, 'negative': 3, 'ratio': 1.25},
#  'say': {'positive': 28, 'negative': 18, 'ratio': 1.5263157894736843},
#  'saaf': {'positive': 7, 'negative': 4, 'ratio': 1.6},
#  'shilpa': {'positive': 49, 'negative': 61, 'ratio': 0.8064516129032258},
#  'fans': {'positive': 17, 'negative': 7, 'ratio': 2.25},
#  'hiten': {'positive': 5, 'negative': 1, 'ratio': 3.0},
#  'mein': {'positive': 161, 'negative': 88, 'ratio': 1.8202247191011236},
#  'kya': {'positive': 260, 'negative': 190, 'ratio': 1.3664921465968587},
#  'woh': {'positive': 41, 'negative': 36, 'ratio': 1.135135135135135},
#  'samjhte': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'hadh': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'hoti': {'positive': 47, 'negative': 46, 'ratio': 1.0212765957446808},
#  'bahut': {'positive': 37, 'negative': 25, 'ratio': 1.4615384615384615},
#  'sochsamajhkr': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'mai': {'positive': 103, 'negative': 70, 'ratio': 1.4647887323943662},
#  'ess': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'tarq': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'pe': {'positive': 110, 'negative': 77, 'ratio': 1.4230769230769231},
#  'purey': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  '42mahino': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'mei': {'positive': 22, 'negative': 20, 'ratio': 1.0952380952380953},
#  'pahucha': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'hoon': {'positive': 10, 'negative': 6, 'ratio': 1.5714285714285714},
#  'k': {'positive': 394, 'negative': 276, 'ratio': 1.4259927797833936},
#  'asli': {'positive': 4, 'negative': 5, 'ratio': 0.8333333333333334},
#  'wajah': {'positive': 19, 'negative': 13, 'ratio': 1.4285714285714286},
#  'muslim': {'positive': 46, 'negative': 33, 'ratio': 1.3823529411764706},
#  'hatred': {'positive': 22, 'negative': 5, 'ratio': 3.8333333333333335},
#  'jo': {'positive': 204, 'negative': 141, 'ratio': 1.443661971830986},
#  'kabi': {'positive': 4, 'negative': 1, 'ratio': 2.5},
#  'partition': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'ramtemple': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'gaumata': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'bharatmaatakijai': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'vandematram': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'raastragan': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'pak': {'positive': 32, 'negative': 23, 'ratio': 1.375},
#  'premi': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'gaddaar': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'bachche': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'jyada': {'positive': 26, 'negative': 19, 'ratio': 1.35},
#  '5bibiya25bachche': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'safar': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'tai': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'huey': {'positive': 3, 'negative': 1, 'ratio': 2.0},
#  'tajmahal': {'positive': 3, 'negative': 0, 'ratio': 4.0},
#  'p': {'positive': 11, 'negative': 6, 'ratio': 1.7142857142857142},
#  'jake': {'positive': 4, 'negative': 8, 'ratio': 0.5555555555555556},
#  'atka': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'ha': {'positive': 77, 'negative': 47, 'ratio': 1.625},
#  'rem': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'emoji': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  'mujhe': {'positive': 42, 'negative': 38, 'ratio': 1.1025641025641026},
#  'nagini': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'hi': {'positive': 303, 'negative': 219, 'ratio': 1.3818181818181818},
#  'yaad': {'positive': 13, 'negative': 8, 'ratio': 1.5555555555555556},
#  'aati': {'positive': 9, 'negative': 13, 'ratio': 0.7142857142857143},
#  'sir': {'positive': 96, 'negative': 27, 'ratio': 3.4642857142857144},
#  'apki': {'positive': 8, 'negative': 6, 'ratio': 1.2857142857142858},
#  'fav': {'positive': 3, 'negative': 1, 'ratio': 2.0},
#  'kon': {'positive': 39, 'negative': 16, 'ratio': 2.3529411764705883},
#  'iss': {'positive': 17, 'negative': 12, 'ratio': 1.3846153846153846},
#  'seasn': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'mehanat': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'school': {'positive': 7, 'negative': 2, 'ratio': 2.6666666666666665},
#  'copy': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  'karke': {'positive': 25, 'negative': 22, 'ratio': 1.1304347826086956},
#  'likhne': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'b': {'positive': 55, 'negative': 31, 'ratio': 1.75},
#  'lagti': {'positive': 6, 'negative': 4, 'ratio': 1.4},
#  'illegal': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'atanki': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'paise': {'positive': 8, 'negative': 13, 'ratio': 0.6428571428571429},
#  'lekar': {'positive': 3, 'negative': 6, 'ratio': 0.5714285714285714},
#  'ghar': {'positive': 36, 'negative': 30, 'ratio': 1.1935483870967742},
#  'aurato': {'positive': 4, 'negative': 7, 'ratio': 0.625},
#  'smman': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'bech': {'positive': 3, 'negative': 5, 'ratio': 0.6666666666666666},
#  'doge': {'positive': 9, 'negative': 1, 'ratio': 5.0},
#  'liye': {'positive': 164, 'negative': 115, 'ratio': 1.4224137931034482},
#  'aap': {'positive': 200, 'negative': 93, 'ratio': 2.1382978723404253},
#  'ladla': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'wo': {'positive': 157, 'negative': 75, 'ratio': 2.0789473684210527},
#  'hay': {'positive': 24, 'negative': 14, 'ratio': 1.6666666666666667},
#  'fard': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'jurm': {'positive': 3, 'negative': 2, 'ratio': 1.3333333333333333},
#  'kay': {'positive': 29, 'negative': 21, 'ratio': 1.3636363636363635},
#  'bad': {'positive': 23, 'negative': 16, 'ratio': 1.411764705882353},
#  'girftar': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'hota': {'positive': 147, 'negative': 82, 'ratio': 1.783132530120482},
#  'money': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  'trail': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'deta': {'positive': 17, 'negative': 10, 'ratio': 1.6363636363636365},
#  'saza': {'positive': 17, 'negative': 6, 'ratio': 2.5714285714285716},
#  'murder': {'positive': 108, 'negative': 49, 'ratio': 2.18},
#  'karta': {'positive': 60, 'negative': 46, 'ratio': 1.297872340425532},
#  'barun': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'comeback': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'show': {'positive': 14, 'negative': 23, 'ratio': 0.625},
#  'koi': {'positive': 193, 'negative': 150, 'ratio': 1.2847682119205297},
#  'q': {'positive': 22, 'negative': 15, 'ratio': 1.4375},
#  'dekhna': {'positive': 12, 'negative': 7, 'ratio': 1.625},
#  'chahega': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'lekin': {'positive': 43, 'negative': 28, 'ratio': 1.5172413793103448},
#  'dekh': {'positive': 44, 'negative': 28, 'ratio': 1.5517241379310345},
#  'paye': {'positive': 5, 'negative': 2, 'ratio': 2.0},
#  '...': {'positive': 409, 'negative': 372, 'ratio': 1.0991957104557641},
#  'shivani': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'karu': {'positive': 3, 'negative': 3, 'ratio': 1.0},
#  'muze': {'positive': 2, 'negative': 4, 'ratio': 0.6},
#  'uski': {'positive': 20, 'negative': 7, 'ratio': 2.625},
#  'acting': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'achchi': {'positive': 4, 'negative': 0, 'ratio': 5.0},
#  'lagi': {'positive': 6, 'negative': 4, 'ratio': 1.4},
#  'laga': {'positive': 29, 'negative': 18, 'ratio': 1.5789473684210527},
#  'maine': {'positive': 23, 'negative': 13, 'ratio': 1.7142857142857142},
#  'kaha': {'positive': 54, 'negative': 30, 'ratio': 1.7741935483870968},
#  'mera': {'positive': 19, 'negative': 16, 'ratio': 1.1764705882352942},
#  'opinion': {'positive': 3, 'negative': 0, 'ratio': 4.0},
#  'ji': {'positive': 108, 'negative': 52, 'ratio': 2.056603773584906},
#  'possible': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'dono': {'positive': 10, 'negative': 17, 'ratio': 0.6111111111111112},
#  'rasta': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'sarhad': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'lakir': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'mita': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'khatam': {'positive': 32, 'negative': 12, 'ratio': 2.5384615384615383},
#  'sakta': {'positive': 31, 'negative': 21, 'ratio': 1.4545454545454546},
#  'jinna': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'sahab': {'positive': 11, 'negative': 4, 'ratio': 2.4},
#  'mar': {'positive': 20, 'negative': 25, 'ratio': 0.8076923076923077},
#  'gaye': {'positive': 39, 'negative': 25, 'ratio': 1.5384615384615385},
#  'neharu': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'kartay': {'positive': 5, 'negative': 7, 'ratio': 0.75},
#  'mulk': {'positive': 27, 'negative': 8, 'ratio': 3.111111111111111},
#  'akhand': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'bharat': {'positive': 30, 'negative': 17, 'ratio': 1.7222222222222223},
#  '…': {'positive': 152, 'negative': 81, 'ratio': 1.8658536585365855},
#  'achha': {'positive': 8, 'negative': 4, 'ratio': 1.8},
#  'bta': {'positive': 3, 'negative': 2, 'ratio': 1.3333333333333333},
#  'diya': {'positive': 76, 'negative': 59, 'ratio': 1.2833333333333334},
#  'hum': {'positive': 85, 'negative': 39, 'ratio': 2.15},
#  'n': {'positive': 34, 'negative': 34, 'ratio': 1.0},
#  'nhi': {'positive': 164, 'negative': 130, 'ratio': 1.2595419847328244},
#  'dekha': {'positive': 28, 'negative': 18, 'ratio': 1.5263157894736843},
#  'khbri': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'krta': {'positive': 13, 'negative': 16, 'ratio': 0.8235294117647058},
#  'kuch': {'positive': 127, 'negative': 98, 'ratio': 1.292929292929293},
#  'ni': {'positive': 44, 'negative': 26, 'ratio': 1.6666666666666667},
#  'maa': {'positive': 53, 'negative': 48, 'ratio': 1.1020408163265305},
#  'bnta': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'h': {'positive': 211, 'negative': 199, 'ratio': 1.06},
#  'kr': {'positive': 104, 'negative': 48, 'ratio': 2.142857142857143},
#  'hina': {'positive': 55, 'negative': 52, 'ratio': 1.0566037735849056},
#  'kaahe': {'positive': 3, 'negative': 1, 'ratio': 2.0},
#  'hindu': {'positive': 76, 'negative': 65, 'ratio': 1.1666666666666667},
#  'bhamhanwadi': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'bus': {'positive': 11, 'negative': 7, 'ratio': 1.5},
#  'aj': {'positive': 25, 'negative': 12, 'ratio': 2.0},
#  'arshi': {'positive': 10, 'negative': 25, 'ratio': 0.4230769230769231},
#  'laat': {'positive': 3, 'negative': 2, 'ratio': 1.3333333333333333},
#  'eske': {'positive': 3, 'negative': 0, 'ratio': 4.0},
#  'pichwade': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'mari': {'positive': 5, 'negative': 2, 'ratio': 2.0},
#  'thi': {'positive': 59, 'negative': 42, 'ratio': 1.3953488372093024},
#  'photo': {'positive': 1, 'negative': 4, 'ratio': 0.4},
#  'twit': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'kro': {'positive': 26, 'negative': 16, 'ratio': 1.588235294117647},
#  'juldi': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'ar': {'positive': 5, 'negative': 7, 'ratio': 0.75},
#  'tag': {'positive': 6, 'negative': 1, 'ratio': 3.5},
#  'kon-kon': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'esh': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'hyena': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'munh': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'haddi': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'dalna': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'chahta': {'positive': 4, 'negative': 1, 'ratio': 2.5},
#  'ya': {'positive': 87, 'negative': 50, 'ratio': 1.7254901960784315},
#  'marna': {'positive': 3, 'negative': 4, 'ratio': 0.8},
#  'gf': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'peene': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'apne': {'positive': 78, 'negative': 60, 'ratio': 1.2950819672131149},
#  'babu': {'positive': 4, 'negative': 1, 'ratio': 2.5},
#  'thana': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'thilane': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'abe': {'positive': 14, 'negative': 17, 'ratio': 0.8333333333333334},
#  'bigg': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'boss': {'positive': 4, 'negative': 5, 'ratio': 0.8333333333333334},
#  'baki': {'positive': 7, 'negative': 4, 'ratio': 1.6},
#  'contestants': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'related': {'positive': 4, 'negative': 0, 'ratio': 5.0},
#  'news': {'positive': 27, 'negative': 11, 'ratio': 2.3333333333333335},
#  'sari': {'positive': 8, 'negative': 3, 'ratio': 2.25},
#  'updates': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'khabari': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'chabar': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'rehta': {'positive': 2, 'negative': 4, 'ratio': 0.6},
#  'bare': {'positive': 16, 'negative': 7, 'ratio': 2.125},
#  'stone': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'miracle': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'hazrat': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'imam': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'hussain': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'ra': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  'pathar': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'abhi': {'positive': 48, 'negative': 30, 'ratio': 1.5806451612903225},
#  'tak': {'positive': 79, 'negative': 22, 'ratio': 3.4782608695652173},
#  'behta': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'via': {'positive': 12, 'negative': 2, 'ratio': 4.333333333333333},
#  'pappu': {'positive': 6, 'negative': 3, 'ratio': 1.75},
#  'saja': {'positive': 14, 'negative': 3, 'ratio': 3.75},
#  'kam': {'positive': 42, 'negative': 32, 'ratio': 1.303030303030303},
#  '. ..': {'positive': 2, 'negative': 4, 'ratio': 0.6},
#  'looted': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'wapas': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'chaiya': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'log': {'positive': 149, 'negative': 119, 'ratio': 1.25},
#  'america': {'positive': 4, 'negative': 1, 'ratio': 2.5},
#  'dalali': {'positive': 3, 'negative': 3, 'ratio': 1.0},
#  'karto': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'agar': {'positive': 81, 'negative': 46, 'ratio': 1.7446808510638299},
#  'isse': {'positive': 12, 'negative': 4, 'ratio': 2.6},
#  'love': {'positive': 44, 'negative': 10, 'ratio': 4.090909090909091},
#  'kehte': {'positive': 12, 'negative': 8, 'ratio': 1.4444444444444444},
#  'bc': {'positive': 15, 'negative': 10, 'ratio': 1.4545454545454546},
#  'pehli': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  'baar': {'positive': 31, 'negative': 15, 'ratio': 2.0},
#  'kisne': {'positive': 7, 'negative': 3, 'ratio': 2.0},
#  'hail': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'hitler': {'positive': 19, 'negative': 3, 'ratio': 5.0},
#  'adolfhitler': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'sadakchaap': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'wala': {'positive': 41, 'negative': 19, 'ratio': 2.1},
#  'gaaliyan': {'positive': 4, 'negative': 0, 'ratio': 5.0},
#  'dete': {'positive': 33, 'negative': 24, 'ratio': 1.36},
#  'provinces': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'banana': {'positive': 7, 'negative': 1, 'ratio': 4.0},
#  'achi': {'positive': 9, 'negative': 4, 'ratio': 2.0},
#  'magar': {'positive': 13, 'negative': 6, 'ratio': 2.0},
#  'bun': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'jana': {'positive': 6, 'negative': 4, 'ratio': 1.4},
#  'fakhar': {'positive': 3, 'negative': 0, 'ratio': 4.0},
#  'hui': {'positive': 27, 'negative': 13, 'ratio': 2.0},
#  'na': {'positive': 205, 'negative': 116, 'ratio': 1.7606837606837606},
#  'acha': {'positive': 22, 'negative': 20, 'ratio': 1.0952380952380953},
#  'tou': {'positive': 31, 'negative': 24, 'ratio': 1.28},
#  'per': {'positive': 38, 'negative': 16, 'ratio': 2.2941176470588234},
#  'quota': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'system': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'unko': {'positive': 17, 'negative': 12, 'ratio': 1.3846153846153846},
#  'baher': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'nikala': {'positive': 3, 'negative': 2, 'ratio': 1.3333333333333333},
#  'jaisay': {'positive': 4, 'negative': 3, 'ratio': 1.25},
#  'mohajiron': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'intr': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'sindh': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'unki': {'positive': 18, 'negative': 9, 'ratio': 1.9},
#  'industry': {'positive': 3, 'negative': 1, 'ratio': 2.0},
#  'nationalise': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'hoi': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  'punjabion': {'positive': 4, 'negative': 0, 'ratio': 5.0},
#  'nay': {'positive': 16, 'negative': 7, 'ratio': 2.125},
#  'pukra': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'sindhi': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'pukarty': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'thy': {'positive': 4, 'negative': 3, 'ratio': 1.25},
#  'ny': {'positive': 11, 'negative': 4, 'ratio': 2.4},
#  'qabool': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'kia': {'positive': 44, 'negative': 13, 'ratio': 3.2142857142857144},
#  'lakin': {'positive': 3, 'negative': 1, 'ratio': 2.0},
#  'qabol': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'bhutto': {'positive': 3, 'negative': 1, 'ratio': 2.0},
#  'sb': {'positive': 10, 'negative': 10, 'ratio': 1.0},
#  'juke': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'char': {'positive': 2, 'negative': 3, 'ratio': 0.75},
#  'niazi': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  'kaho': {'positive': 4, 'negative': 2, 'ratio': 1.6666666666666667},
#  'mafi': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'nama': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'wapis': {'positive': 5, 'negative': 4, 'ratio': 1.2},
#  'le': {'positive': 47, 'negative': 25, 'ratio': 1.8461538461538463},
#  'jaye': {'positive': 38, 'negative': 15, 'ratio': 2.4375},
#  'phir': {'positive': 53, 'negative': 26, 'ratio': 2.0},
#  'maanoo': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'gande': {'positive': 4, 'negative': 0, 'ratio': 5.0},
#  'message': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'bi': {'positive': 10, 'negative': 7, 'ratio': 1.375},
#  'chorne': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'pare': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'ge': {'positive': 13, 'negative': 3, 'ratio': 3.5},
#  'pervez': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'musharraf': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'nawaz': {'positive': 9, 'negative': 6, 'ratio': 1.4285714285714286},
#  'shareef': {'positive': 3, 'negative': 4, 'ratio': 0.8},
#  'haramkhoor': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  'choor': {'positive': 4, 'negative': 0, 'ratio': 5.0},
#  'awan': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'paisa': {'positive': 8, 'negative': 6, 'ratio': 1.2857142857142858},
#  'lotnay': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'nahe': {'positive': 4, 'negative': 2, 'ratio': 1.6666666666666667},
#  'atleast': {'positive': 3, 'negative': 0, 'ratio': 4.0},
#  'moto': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'gang': {'positive': 45, 'negative': 12, 'ratio': 3.5384615384615383},
#  'sath': {'positive': 62, 'negative': 63, 'ratio': 0.984375},
#  'country': {'positive': 7, 'negative': 5, 'ratio': 1.3333333333333333},
#  'hote': {'positive': 65, 'negative': 46, 'ratio': 1.4042553191489362},
#  'hn': {'positive': 6, 'negative': 4, 'ratio': 1.4},
#  'wahan': {'positive': 14, 'negative': 6, 'ratio': 2.142857142857143},
#  'qanoon': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  'laagu': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'hona': {'positive': 27, 'negative': 12, 'ratio': 2.1538461538461537},
#  'chahiye': {'positive': 62, 'negative': 27, 'ratio': 2.25},
#  'india': {'positive': 93, 'negative': 72, 'ratio': 1.2876712328767124},
#  'tabhi': {'positive': 18, 'negative': 6, 'ratio': 2.7142857142857144},
#  'darindo': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'ilaaj': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'dont': {'positive': 4, 'negative': 2, 'ratio': 1.6666666666666667},
#  'nanhi': {'positive': 3, 'negative': 0, 'ratio': 4.0},
#  'si': {'positive': 5, 'negative': 7, 'ratio': 0.75},
#  'tu': {'positive': 110, 'negative': 71, 'ratio': 1.5416666666666667},
#  'shocked': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'lat': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'padi': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'ise': {'positive': 9, 'negative': 8, 'ratio': 1.1111111111111112},
#  'jabardast': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'khana': {'positive': 4, 'negative': 4, 'ratio': 1.0},
#  'khayegi': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'zillat': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  'laddu': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'salman': {'positive': 10, 'negative': 11, 'ratio': 0.9166666666666666},
#  'bhijwa': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'diye': {'positive': 13, 'negative': 6, 'ratio': 2.0},
#  'haha': {'positive': 9, 'negative': 3, 'ratio': 2.5},
#  'farzi': {'positive': 5, 'negative': 1, 'ratio': 3.0},
#  'spreading': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'moron': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'blocked': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'vidya': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'bhut': {'positive': 3, 'negative': 2, 'ratio': 1.3333333333333333},
#  'bdi': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  'celebrity': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'ajkaal': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'achcha': {'positive': 3, 'negative': 1, 'ratio': 2.0},
#  'jata': {'positive': 40, 'negative': 21, 'ratio': 1.8636363636363635},
#  'ahmed': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'tarek': {'positive': 3, 'negative': 1, 'ratio': 2.0},
#  'fatah': {'positive': 3, 'negative': 1, 'ratio': 2.0},
#  'jaise': {'positive': 64, 'negative': 51, 'ratio': 1.25},
#  'mahapurusoko': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'mante': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'pahelane': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'apke': {'positive': 5, 'negative': 4, 'ratio': 1.2},
#  'guru': {'positive': 5, 'negative': 3, 'ratio': 1.5},
#  'sakte': {'positive': 21, 'negative': 16, 'ratio': 1.2941176470588236},
#  'vivekanand': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'sakshiat': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'kahete': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'indians': {'positive': 8, 'negative': 6, 'ratio': 1.2857142857142858},
#  'brother': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'mahajiron': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'bhe': {'positive': 11, 'negative': 5, 'ratio': 2.0},
#  'mostly': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'tragedy': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'hain.aur': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'husain': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'qatal': {'positive': 8, 'negative': 7, 'ratio': 1.125},
#  'gharatkar': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'mohajir': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'cause': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'badnaam': {'positive': 6, 'negative': 2, 'ratio': 2.3333333333333335},
#  'dia': {'positive': 10, 'negative': 4, 'ratio': 2.2},
#  'haan': {'positive': 23, 'negative': 11, 'ratio': 2.0},
#  'hm': {'positive': 5, 'negative': 3, 'ratio': 1.5},
#  'tilak': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'dekr': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'chhod': {'positive': 3, 'negative': 1, 'ratio': 2.0},
#  'jalate': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'nahin': {'positive': 32, 'negative': 21, 'ratio': 1.5},
#  'orton': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'baba': {'positive': 29, 'negative': 17, 'ratio': 1.6666666666666667},
#  'krne': {'positive': 24, 'negative': 11, 'ratio': 2.0833333333333335},
#  'pata': {'positive': 59, 'negative': 26, 'ratio': 2.2222222222222223},
#  'kyun': {'positive': 25, 'negative': 18, 'ratio': 1.368421052631579},
#  'farziwal': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'sarkar': {'positive': 19, 'negative': 22, 'ratio': 0.8695652173913043},
#  'har': {'positive': 47, 'negative': 42, 'ratio': 1.1162790697674418},
#  '1': {'positive': 26, 'negative': 12, 'ratio': 2.076923076923077},
#  'par': {'positive': 136, 'negative': 109, 'ratio': 1.2454545454545454},
#  'spa': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'khula': {'positive': 2, 'negative': 3, 'ratio': 0.75},
#  'add': {'positive': 3, 'negative': 2, 'ratio': 1.3333333333333333},
#  'jayenge': {'positive': 7, 'negative': 3, 'ratio': 2.0},
#  'personal': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'srk': {'positive': 16, 'negative': 4, 'ratio': 3.4},
#  'nam': {'positive': 5, 'negative': 5, 'ratio': 1.0},
#  'badnam': {'positive': 6, 'negative': 2, 'ratio': 2.3333333333333335},
#  'rhe': {'positive': 38, 'negative': 28, 'ratio': 1.3448275862068966},
#  'chutiye': {'positive': 8, 'negative': 11, 'ratio': 0.75},
#  'bhakts': {'positive': 3, 'negative': 0, 'ratio': 4.0},
#  'support': {'positive': 14, 'negative': 15, 'ratio': 0.9375},
#  'kaise': {'positive': 21, 'negative': 24, 'ratio': 0.88},
#  'lolll': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'red': {'positive': 3, 'negative': 0, 'ratio': 4.0},
#  'sy': {'positive': 10, 'negative': 3, 'ratio': 2.75},
#  'kyunky': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'tumhe': {'positive': 10, 'negative': 26, 'ratio': 0.4074074074074074},
#  'meray': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'dilay': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'ga': {'positive': 33, 'negative': 10, 'ratio': 3.090909090909091},
#  '<3': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'main': {'positive': 127, 'negative': 69, 'ratio': 1.8285714285714285},
#  'apko': {'positive': 15, 'negative': 3, 'ratio': 4.0},
#  'insan': {'positive': 8, 'negative': 5, 'ratio': 1.5},
#  'samjh': {'positive': 4, 'negative': 7, 'ratio': 0.625},
#  'layak': {'positive': 6, 'negative': 3, 'ratio': 1.75},
#  'balki': {'positive': 3, 'negative': 1, 'ratio': 2.0},
#  'izzat': {'positive': 23, 'negative': 6, 'ratio': 3.4285714285714284},
#  'jisko': {'positive': 3, 'negative': 3, 'ratio': 1.0},
#  'dekhke': {'positive': 3, 'negative': 0, 'ratio': 4.0},
#  'kare': {'positive': 49, 'negative': 15, 'ratio': 3.125},
#  'bahrupiya': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'khasiyat': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  '3': {'positive': 12, 'negative': 9, 'ratio': 1.3},
#  'people': {'positive': 5, 'negative': 3, 'ratio': 1.5},
#  'real': {'positive': 8, 'negative': 3, 'ratio': 2.25},
#  'sapna': {'positive': 2, 'negative': 6, 'ratio': 0.42857142857142855},
#  'akash': {'positive': 7, 'negative': 5, 'ratio': 1.3333333333333333},
#  'hina.baki': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'fake': {'positive': 18, 'negative': 17, 'ratio': 1.0555555555555556},
#  'banwti': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'bb11': {'positive': 7, 'negative': 3, 'ratio': 2.0},
#  'ara': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'bjp': {'positive': 31, 'negative': 39, 'ratio': 0.8},
#  'jila': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'mahamantri': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'sh.dhirendra': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'singh': {'positive': 18, 'negative': 8, 'ratio': 2.111111111111111},
#  'sare': {'positive': 12, 'negative': 15, 'ratio': 0.8125},
#  'road': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'chaap': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'leader': {'positive': 4, 'negative': 2, 'ratio': 1.6666666666666667},
#  'surendra': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'uske': {'positive': 42, 'negative': 30, 'ratio': 1.3870967741935485},
#  'bodyguard': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'rinku': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'udeshye': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'aa': {'positive': 30, 'negative': 24, 'ratio': 1.24},
#  'maarvkar': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'chala': {'positive': 9, 'negative': 12, 'ratio': 0.7692307692307693},
#  'hamari': {'positive': 12, 'negative': 9, 'ratio': 1.3},
#  'karya': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'aise': {'positive': 38, 'negative': 25, 'ratio': 1.5},
#  'baithe': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  'hai.kal': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'pichle': {'positive': 4, 'negative': 0, 'ratio': 5.0},
#  '2': {'positive': 35, 'negative': 9, 'ratio': 3.6},
#  'month': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  'jio': {'positive': 5, 'negative': 1, 'ratio': 3.0},
#  'net': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  '50k': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'online': {'positive': 4, 'negative': 0, 'ratio': 5.0},
#  'dekhe': {'positive': 10, 'negative': 3, 'ratio': 2.75},
#  'buffering': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'bina': {'positive': 17, 'negative': 3, 'ratio': 4.5},
#  'sambhav': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'khuch': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  'twtr': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'v': {'positive': 19, 'negative': 15, 'ratio': 1.25},
#  'shakte': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'apni': {'positive': 90, 'negative': 75, 'ratio': 1.1973684210526316},
#  'ghatiya': {'positive': 4, 'negative': 15, 'ratio': 0.3125},
#  'tweets': {'positive': 7, 'negative': 1, 'ratio': 4.0},
#  'aayi': {'positive': 7, 'negative': 4, 'ratio': 1.6},
#  'humidity': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'mat': {'positive': 36, 'negative': 27, 'ratio': 1.3214285714285714},
#  'hua': {'positive': 107, 'negative': 56, 'ratio': 1.894736842105263},
#  '95': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'case': {'positive': 88, 'negative': 18, 'ratio': 4.684210526315789},
#  'jhut': {'positive': 4, 'negative': 4, 'ratio': 1.0},
#  'fashion': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'ban': {'positive': 32, 'negative': 18, 'ratio': 1.736842105263158},
#  'gaya': {'positive': 84, 'negative': 30, 'ratio': 2.7419354838709675},
#  'fasal': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'mota': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'kamao': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'chutya': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'media': {'positive': 28, 'negative': 17, 'ratio': 1.6111111111111112},
#  'vajah': {'positive': 2, 'negative': 3, 'ratio': 0.75},
#  'chatukarta': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'baare': {'positive': 15, 'negative': 5, 'ratio': 2.6666666666666665},
#  'suna': {'positive': 16, 'negative': 5, 'ratio': 2.8333333333333335},
#  'saare': {'positive': 9, 'negative': 6, 'ratio': 1.4285714285714286},
#  'record': {'positive': 4, 'negative': 0, 'ratio': 5.0},
#  'tor': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'lab': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'pehchaan': {'positive': 3, 'negative': 1, 'ratio': 2.0},
#  'yahi': {'positive': 24, 'negative': 19, 'ratio': 1.25},
#  'doosri': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'buri': {'positive': 3, 'negative': 3, 'ratio': 1.0},
#  'zubaan': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'sachchayee': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'imaandaari': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'aqal': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'saheb': {'positive': 4, 'negative': 1, 'ratio': 2.5},
#  '60': {'positive': 3, 'negative': 1, 'ratio': 2.0},
#  'sal.kyabhutta': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'rahe': {'positive': 115, 'negative': 84, 'ratio': 1.3647058823529412},
#  'cort': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'pahle': {'positive': 17, 'negative': 11, 'ratio': 1.5},
#  'karo': {'positive': 78, 'negative': 55, 'ratio': 1.4107142857142858},
#  'forge': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'kanon': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'banwaya': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'aria': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'speed': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  'milta': {'positive': 3, 'negative': 4, 'ratio': 0.8},
#  'aisa': {'positive': 34, 'negative': 15, 'ratio': 2.1875},
#  'video': {'positive': 11, 'negative': 9, 'ratio': 1.2},
#  '4g': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'naam': {'positive': 47, 'negative': 49, 'ratio': 0.96},
#  '2g': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  'mil': {'positive': 15, 'negative': 9, 'ratio': 1.6},
#  'raha': {'positive': 163, 'negative': 95, 'ratio': 1.7083333333333333},
#  'kai': {'positive': 13, 'negative': 6, 'ratio': 2.0},
#  'recharge': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'samapt': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'hone': {'positive': 31, 'negative': 28, 'ratio': 1.103448275862069},
#  'baad': {'positive': 36, 'negative': 22, 'ratio': 1.608695652173913},
#  'chale': {'positive': 5, 'negative': 4, 'ratio': 1.2},
#  'jayege': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'sanitary': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'napkin': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'sasti': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  'pahan': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'fek': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'logo': {'positive': 67, 'negative': 61, 'ratio': 1.096774193548387},
#  'dukan': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'chupke': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'bol': {'positive': 44, 'negative': 31, 'ratio': 1.40625},
#  'andhe': {'positive': 6, 'negative': 2, 'ratio': 2.3333333333333335},
#  'bhakto': {'positive': 4, 'negative': 3, 'ratio': 1.25},
#  'dhik': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'sabhi': {'positive': 16, 'negative': 5, 'ratio': 2.8333333333333335},
#  'jagah': {'positive': 11, 'negative': 6, 'ratio': 1.7142857142857142},
#  'jhgde': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'faila': {'positive': 12, 'negative': 4, 'ratio': 2.6},
#  'suru': {'positive': 3, 'negative': 1, 'ratio': 2.0},
#  'gye': {'positive': 18, 'negative': 10, 'ratio': 1.7272727272727273},
#  '30': {'positive': 3, 'negative': 1, 'ratio': 2.0},
#  'saal': {'positive': 49, 'negative': 30, 'ratio': 1.6129032258064515},
#  'awam': {'positive': 2, 'negative': 8, 'ratio': 0.3333333333333333},
#  'choosnay': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'walay': {'positive': 10, 'negative': 2, 'ratio': 3.6666666666666665},
#  'sharif': {'positive': 4, 'negative': 2, 'ratio': 1.6666666666666667},
#  'brothers': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'saverage': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'nizam': {'positive': 3, 'negative': 0, 'ratio': 4.0},
#  'theak': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'nai': {'positive': 72, 'negative': 36, 'ratio': 1.972972972972973},
#  'sakay': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'election': {'positive': 4, 'negative': 3, 'ratio': 1.25},
#  'pahiley': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'janta': {'positive': 14, 'negative': 11, 'ratio': 1.25},
#  'samne': {'positive': 10, 'negative': 10, 'ratio': 1.0},
#  'tukde': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'fenk': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'karna': {'positive': 84, 'negative': 39, 'ratio': 2.125},
#  'birthday': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'manaye': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'apna': {'positive': 51, 'negative': 30, 'ratio': 1.6774193548387097},
#  'kaam': {'positive': 41, 'negative': 16, 'ratio': 2.4705882352941178},
#  'theek': {'positive': 11, 'negative': 5, 'ratio': 2.0},
#  'sheekho': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'jumlaa': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'humare': {'positive': 11, 'negative': 5, 'ratio': 2.0},
#  'profession': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'make-up': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'lagana': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  'padta': {'positive': 7, 'negative': 5, 'ratio': 1.3333333333333333},
#  'aapki': {'positive': 9, 'negative': 6, 'ratio': 1.4285714285714286},
#  'aadat': {'positive': 3, 'negative': 2, 'ratio': 1.3333333333333333},
#  'chhoot': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'hogi': {'positive': 21, 'negative': 16, 'ratio': 1.2941176470588236},
#  'padmavati': {'positive': 4, 'negative': 7, 'ratio': 0.625},
#  'dusra': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'sunkar': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'kano': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'nikalne': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'waala': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'deepika': {'positive': 5, 'negative': 1, 'ratio': 3.0},
#  'dekhte': {'positive': 11, 'negative': 3, 'ratio': 3.0},
#  'vomiting': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'itni': {'positive': 23, 'negative': 14, 'ratio': 1.6},
#  'ugly': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  'kesi': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'dikh': {'positive': 5, 'negative': 4, 'ratio': 1.2},
#  'sakti': {'positive': 8, 'negative': 9, 'ratio': 0.9},
#  'maara': {'positive': 3, 'negative': 2, 'ratio': 1.3333333333333333},
#  'isliye': {'positive': 19, 'negative': 8, 'ratio': 2.2222222222222223},
#  'jataya': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'zaat': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'paat': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'muhallay': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'aurton': {'positive': 6, 'negative': 3, 'ratio': 1.75},
#  'aik': {'positive': 18, 'negative': 6, 'ratio': 2.7142857142857144},
#  'doosre': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'talwaaron': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'shaheed': {'positive': 4, 'negative': 3, 'ratio': 1.25},
#  'khud': {'positive': 76, 'negative': 66, 'ratio': 1.1492537313432836},
#  'saath': {'positive': 28, 'negative': 29, 'ratio': 0.9666666666666667},
#  'story': {'positive': 13, 'negative': 5, 'ratio': 2.3333333333333335},
#  'stages': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'attitude': {'positive': 2, 'negative': 5, 'ratio': 0.5},
#  'dikhaya': {'positive': 3, 'negative': 2, 'ratio': 1.3333333333333333},
#  'better': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'milke': {'positive': 3, 'negative': 2, 'ratio': 1.3333333333333333},
#  'accha': {'positive': 7, 'negative': 8, 'ratio': 0.8888888888888888},
#  'socho': {'positive': 6, 'negative': 1, 'ratio': 3.5},
#  'acchi': {'positive': 5, 'negative': 2, 'ratio': 2.0},
#  'yuva': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'banao': {'positive': 2, 'negative': 3, 'ratio': 0.75},
#  'progress': {'positive': 3, 'negative': 0, 'ratio': 4.0},
#  'jisse': {'positive': 4, 'negative': 0, 'ratio': 5.0},
#  'taraqqi': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'movie': {'positive': 12, 'negative': 13, 'ratio': 0.9285714285714286},
#  'dekhi': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'sanjay': {'positive': 3, 'negative': 1, 'ratio': 2.0},
#  'leela': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'jaante': {'positive': 3, 'negative': 1, 'ratio': 2.0},
#  'kei': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'saab': {'positive': 4, 'negative': 6, 'ratio': 0.7142857142857143},
#  'raajput': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'krte': {'positive': 34, 'negative': 11, 'ratio': 2.9166666666666665},
#  'filmo': {'positive': 4, 'negative': 1, 'ratio': 2.5},
#  'nicha': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'dikhane': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'moka': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  'chodte': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'bakwaas': {'positive': 4, 'negative': 2, 'ratio': 1.6666666666666667},
#  'lol': {'positive': 20, 'negative': 4, 'ratio': 4.2},
#  'pura': {'positive': 8, 'negative': 9, 'ratio': 0.9},
#  'thread': {'positive': 3, 'negative': 0, 'ratio': 4.0},
#  'karma': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'chutiyapa': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'cancer': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'mareez': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'elaj': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'karwane': {'positive': 4, 'negative': 0, 'ratio': 5.0},
#  'lahor': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'jane': {'positive': 9, 'negative': 5, 'ratio': 1.6666666666666667},
#  'mutadid': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'sheri': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'panjab': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'poliec': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'chad': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'gai': {'positive': 14, 'negative': 7, 'ratio': 1.875},
#  'respect': {'positive': 8, 'negative': 4, 'ratio': 1.8},
#  'dilwale': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'phele': {'positive': 6, 'negative': 3, 'ratio': 1.75},
#  'jab': {'positive': 84, 'negative': 58, 'ratio': 1.4406779661016949},
#  'challengeaccepted': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'tweet': {'positive': 26, 'negative': 9, 'ratio': 2.7},
#  'dala': {'positive': 3, 'negative': 5, 'ratio': 0.6666666666666666},
#  'tabse': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'hun': {'positive': 8, 'negative': 6, 'ratio': 1.2857142857142858},
#  'rahunga': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'kismat': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'badi': {'positive': 7, 'negative': 11, 'ratio': 0.6666666666666666},
#  'kutti': {'positive': 3, 'negative': 1, 'ratio': 2.0},
#  'cheez': {'positive': 6, 'negative': 6, 'ratio': 1.0},
#  'saali': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'palat': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'jaati': {'positive': 6, 'negative': 5, 'ratio': 1.1666666666666667},
#  'bholunga': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'jan': {'positive': 3, 'negative': 2, 'ratio': 1.3333333333333333},
#  'deekho': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'rashtravadi': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'isko': {'positive': 17, 'negative': 12, 'ratio': 1.3846153846153846},
#  'muslims': {'positive': 17, 'negative': 7, 'ratio': 2.25},
#  'cencus': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'hoga': {'positive': 86, 'negative': 48, 'ratio': 1.7755102040816326},
#  'pure': {'positive': 8, 'negative': 3, 'ratio': 2.25},
#  'world': {'positive': 10, 'negative': 4, 'ratio': 2.2},
#  'history': {'positive': 4, 'negative': 4, 'ratio': 1.0},
#  'bata': {'positive': 16, 'negative': 8, 'ratio': 1.8888888888888888},
#  'dega': {'positive': 10, 'negative': 4, 'ratio': 2.2},
#  'islam': {'positive': 21, 'negative': 14, 'ratio': 1.4666666666666666},
#  'majority': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'terrorism': {'positive': 313, 'negative': 100, 'ratio': 3.108910891089109},
#  'non': {'positive': 3, 'negative': 1, 'ratio': 2.0},
#  'secular': {'positive': 3, 'negative': 2, 'ratio': 1.3333333333333333},
#  'samjayega': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'bachao': {'positive': 8, 'negative': 2, 'ratio': 3.0},
#  'chilayega': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'hahaha': {'positive': 10, 'negative': 3, 'ratio': 2.75},
#  'koii': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'imtihaan': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'logonko': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'najar': {'positive': 4, 'negative': 1, 'ratio': 2.5},
#  'ata': {'positive': 4, 'negative': 9, 'ratio': 0.5},
#  'yoga': {'positive': 3, 'negative': 0, 'ratio': 4.0},
#  'communalism': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'safronisation': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'unka': {'positive': 17, 'negative': 6, 'ratio': 2.5714285714285716},
#  'virodh': {'positive': 4, 'negative': 14, 'ratio': 0.3333333333333333},
#  'secularism': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  'shanti': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'sandesh': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'samazna': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'ravish': {'positive': 8, 'negative': 4, 'ratio': 1.8},
#  'sachcha': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'suchcha': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'journalist': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  'sachche': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'budhdhijeevi': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'intelligent': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'achhe': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  'logon': {'positive': 22, 'negative': 14, 'ratio': 1.5333333333333334},
#  'extra': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'ordinary': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'loud': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  'voice': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'zehreele': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'shabd': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'istemaal': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'karenge.har': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'waqt': {'positive': 13, 'negative': 6, 'ratio': 2.0},
#  'gussie': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'rahenge.ye': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'sanskaar': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'larisa': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'culture': {'positive': 3, 'negative': 1, 'ratio': 2.0},
#  'hai.bure': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'soc': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'oooo': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'hello': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'serial': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'fan': {'positive': 14, 'negative': 13, 'ratio': 1.0714285714285714},
#  'lage': {'positive': 11, 'negative': 4, 'ratio': 2.4},
#  'samaj': {'positive': 13, 'negative': 4, 'ratio': 2.8},
#  'salmanji': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'bajai': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  'lagta': {'positive': 28, 'negative': 14, 'ratio': 1.9333333333333333},
#  'kanta': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'lagny': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'phool': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'phenk': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'dety': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'u': {'positive': 37, 'negative': 82, 'ratio': 0.4578313253012048},
#  'ham': {'positive': 22, 'negative': 4, 'ratio': 4.6},
#  'likhte': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'garam': {'positive': 3, 'negative': 1, 'ratio': 2.0},
#  'jaae': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'khikhikhi': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'khair': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  'yah': {'positive': 5, 'negative': 1, 'ratio': 3.0},
#  'imagination': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'writer': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'baaki': {'positive': 7, 'negative': 4, 'ratio': 1.6},
#  'om': {'positive': 3, 'negative': 2, 'ratio': 1.3333333333333333},
#  'raut': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'likha': {'positive': 9, 'negative': 3, 'ratio': 2.5},
#  'alag': {'positive': 8, 'negative': 4, 'ratio': 1.8},
#  'ram': {'positive': 19, 'negative': 7, 'ratio': 2.5},
#  'kalpanik': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'bolne': {'positive': 12, 'negative': 10, 'ratio': 1.1818181818181819},
#  'kehne': {'positive': 4, 'negative': 3, 'ratio': 1.25},
#  'mandir': {'positive': 9, 'negative': 7, 'ratio': 1.25},
#  'jaate': {'positive': 3, 'negative': 5, 'ratio': 0.6666666666666666},
#  'ladkiya': {'positive': 5, 'negative': 2, 'ratio': 2.0},
#  'chedte': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'kutta': {'positive': 4, 'negative': 6, 'ratio': 0.7142857142857143},
#  'temple': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'run': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  'khel': {'positive': 5, 'negative': 3, 'ratio': 1.5},
#  'hinduo': {'positive': 3, 'negative': 5, 'ratio': 0.6666666666666666},
#  'dhakke': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'astha': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'mtlb': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'elections': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'achchha': {'positive': 3, 'negative': 0, 'ratio': 4.0},
#  'indian': {'positive': 20, 'negative': 19, 'ratio': 1.05},
#  'ekdusre': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'rakhta': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'comments': {'positive': 9, 'negative': 2, 'ratio': 3.3333333333333335},
#  'karein': {'positive': 5, 'negative': 1, 'ratio': 3.0},
#  'pls': {'positive': 3, 'negative': 1, 'ratio': 2.0},
#  'tiger': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'humari': {'positive': 5, 'negative': 3, 'ratio': 1.5},
#  'free': {'positive': 10, 'negative': 3, 'ratio': 2.75},
#  'dekhne': {'positive': 4, 'negative': 4, 'ratio': 1.0},
#  'ufaan': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'maare': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  'zyaada': {'positive': 3, 'negative': 0, 'ratio': 4.0},
#  'load': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'moviegoer': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'twitter': {'positive': 15, 'negative': 8, 'ratio': 1.7777777777777777},
#  'boycott': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'trend': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'khan': {'positive': 17, 'negative': 25, 'ratio': 0.6923076923076923},
#  'degi': {'positive': 7, 'negative': 3, 'ratio': 2.0},
#  'bolegi': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'use': {'positive': 33, 'negative': 30, 'ratio': 1.096774193548387},
#  'lene': {'positive': 5, 'negative': 1, 'ratio': 3.0},
#  'goli': {'positive': 10, 'negative': 3, 'ratio': 2.75},
#  'chalakar': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'rahi': {'positive': 70, 'negative': 58, 'ratio': 1.2033898305084745},
#  'uspe': {'positive': 7, 'negative': 2, 'ratio': 2.6666666666666665},
#  'maar': {'positive': 16, 'negative': 19, 'ratio': 0.85},
#  'pic.twitter.com/58wfsqwnuh': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'khole': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'cheepikians': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'chutiya': {'positive': 4, 'negative': 15, 'ratio': 0.3125},
#  'sambhal': {'positive': 3, 'negative': 1, 'ratio': 2.0},
#  'ja': {'positive': 44, 'negative': 30, 'ratio': 1.4516129032258065},
#  'zara': {'positive': 10, 'negative': 4, 'ratio': 2.2},
#  'mohabbat': {'positive': 17, 'negative': 5, 'ratio': 3.0},
#  'marks': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'yahin': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'jate': {'positive': 13, 'negative': 16, 'ratio': 0.8235294117647058},
#  '370': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'abdullah': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'hoke': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'pok': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  'batate': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'tere': {'positive': 47, 'negative': 37, 'ratio': 1.263157894736842},
#  'kodi': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'congi': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'chudail': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'wahi': {'positive': 18, 'negative': 6, 'ratio': 2.7142857142857144},
#  'kahegi': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'congress': {'positive': 17, 'negative': 13, 'ratio': 1.2857142857142858},
#  'karti': {'positive': 26, 'negative': 10, 'ratio': 2.4545454545454546},
#  'ayi': {'positive': 2, 'negative': 3, 'ratio': 0.75},
#  'tujhe': {'positive': 10, 'negative': 13, 'ratio': 0.7857142857142857},
#  'halala': {'positive': 3, 'negative': 6, 'ratio': 0.5714285714285714},
#  'pad': {'positive': 5, 'negative': 2, 'ratio': 2.0},
#  'gyi': {'positive': 7, 'negative': 6, 'ratio': 1.1428571428571428},
#  'islie': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'esa': {'positive': 6, 'negative': 4, 'ratio': 1.4},
#  'rhi': {'positive': 14, 'negative': 11, 'ratio': 1.25},
#  'gunhegar': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'muhabbat': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'konsa': {'positive': 4, 'negative': 1, 'ratio': 2.5},
#  'dsp': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'lagwa': {'positive': 3, 'negative': 0, 'ratio': 4.0},
#  'deti': {'positive': 6, 'negative': 6, 'ratio': 1.0},
#  'ppl': {'positive': 4, 'negative': 3, 'ratio': 1.25},
#  'wen': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'dey': {'positive': 4, 'negative': 2, 'ratio': 1.6666666666666667},
#  'call': {'positive': 4, 'negative': 4, 'ratio': 1.0},
#  'jabki': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'vo': {'positive': 36, 'negative': 35, 'ratio': 1.0277777777777777},
#  'feeling': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'felaoge': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'mulle': {'positive': 6, 'negative': 3, 'ratio': 1.75},
#  'invent': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'jeet': {'positive': 14, 'negative': 5, 'ratio': 2.5},
#  'mc': {'positive': 5, 'negative': 2, 'ratio': 2.0},
#  'la': {'positive': 5, 'negative': 1, 'ratio': 3.0},
#  'dena': {'positive': 23, 'negative': 5, 'ratio': 4.0},
#  'parliament': {'positive': 2, 'negative': 3, 'ratio': 0.75},
#  'phle': {'positive': 4, 'negative': 5, 'ratio': 0.8333333333333334},
#  'atankwadi': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  'ghosit': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'suadie': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'kings': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'badshat': {'positive': 1, 'negative': 0, 'ratio': 2.0},
#  'bachane': {'positive': 7, 'negative': 3, 'ratio': 2.0},
#  'chora': {'positive': 2, 'negative': 0, 'ratio': 3.0},
#  ...}

# %%
# Test your function; find positive words at or above a threshold
get_words_by_threshold(freqs, label=1, threshold=10)
# Out:
# {'bakri': {'positive': 10, 'negative': 0, 'ratio': 11.0},
#  'punjab': {'positive': 13, 'negative': 0, 'ratio': 14.0},
#  'khatm': {'positive': 15, 'negative': 0, 'ratio': 16.0},
#  'episode': {'positive': 9, 'negative': 0, 'ratio': 10.0},
#  'stop': {'positive': 11, 'negative': 0, 'ratio': 12.0},
#  'himachal': {'positive': 9, 'negative': 0, 'ratio': 10.0},
#  'jeeto': {'positive': 10, 'negative': 0, 'ratio': 11.0}}

# %% [markdown]
# Notice the difference between the positive and negative ratios. Emojis like :( and words like 'me' tend to have a negative connotation. Other words like glad, community, arrives, tend to be found in the positive tweets.

# %% [markdown]
# <a name='5'></a>
# ## 5 - Error Analysis
#
# In this part you will see some tweets that your model missclassified. Why do you think the missclassifications happened? Were there any assumptions made by your naive bayes model?

# %%
# Some error analysis done for you
print('Truth Predicted Tweet')
for x, y in zip(test_x, test_y):
    y_hat = naive_bayes_predict(x, logprior, loglikelihood)
    if y != (np.sign(y_hat) > 0):
        print('%d\t%0.2f\t%s' % (y, np.sign(y_hat) > 0, ' '.join(
            process_tweet(x)).encode('ascii', 'ignore')))
# Out:
# Truth Predicted Tweet
# 1	0.00	b'salo rape k ilawah aur kiya ate hai porkies'
# 1	0.00	b'use ghar ki safayi karni hogi .. wish sanya kabhi mere ghar ayi hoti.pkka mera murder kar deti mera room dekh kar proud fatimasanashaikh'
# 1	0.00	b'india waly nafrat ko badhawa denay ka koi mauka ni choorty un gov apni jaga un fazool channel waly bhi un ki ...'
# 1	0.00	b'ye sahe kaha par matter solve karo ki tumhare bestie kyun hate karte'
# 1	0.00	b'kulbhushan bhi katega phansi pe charha ke bhej dein ge independence day pe'
# 1	0.00	b'wo gareeb awam ja k army ki god kyu beithi hai.kyu waha k terror perpetrators ka sath deti hai'
# 1	0.00	b'phir badiya hai ... voh kya hai ki hindustan ke hain na sirf pyar aur ekta samajh aati hai ... yeh nafrat ki soch se confuse hote hain'
# 1	0.00	b'ya allah hitler jesa hukmaran de sdo thatta ko sharm nai roz jamah masjid ki light kharab hoti ye log ac room se nikulte tuk nai inko'
# 1	0.00	b'jinke khoon mein hai desh deshwasiyo se gadaari wo hai congress saari'
# 1	0.00	b'jinke khoon mein hai desh deshwasiyo se gadaari wo hai congress saari'
# 1	0.00	b'behen ki loudi tumhare legal rape krte h ... bhai behen ka chutiya'
# 1	0.00	b'ye sab chakkar rajnitee k hain ... dilon mai nafrat ye log dalte hain dono country k citizens k ...'
# 1	0.00	b'vasno devi ke mandir jane se sare paap kat hate h aur man ko saanti multi h jai mata di d.kumar p pic.twitter.com/dhzfxsgq18'
# 1	0.00	b'cong mahan bheekh mange votes'
# 1	0.00	b'mother bech kaar ke'
# 1	0.00	b'budha insaan tri fuddi 65 ki hai koi donkey hi chode tujhe han jitenge bhi hm n plz ye rape karna chordo hme izzat pyari hai jeet nhi'
# 1	0.00	b'farak bas itna hai hum sidhe sidhe rape bolte hai aur tum nikah ab pakistan legal rape hota hai bha se shadi kar ke usme hum kya kare'
# 1	0.00	b'islie india ko hindu rastra banay ccc'
# 1	0.00	b'rape se jo tu obsessed hai aur tuze live rape dikhana mera farz hai isliye fikar hai aur attached toilet bana diya tha hamne 47 hi'
# 1	0.00	b'awww pakistani hurt hua bas itne mehi kal tv aur aankh dono phod lega tu ek rape live hone wala hai pakistan ka dekh liyo agar light ho'
# 1	0.00	b'lekin tum log terrorism krte raho bs films banana chor ghatiya films aur ghatiya actors'
# 1	0.00	b'6yrs nikah'
# 1	0.00	b'jo bhi karlo rishikapoor kabhi prime minister nhi banega na us k bete ko koi film mileg jitni hate pak se karni ho karlo run veer kapoora'
# 1	0.00	b'mohabbat mein teri fitrat kya thi kadar humse nafrat kya thi teri chahat pe wafa ki thi mene tujhe bewafa hone ki zarurat kya thi'
# 1	0.00	b'ye hamesha denial mode pe rahenge jitna marji aaina dikha'
# 1	0.00	b'tere nabi k tatah 9 saal ki ladki se rape nehi karta hai chutia sala abu jahl k najayaj aulade'
# 1	0.00	b'crime petrol ka epi nhi dekha 5 sal se ghar mai kam karte hue maid ne apne hi malik ka murder kiya .. kisi pr bhrosha ni karna chahiye'
# 1	0.00	b'inki ragon mai wahii khoon hai jo aatankion ki mai hai jab opposition hoti h khud b gun uthaane ki baat krti'
# 1	0.00	b'raveesh ji u r right'
# 1	0.00	b'jo sochega logic ke sath ki usko hate krta hu ... means yes'
# 1	0.00	b'yes aur jo hate use mili wo usne khud hi bulaayi thi bayaan de kar ..'
# 1	0.00	b'least kisi ko female hone ka taana nahi marte aur wese rape k leay tou 1 hai'
# 1	0.00	b'sab se jayda nafrat mujhe us bell se h abhi se chipak rahi thi man hua uska murder kar'
# 1	0.00	b'ladkiyun ko rape kar k samjhty hain barry mard hain hum.border pe tu k himat ni hai hindus ki aur batein dekho'
# 1	0.00	b'azaadi k bad bhi kuch esa kro pak ... hate felane se abdus salam nhi bnte'
# 1	0.00	b'ranbir ko hate mat kar ... baaki sabko kar ...'
# 1	0.00	b'tum na miltae tou accha tha jahaan'
# 1	0.00	b'india kya hota h orat zaat ke sath har community orat rape hotti h siraf muslims nahi.kiyo nahi aap issue ko othate'
# 1	0.00	b'hota usko iska khoon karne k liye hire kar leti'
# 1	0.00	b'molvi shb v per fashion show dekh rhy thy'
# 1	0.00	b'aap ko koi hate nahi karta manveer ji ... '
# 0	1.00	b'bhai army donoun taraf ki hi lagi hoe hai hum log aapas main nafrat ko pata nahi kyun parwaan charha rhe hain '
# 0	1.00	b'kashmir itny log shaheed karty ho woh terrorism act ni jahil rishi kapoor khoty kabhi school chala jata ...'
# 0	1.00	b'yar ap rape pehle band karo os ky bad baat karna'
# 0	1.00	b'bhai mohabbat ki zubaan seekho nafrat kuch nhi degi siwae jang aur larai k'
# 0	1.00	b'thori c sharam b nae ha .. kon kar raa ha terrorism ultaa chor kotowaal ko dantay ..'
# 0	1.00	b'itne sidhe hote baat hi kucch hoti pata nahi kyun terrorism ko panah deke baithe hai'
# 0	1.00	b'terrorism ka matlab bhee pata hai aap ka pita modi nay aps bacho ko mara gujrat kashmir ya kia hai shoib malik ka salo'
# 0	1.00	b'kya bol saktey hain ab men trash bs ik pathr pe lakeer lagado bhai hum bi men hain humne rape jokes ni kiye na ni bhai men trash '
# 0	1.00	b'truth hai yar'
# 0	1.00	b'rape say paida honay walo pehlay decide kar ap logon ka asal baap kon hai jo paida hota hai ilzam pakistan pay ilzam laga detay ho'
# 0	1.00	b'well said bas tum log bhi gadhon ka rape karna band kar pic.twitter.com/hedxpmenun'
# 0	1.00	b'kashmir pe jo indian army jo zulm kar rahi usko kia kahtay hain'
# 0	1.00	b'aise hi meeting attend karte raho train mein rape hota rahe ga tum napunsak ki tarah baith kar dekhte raho'
# 0	1.00	b'bal thakray muslims k jo kar rahay usko kia bolain ge '
# 0	1.00	b'apki baaton se nhi lagraha bhai aur mein kiun apko deshdrohi bolunga bas ab abhijeet jaise nafrat failane wale agent ke samarthan mein aaye'
# 0	1.00	b'toilets tm log banwa ni sakte'
# 0	1.00	b'rape tm log rukwa ni sakte'
# 0	1.00	b'aur phir mun utha kar ah jate ho twitter par'
# 0	1.00	b'news mai dekhte nahi chakro makn khoon hojate'
# 0	1.00	b'ager yehi bat hai hum har jayen gay bas har larki ka rape karna banda kar humain haar mazoor hai'
# 0	1.00	b'hum khud terrorism se effected han aur ke khilaf larh rahe han mager aap logon ko nahi nazer ata ke mudi sarkar kiya kar rahi hae'
# 0	1.00	b'arey sirji agar ye logon ko kashmir bhi deh dona phir bhi unka terrorism khatam nahi hoga.woh baat alag hai ki kashmir unke haath nai ayega'
# 0	1.00	b'raw kabhi v pak mein terrorism spread nahi karta hai.pak hi jimedar hai yeh sab keliye.tumhare bachr marte hai phir v tum sudharte nahi ho'
# 0	1.00	b'prosiac well grammar nazi baat karni mujhe mushkil kabhi aisi toh na thi'
# 0	1.00	b'rape karte waqt words ki chinta karni thi'
# 0	1.00	b'abe kutte modi ko teen sal huye hai 70 sal tak teri ke yar kishano ka khoon pikar unko anemic kar diya chosne ko bacha kya hai'
# 0	1.00	b'beef se jisko nafrat h pahle apne gharon se leather k belt aur shoes nikaal kr jala de ..'
# 0	1.00	b'modiji ji andhakanun badlo 70sal purana abi cc camera ka zamana h deshko surakshit banao rape bhrastachari band karo pic.twitter.com/kbmkuifmni'
# 0	1.00	b'hate yahya jammeh sa chapi mamitimam'
# 0	1.00	b'9 ho jate hate aamir '
# 0	1.00	b'maine kab kaha k ghaib kerna theek hai .. meri konsi tweet main ye likha hai sare-e-aam phansi jo bakwas kare '
# 0	1.00	b'aaj se j ko hate karna suru'
# 0	1.00	b'prostitute k pass bhi jaane k baad hawas poori na hoti toh rape pe aa jate hai ... hawas ki hadh hai bhai ...'
# 0	1.00	b'talk hate preachers hamara kaam mohabbat banta hai jahan nafrat ki jagah nahi hai ..'
# 0	1.00	b'cunning person.apne bhasan se ghar walon ko fasa liya.bani se bahut jyada bura isne bola tha hate u'
# 0	1.00	b'rape ke mamale logo ko hi kuchh karna'
# 0	1.00	b'roz news aane se ye prison jane ya candle march karne se rape nhi band hoga'
# 0	1.00	b'jab court saza deti hai humen right wale aate hai bachane ye hai insan aise rape nhi band hone wale'
# 0	1.00	b'kami hamare andar khud hai jab rape hota hai candle march karte hai'
# 0	1.00	b'bani made hate meri maa ko bola sab ayo help kro another case bani tumhari maa ko bola main kya kru'
# 0	1.00	b'hate yaar hate much par ek baat yaad rakho pehle apni level ko unke jaisa kr firrr bolneke ke layak ho fuck ratherpic.twitter.com/pig5l69vyp'
# 0	1.00	b'naqab pr bolne se pahle un logo pr bolye jo rape krte h chher chhar krte jis din duniya ke mrd sudhar jynge insallah nakab khud ht jyega'
# 0	1.00	b'hate baekhyun '
# 0	1.00	b'oh shit hate ruqee'
# 0	1.00	b'hate sarrdi'
# 0	1.00	b'wo akdu hai hate usne ek tweet bhi nahi kiya dangal ke liye itni insecure hai jabki aamir ne kiya tha sultan ke liye'
# 0	1.00	b'captain ko koi kuch bolega tho uska rape hoga wo bhi insane rape'
# 0	1.00	b'hate formalities bhai tum bhi insan ho main bhi'
# 0	1.00	b'okay use bata dena ki hate salluu '
# 0	1.00	b'hate sony manhus channel main dekhti hi nhi thi bus edkv ke liye dekha tha'
# 0	1.00	b'pehke wale srk hote toh abtak inki maiya ka rape ho chuka hota aajkal bahoot simple hogayein hain'
# 0	1.00	b'agar hindustan rape ki saza jo islam saza e maurice muluk rape nahi ho sakta'
# 0	1.00	b'allah ne logoko brain name ki cheez hi nahi diyavai agr kisiko hate karna puri shiddhat se karo na khudse jada unka news rakteho'
# 0	1.00	b'aaj se hate mitha'
# 0	1.00	b'see 50 public pagal ho gai bhukha mar dete hai bomb daltr hai gharope ladkiyo ka rape karte hai'
# 0	1.00	b'hai hate '
# 0	1.00	b'knsa terrorism agr yeh baat ha phir toh sabse zyada hum log hain cheez ka shikaar'
# 0	1.00	b'konje ke ya daar ko jozi yeses hate city'
# 0	1.00	b'umubi futhi uyaphapha hate'
# 0	1.00	b'namo ji betiyon ko rape se bachao-rapist ko sajaye maut kya hoga aap ke raaj'
# 0	1.00	b'tum na izzat jeet payi na dil na trophy .. jitni bhi izzat bachi thi woh bhi kho baithi .. hate u ..'
# 0	1.00	b'reply kare jaldi se mein nahi dekh sakta ki salman bhai se aise koi aise bat kare hate bani'
# 0	1.00	b'hate padhai ..'
# 0	1.00	b'wohh gharse dawa nhi maa ki dua leke nikalte hai .. hate ajaz bhai haters '
# 0	1.00	b'islea rape hote hai'
# 0	1.00	b'tak payah tak payah hate suprise'
# 0	1.00	b'acha .. hindu dharma ko bad dekhna jao.halala roko.masumo.ka rape hota bahane se'
# 0	1.00	b'chole hate kabi mere liye bi kuch dedicate kia kariye crush g '
# 0	1.00	b'baarish may bheeg gaya hate rain'
# 0	1.00	b'yaar ye kya chutiyapa hai banda shaadi bhi na kare hate football '
# 0	1.00	b'punjab hate kejriwal mean words samana aaye kejriwal jutta maarne mai aaunga ..'
# 0	1.00	b'bhai ye batao tum ji murthal rape case ki baat kar rahe ho wo rape case mein tum high court se aage hogaye ..'
# 0	1.00	b'patiwarta k karan unki image kharab hui hate kalwaa'
# 0	1.00	b'hate flopa khud ki shakal itni bekar hai dusro ko boti hai apni sadhi se shakal dekh ja ke mirror mein ghost dikhegi koi'
# 0	1.00	b'agar tum bani ko hate karta ho toh time kyu waste kar rahe ho posting bani posts'
# 0	1.00	b'haaye tab also hate duniya sabse zyaada ... ab bolo'
# 0	1.00	b'bhanwari devi ka nam yad hai rajsthan ki thi .. unhone raga pe rape kr arop dala aur dead body mili unki ..'
# 0	1.00	b'ab v rape band nahi ho raha hai'
# 0	1.00	b'yaudah nurut umji aja gausah ke pavo pavo hate much om jejin pic.twitter.com/rzruizyzle'
# 0	1.00	b'sirji 1 mulla rape killed dalit girl bihar kuch bhonko'
# 0	1.00	b'mujhe restey aur payar ke naam par dokha diya gaya hai.jhut ke game khela hai logo ne mere saath.agar kahety payar ke naam mar jata hate u'
# 0	1.00	b'kon hate karta hai tumhay dafa karo usay bas'
# 0	1.00	b'freedom speech aur hate speech farq jaan kr geo ... islam ka mazaq urana freedom speech nhi'
# 0	1.00	b'love tweet hate ridiculous bani ek task kar nahi pai aaj tak bas ande tatto k siwa kuch nahi hai'
# 0	1.00	b'hate lopa trend vi banao yar bahut hit hogi .. stand bani'
# 0	1.00	b'humayun apne pm se bol ki pehle terrorism khatam kare puriya duniya gandagi faila ke rakhi hai pakistan ne'
# 0	1.00	b'hate guys jo hostel mai bilawaja hi aa kar room mai baith jaty hain'
# 0	1.00	b'sir jaise log rape ko bhi galat nhi mante honge'
# 0	1.00	b'kahit gaano mopako ka hate lab paren kita'
# 0	1.00	b'kashmiri hindu innocent nahi kya unhone kya gunah kiya tha unke sath q rape mass murder hua kisne kiya terrorists kon hain'
# 0	1.00	b'behanchod pehle terrorism band karlo 2-3 baar bheek di uske baad bhi harkato se baaz naahi aate'
# 0	1.00	b'zaroor agar ko railway se hataya hate toh .. pic.twitter.com/sgyl2s48xj'
# 0	1.00	b'hate manu rohan ko priyanka se compare karta hai kuch bhi '
# 0	1.00	b'aaj jo tumne kiya hai na manu anty iske baad .. hate'
# 0	1.00	b'aate hai hate'
# 0	1.00	b'8: 12 manhoos ghari lufe yw waqt hate'
# 0	1.00	b'hate poori kulfi jam gyi hai'
# 0	1.00	b'kuch log british raj ko acha mante h par wo log jo musalmano ki chamchaguri karte h inki kisi na kisi generation muslim ne rape kia hoga'
# 0	1.00	b'bihado bagi hote ye v wahi hai vyawastha se pareshan sipahi kya kare.neta murga khaye aur use sukhi roti chai hate leader'
# 0	1.00	b'hahaha hohoho kaun si imadaar rajneeti krta hai yeh pagal aadmi ration card k naam pr rape krte hai paapiye'
# 0	1.00	b'mughalo k rape ka nateeja hai tu osama bin laden ki aulaad ... dekh kahin agla bomb teri maa k gaand mein naa fatt jaye'
# 0	1.00	b'sachche deen kon vo lootere kasai ghod-sawar mangoliye arab jo lootne aaye aur hindu auratonko rape kr ke tumhe paida kiya '
# 0	1.00	b'jaha tak mujhe pta hai terrorism religion still jab tak aap jaise log chutiyapa kabhi band nahi hoga'
# 0	1.00	b'aaj koi hate speech diya toh kal director ki pitayi sanjayleelabhansali'
# 0	1.00	b'mc kuch gundo ki vajah se tum aaj hindu .. bol rahe ho islamic terrorism bolne gand phatti hai'
# 0	1.00	b'aur jo hate speech kuuta karta hai us ka kya hai himmat defend kro usko'
# 0	1.00	b'haha slb ko thappad pada tab kaisa des mei ho lagraha hei jab har din rape hota hei tab gaand marwa rahi thi kya'
# 0	1.00	b'bhai tumhari soch pe daat deta hu tum aap k ho ye pta chal gaya uska hu jo kuch kare hate congress 4 ur information'
# 0	1.00	b'koi bhi ban jaye bani j na bane hate'
# 0	1.00	b'bigboss na akhri wqat par voting rule change kar diya aur inform bhi ab kar raha ha ... hate'
# 0	1.00	b'magar porkistani insaan nahi hai ghade hai sarey rape ki padaish'
# 0	1.00	b'wese chahe rape hote rahe poore desh one bats eye'
# 0	1.00	b'veer hate usne aaj rangeela ko ghoda bana diya uska maa kal rangeela ko kutta kaha'
# 0	1.00	b'raees ka rape hoke hi rahega'
# 0	1.00	b'bhensa ko van karna chye tha us awaz uthanay wlay ko ban kr diya hate speech tou bhensa kr rha hai pemra'
# 0	1.00	b'chal na gunda manvr manu ka chamcha hate m2 piche piche chugliya karta hai manu ke sath ghar ganda bna rak'
# 0	1.00	b'elections 2017 betiyoon ka rape kar unhe pedh se latka diya tha shayad ye sabhi ko hoga yaad .. bachaoo desh bachaoo'
# 0	1.00	b'kitni gaand jalti hai bhai teri even srk fans hate u chutiye'
# 0	1.00	b'kitni gaand jalti hai bhai teri even srk fans hate u chutiye'
# 0	1.00	b'waise toh srk ki last movie maine lappy pr 2011 dekhi thi uske baad se hate'
# 0	1.00	b'ye hai sapa ke neta jo ki varanasi cholapur block ke pramukh hai inki gunda gardi.ladish ko rape ki dhamki pic.twitter.com/51y8zk16ln'
# 0	1.00	b'mujhe pehele se hi pata tha sallu fans ke bareme galat kuch tweet nahin kiya kabhi bt hate srk'

# %% [markdown]
# <a name='6'></a>
# ## 6 - Predict

# %%
my_tweet = 'ab janata ke praakrtik otomaitik #raiphal ka baarood #nasabandee karake band karoge,,to phir khilauna #bandook to chalaenge hee....  ib kutte karm karoge to pher #kutte kee maut hee maroge    #tera bee tem aagya #kaijriwalassassinationchlaim'
p = naive_bayes_predict(my_tweet, logprior, loglikelihood)
print(p)
# Out:
# -0.5728726547946349

# %%
my_tweet = 'kitana achchha samudaay hai ye hamesha gareeb logo ke lie bhandaara arenj karata hai'
p = naive_bayes_predict(my_tweet, logprior, loglikelihood)
print(p)
# Out:
# 1.6383123562330117
