# %%
# !git clone https://github.com/huggingface/transformers
# Out:
# fatal: destination path 'transformers' already exists and is not an empty directory.

# %%
# !pip install -q datasets transformers evaluate scipy rouge_score py7zr

# %%
# !pip install git+https://github.com/huggingface/transformers

# %%
# !pip install --upgrade accelerate

# %%
# !python /content/transformers/examples/pytorch/text-generation/run_generation.py \
    --model_name_or_path gpt2 \
    --model_type gpt2 \
    --do_train \
    --do_eval \
    --train_file /train.csv \
    --validation_file /test.csv \
    --output_dir /tmp/tst-gen \
    --per_device_train_batch_size=4 \
    --per_device_eval_batch_size=4 \
    --overwrite_output_dir \
    --predict_with_generate
# Out:
# 2023-04-25 19:44:32.925491: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# usage: run_generation.py
#        [-h]
#        --model_type
#        MODEL_TYPE
#        --model_name_or_path
#        MODEL_NAME_OR_PATH
#        [--prompt PROMPT]
#        [--length LENGTH]
#        [--stop_token STOP_TOKEN]
#        [--temperature TEMPERATURE]
#        [--repetition_penalty REPETITION_PENALTY]
#        [--k K]
#        [--p P]
#        [--prefix PREFIX]
#        [--padding_text PADDING_TEXT]
#        [--xlm_language XLM_LANGUAGE]
#        [--seed SEED]
#        [--no_cuda]
#        [--num_return_sequences NUM_RETURN_SEQUENCES]
#        [--fp16]
#        [--jit JIT]
# run_generation.py: error: unrecognized arguments: --do_train --do_eval --train_file /train.csv --validation_file /test.csv --output_dir /tmp/tst-gen --per_device_train_batch_size=4 --per_device_eval_batch_size=4 --overwrite_output_dir --predict_with_generate
